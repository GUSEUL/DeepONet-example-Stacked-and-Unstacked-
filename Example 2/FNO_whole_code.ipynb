# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt


# =============================================================================
# 1. Navier–Stokes PDE solver (pseudo-spectral method)
# =============================================================================
def solve_navier_stokes(w0, nu, dt, t_final, N):
    """
    2D Navier–Stokes vorticity PDE (주기적 경계조건) 를 푸는 간단한 pseudo-spectral solver.
    
    PDE:
        ∂ₜw + u · ∇w = ν ∆w + f(x)
        u = (ψ_y, -ψ_x),   and   ∆ψ = -w,  with periodic boundary conditions.
    입력:
        w0: 초기 vorticity, shape (N, N)
        nu: 점성 계수
        dt: 시간 스텝
        t_final: 최종 시간
        N: 격자 크기 (N×N)
    출력:
        snapshots: 정수 시간마다 (t, w) 튜플 리스트.
    """
    # 공간 좌표 생성 (0 ≤ x,y < 1)
    x = np.linspace(0, 1, N, endpoint=False)
    y = np.linspace(0, 1, N, endpoint=False)
    xv, yv = np.meshgrid(x, y, indexing='ij')
    
    # forcing function: f(x) = 0.1*( sin(2π(x+y)) + cos(2π(x+y)) )
    f = 0.1 * (np.sin(2*np.pi*(xv + yv)) + np.cos(2*np.pi*(xv + yv)))
    
    # FFT frequencies (주기적 도메인: [0,1])
    kx = np.fft.fftfreq(N, d=1.0/N) * 2*np.pi
    ky = np.fft.fftfreq(N, d=1.0/N) * 2*np.pi
    kx, ky = np.meshgrid(kx, ky, indexing='ij')
    ksq = kx**2 + ky**2
    ksq[0,0] = 1.0  # 0분할 방지
    
    w = w0.copy()
    snapshots = []
    snapshot_times = np.arange(0, t_final+dt, 1.0)  # 정수 시간마다 기록
    next_snapshot_index = 0
    
    nsteps = int(t_final/dt)
    for step in range(nsteps):
        t = step * dt
        # 스냅샷 기록
        if next_snapshot_index < len(snapshot_times) and t >= snapshot_times[next_snapshot_index]:
            snapshots.append((t, w.copy()))
            next_snapshot_index += 1
        
        # vorticity의 FFT
        w_hat = np.fft.fft2(w)
        # stream function: ∆ψ = -w  ->  ψ_hat = -w_hat / ksq, ψ_hat(0)=0
        psi_hat = -w_hat / ksq
        psi_hat[0,0] = 0.0
        psi = np.real(np.fft.ifft2(psi_hat))
        
        # 속도 계산: u = ψ_y, v = -ψ_x (spectral differentiation)
        u = np.real(np.fft.ifft2(1j * ky * psi_hat))
        v = -np.real(np.fft.ifft2(1j * kx * psi_hat))
        
        # vorticity gradient (spectral differentiation)
        w_x = np.real(np.fft.ifft2(1j * kx * w_hat))
        w_y = np.real(np.fft.ifft2(1j * ky * w_hat))
        
        # 비선형 항: u * w_x + v * w_y
        nonlinear = u * w_x + v * w_y
        
        # Laplacian: ∆w = ifft2(-ksq * w_hat)
        lap_w = np.real(np.fft.ifft2(-ksq * w_hat))
        
        # Euler explicit time stepping
        w = w + dt * (-nonlinear + nu * lap_w + f)
    
    return snapshots

    
# =============================================================================
# 2. Navier-Stokes 데이터셋 (PDE solver를 사용하여 데이터 생성)
# =============================================================================
class NavierStokesDatasetFromSolver(Dataset):
    def __init__(self, num_samples, N, dt, t_final, nu, T_in_range, T_out_times):
        """
        num_samples: 샘플 개수.
        N: 공간 격자 크기 (N×N).
        dt: 시간 스텝.
        t_final: 최종 시각 (예, 30).
        nu: 점성 계수.
        T_in_range: 입력 시간 구간 (예: (0, 10)).
        T_out_times: 타겟 시간 (예: [15, 20, 25, 30]).
        """
        self.samples = []
        for i in range(num_samples):
            # 랜덤 초기 조건 (예: 가우시안 랜덤 필드)
            w0 = np.random.randn(N, N)
            snapshots = solve_navier_stokes(w0, nu, dt, t_final, N)
            # snapshots: [(t, w), ...] t는 정수 시간 (0,1,2,...,t_final)
            input_series = []
            for t, w in snapshots:
                if t >= T_in_range[0] and t <= T_in_range[1]:
                    input_series.append(w)
            input_series = np.array(input_series)  # shape: (T_in, N, N)
            
            target_series = []
            for t, w in snapshots:
                if t in T_out_times:
                    target_series.append(w)
            target_series = np.array(target_series)  # shape: (T_out, N, N)
            self.samples.append((input_series, target_series))
        
        # 공간 좌표 (x, y) 생성, x,y ∈ [0,1)
        x = np.linspace(0, 1, N, endpoint=False)
        y = np.linspace(0, 1, N, endpoint=False)
        xv, yv = np.meshgrid(x, y, indexing='ij')
        self.spatial_coords = np.stack([xv, yv], axis=-1)  # (N, N, 2)
        # 입력 시간 좌표: 정수 시간 (예: 0,1,...,10)
        self.input_times = np.arange(T_in_range[0], T_in_range[1]+1)
        self.target_times = np.array(T_out_times)
        
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        input_series, target_series = self.samples[idx]
        T_in = input_series.shape[0]
        N = input_series.shape[1]
        # 각 입력 시간(t)에 대해 [vorticity, t, x, y]를 결합
        input_data = []
        for i, t in enumerate(self.input_times):
            t_field = np.full((N, N, 1), t)
            w_field = input_series[i][:, :, np.newaxis]
            combined = np.concatenate([w_field, t_field, self.spatial_coords], axis=-1)
            input_data.append(combined)
        input_data = np.stack(input_data, axis=0)  # shape: (T_in, N, N, 4)
        
        # target_series의 길이가 기대하는 T_out와 같지 않은 경우, 부족한 부분을 마지막 스냅샷으로 패딩
        if target_series.shape[0] < len(self.target_times):
            pad_len = len(self.target_times) - target_series.shape[0]
            last = target_series[-1:,...]
            pad = np.repeat(last, pad_len, axis=0)
            target_series = np.concatenate([target_series, pad], axis=0)
        
        target_data = []
        for i in range(target_series.shape[0]):
            target_data.append(target_series[i][:, :, np.newaxis])
        target_data = np.stack(target_data, axis=0)  # shape: (T_out, N, N, 1)
        
        # Torch tensor로 변환
        input_data = torch.tensor(input_data, dtype=torch.float32)
        target_data = torch.tensor(target_data, dtype=torch.float32)
        return input_data, target_data


# =============================================================================
# 3. 기존의 FNO 모델 (3D FNO: 시간-공간 연산자 학습)
# =============================================================================
class SpectralConv3d(nn.Module):
    def __init__(self, in_channels, out_channels, modes_t, modes_x, modes_y):
        super(SpectralConv3d, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes_t = modes_t
        self.modes_x = modes_x
        self.modes_y = modes_y
        self.scale = 1 / (in_channels * out_channels)
        self.weights = nn.Parameter(
            self.scale * torch.rand(in_channels, out_channels, modes_t, modes_x, modes_y, 2)
        )
    
    def compl_mul3d(self, input, weights):
        # weights: (in_channels, out_channels, t, x, y, 2) -> 복소수 텐서: (in_channels, out_channels, t, x, y)
        weight_complex = torch.view_as_complex(weights)
        # "bctxy, cotxy -> botxy": 입력의 각 주파수에 대해, C_in에 대해 합산하여 (batch, out_channels, t, x, y)를 얻음.
        return torch.einsum("bctxy, cotxy -> botxy", input, weight_complex)
    
    def forward(self, x):
        batchsize = x.shape[0]
        # 3D FFT 계산: x의 shape은 (batch, in_channels, t, x, y)
        x_ft = torch.fft.rfftn(x, dim=[2,3,4])
        out_ft = torch.zeros(
            batchsize, self.out_channels, x_ft.size(2), x_ft.size(3), x_ft.size(4),
            device=x.device, dtype=torch.cfloat
        )
        t_modes = min(self.modes_t, x_ft.size(2))
        x_modes = min(self.modes_x, x_ft.size(3))
        y_modes = min(self.modes_y, x_ft.size(4))
        out_ft[:, :, :t_modes, :x_modes, :y_modes] = self.compl_mul3d(
            x_ft[:, :, :t_modes, :x_modes, :y_modes],
            self.weights[:, :, :t_modes, :x_modes, :y_modes]
        )
        x = torch.fft.irfftn(out_ft, s=(x.size(2), x.size(3), x.size(4)))
        return x



class FNO3d(nn.Module):
    def __init__(self, modes_t, modes_x, modes_y, width, T_in, T_out):
        """
        modes_t, modes_x, modes_y: 시간 및 공간 방향의 Fourier 모드 수.
        width: latent channel 차원.
        T_in: 입력 시간 스텝 수 (예: 11, t=0~10)
        T_out: 출력 시간 스텝 수 (예: 4, t=15,20,25,30)
        """
        super(FNO3d, self).__init__()
        self.width = width
        self.T_in = T_in
        self.T_out = T_out
        self.fc0 = nn.Linear(4, width)  # 입력 채널: [vorticity, t, x, y]
        
        self.conv0 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv1 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv2 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv3 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        
        self.w0 = nn.Conv3d(self.width, self.width, 1)
        self.w1 = nn.Conv3d(self.width, self.width, 1)
        self.w2 = nn.Conv3d(self.width, self.width, 1)
        self.w3 = nn.Conv3d(self.width, self.width, 1)
        
        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)  # 출력: vorticity
        
        # Temporal predictor: 각 픽셀별로 입력 시간(T_in)을 출력 시간(T_out)으로 매핑
        self.temporal_fc = nn.Linear(T_in, T_out)
        
    def forward(self, x):
        # x: (batch, T_in, H, W, 4)
        batch, T_in, H, W, _ = x.shape
        x = self.fc0(x)  # (batch, T_in, H, W, width)
        x = x.permute(0, 4, 1, 2, 3)  # (batch, width, T_in, H, W)
        
        x0 = self.conv0(x)
        x1 = self.w0(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv1(x)
        x1 = self.w1(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv2(x)
        x1 = self.w2(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv3(x)
        x1 = self.w3(x)
        x = F.gelu(x0 + x1)
        
        x = x.permute(0, 2, 3, 4, 1)  # (batch, T_in, H, W, width)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)  # (batch, T_in, H, W, 1)
        
        # Temporal prediction: 각 픽셀별로 입력 시간 차원(T_in)을 T_out 차원으로 변환
        x = x.squeeze(-1)              # (batch, T_in, H, W)
        x = x.permute(0, 2, 3, 1)        # (batch, H, W, T_in)
        x = self.temporal_fc(x)          # (batch, H, W, T_out)
        x = x.permute(0, 3, 1, 2).unsqueeze(-1)  # (batch, T_out, H, W, 1)
        return x


# =============================================================================
# 4. 학습 루프 및 시각화
# =============================================================================
def train_model_3d(model, train_loader, test_loader, epochs=300):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)
    loss_fn = nn.MSELoss()
    train_losses = []
    test_losses = []
    
    for epoch in range(1, epochs+1):
        model.train()
        train_loss = 0.0
        for input_data, target in train_loader:
            # input_data: (batch, T_in, H, W, 4), target: (batch, T_out, H, W, 1)
            input_data = input_data.to(device)
            target = target.to(device)
            optimizer.zero_grad()
            output = model(input_data)
            loss = loss_fn(output, target)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * input_data.size(0)
        train_loss /= len(train_loader.dataset)
        train_losses.append(train_loss)
        
        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for input_data, target in test_loader:
                input_data = input_data.to(device)
                target = target.to(device)
                output = model(input_data)
                loss = loss_fn(output, target)
                test_loss += loss.item() * input_data.size(0)
        test_loss /= len(test_loader.dataset)
        test_losses.append(test_loss)
        #scheduler.step()
        if epoch % 1 == 0:
            print(f"Epoch {epoch:03d}: Train Loss = {train_loss:.6f}, Test Loss = {test_loss:.6f}")
    
    plt.figure(figsize=(8,6))
    plt.plot(train_losses, label="Train Loss")
    plt.plot(test_losses, label="Test Loss")
    plt.xlabel("Epoch")
    plt.ylabel("MSE Loss")
    plt.legend()
    plt.title("Training and Test Loss Curves (FNO3d)")
    plt.show()
    
    return train_losses, test_losses

def visualize_sample_3d(model, test_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    with torch.no_grad():
        input_data, target = next(iter(test_loader))
        input_data = input_data.to(device)
        pred = model(input_data)
    sample_target = target[0].cpu().numpy()  # (T_out, H, W, 1)
    sample_pred = pred[0].cpu().numpy()      # (T_out, H, W, 1)
    times = [15, 20, 25, 30]  # target 시간 라벨
    T_out = sample_target.shape[0]
    plt.figure(figsize=(16, 4*T_out))
    for i in range(T_out):
        plt.subplot(T_out, 2, 2*i+1)
        plt.title(f"Ground Truth at t = {times[i]}")
        plt.imshow(sample_target[i, :, :, 0], cmap="seismic", origin="lower")
        plt.colorbar()
        plt.subplot(T_out, 2, 2*i+2)
        plt.title(f"Prediction at t = {times[i]}")
        plt.imshow(sample_pred[i, :, :, 0], cmap="seismic", origin="lower")
        plt.colorbar()
    plt.tight_layout()
    plt.show()


# =============================================================================
# 5. 전체 파이프라인 실행
# =============================================================================
if __name__ == '__main__':
    # PDE simulation parameters
    N = 64         # spatial resolution: 64x64
    dt = 0.005     # 시간 스텝 (안정성을 위해 충분히 작게)
    t_final = 50   # 최종 시각
    nu = 1e-3      # 점성 계수 (예시)
    
    # 데이터셋에서 사용할 시간 구간
    T_in_range = (0, 10)          # 입력: t=0 ~ 10 (정수 시간 스냅샷)
    T_out_times = [20, 30, 40, 49] # 타겟: t = 15,20,25,30
    
    num_train = 100   # 시연을 위한 샘플 수 (실제 연구에서는 더 많은 샘플 사용)
    num_test = 20
    
    # Navier–Stokes PDE solver를 통해 데이터 생성
    dataset_solver_train = NavierStokesDatasetFromSolver(num_samples=num_train, N=N, dt=dt, t_final=t_final, nu=nu, 
                                                          T_in_range=T_in_range, T_out_times=T_out_times)
    dataset_solver_test  = NavierStokesDatasetFromSolver(num_samples=num_test, N=N, dt=dt, t_final=t_final, nu=nu, 
                                                          T_in_range=T_in_range, T_out_times=T_out_times)
    
    train_loader = DataLoader(dataset_solver_train, batch_size=2, shuffle=True)
    test_loader = DataLoader(dataset_solver_test, batch_size=2, shuffle=False)
    
    # 모델 하이퍼파라미터: Fourier 모드 수 선택 (시간: 4, x: 16, y: 16), width: 32, T_out: 4
    modes_t, modes_x, modes_y = 4, 16, 16
    width = 32
    T_out = len(T_out_times)
    T_in = 11
    model = FNO3d(modes_t, modes_x, modes_y, width, T_in, T_out)
    
    # 학습
    train_losses, test_losses = train_model_3d(model, train_loader, test_loader, epochs=500)
    
    # 결과 시각화
    visualize_sample_3d(model, test_loader)
# Out:
# Epoch 001: Train Loss = 1.174182, Test Loss = 1.225420
# Epoch 002: Train Loss = 1.156761, Test Loss = 1.205609
# Epoch 003: Train Loss = 1.126006, Test Loss = 1.138226
# Epoch 004: Train Loss = 1.023474, Test Loss = 0.920635
# Epoch 005: Train Loss = 0.744125, Test Loss = 0.484257
# Epoch 006: Train Loss = 0.481833, Test Loss = 0.378235
# Epoch 007: Train Loss = 0.377454, Test Loss = 0.308776
# Epoch 008: Train Loss = 0.319800, Test Loss = 0.261879
# Epoch 009: Train Loss = 0.280693, Test Loss = 0.216916
# Epoch 010: Train Loss = 0.251976, Test Loss = 0.198464
# Epoch 011: Train Loss = 0.228965, Test Loss = 0.186529
# Epoch 012: Train Loss = 0.218258, Test Loss = 0.179723
# Epoch 013: Train Loss = 0.207819, Test Loss = 0.178697
# Epoch 014: Train Loss = 0.202304, Test Loss = 0.178151
# Epoch 015: Train Loss = 0.197355, Test Loss = 0.172293
# Epoch 016: Train Loss = 0.196457, Test Loss = 0.179182
# Epoch 017: Train Loss = 0.181803, Test Loss = 0.170704
# Epoch 018: Train Loss = 0.173519, Test Loss = 0.167796
# Epoch 019: Train Loss = 0.161294, Test Loss = 0.180533
# Epoch 020: Train Loss = 0.152105, Test Loss = 0.158391
# Epoch 021: Train Loss = 0.135653, Test Loss = 0.150683
# Epoch 022: Train Loss = 0.123027, Test Loss = 0.159387
# Epoch 023: Train Loss = 0.112503, Test Loss = 0.144625
# Epoch 024: Train Loss = 0.098426, Test Loss = 0.137675
# Epoch 025: Train Loss = 0.090252, Test Loss = 0.139975
# Epoch 026: Train Loss = 0.076557, Test Loss = 0.132593
# Epoch 027: Train Loss = 0.064620, Test Loss = 0.122801
# Epoch 028: Train Loss = 0.059404, Test Loss = 0.114444
# Epoch 029: Train Loss = 0.052817, Test Loss = 0.126019
# Epoch 030: Train Loss = 0.047670, Test Loss = 0.105124
# Epoch 031: Train Loss = 0.042604, Test Loss = 0.102231
# Epoch 032: Train Loss = 0.038800, Test Loss = 0.115375
# Epoch 033: Train Loss = 0.033609, Test Loss = 0.093279
# Epoch 034: Train Loss = 0.033998, Test Loss = 0.103963
# Epoch 035: Train Loss = 0.028405, Test Loss = 0.091656
# Epoch 036: Train Loss = 0.023864, Test Loss = 0.093600
# Epoch 037: Train Loss = 0.019282, Test Loss = 0.102209
# Epoch 038: Train Loss = 0.015647, Test Loss = 0.095392
# Epoch 039: Train Loss = 0.011546, Test Loss = 0.096889
# Epoch 040: Train Loss = 0.009492, Test Loss = 0.097517
# Epoch 041: Train Loss = 0.007704, Test Loss = 0.097214
# Epoch 042: Train Loss = 0.006407, Test Loss = 0.101538
# Epoch 043: Train Loss = 0.005400, Test Loss = 0.098101
# Epoch 044: Train Loss = 0.004582, Test Loss = 0.102538
# Epoch 045: Train Loss = 0.003992, Test Loss = 0.101434
# Epoch 046: Train Loss = 0.003289, Test Loss = 0.101748
# Epoch 047: Train Loss = 0.002887, Test Loss = 0.104737
# Epoch 048: Train Loss = 0.002592, Test Loss = 0.101719
# Epoch 049: Train Loss = 0.002194, Test Loss = 0.104315
# Epoch 050: Train Loss = 0.001935, Test Loss = 0.102990
# Epoch 051: Train Loss = 0.001672, Test Loss = 0.103143
# Epoch 052: Train Loss = 0.001482, Test Loss = 0.103420
# Epoch 053: Train Loss = 0.001282, Test Loss = 0.104004
# Epoch 054: Train Loss = 0.001137, Test Loss = 0.103053
# Epoch 055: Train Loss = 0.001042, Test Loss = 0.104256
# Epoch 056: Train Loss = 0.000920, Test Loss = 0.104543
# Epoch 057: Train Loss = 0.000816, Test Loss = 0.103935
# Epoch 058: Train Loss = 0.000745, Test Loss = 0.104453
# Epoch 059: Train Loss = 0.000686, Test Loss = 0.104403
# Epoch 060: Train Loss = 0.000649, Test Loss = 0.104200
# Epoch 061: Train Loss = 0.000598, Test Loss = 0.104307
# Epoch 062: Train Loss = 0.000574, Test Loss = 0.104871
# Epoch 063: Train Loss = 0.000536, Test Loss = 0.104946
# Epoch 064: Train Loss = 0.000469, Test Loss = 0.104584
# Epoch 065: Train Loss = 0.000449, Test Loss = 0.104868
# Epoch 066: Train Loss = 0.000439, Test Loss = 0.105067
# Epoch 067: Train Loss = 0.000437, Test Loss = 0.104539
# Epoch 068: Train Loss = 0.000385, Test Loss = 0.105124
# Epoch 069: Train Loss = 0.000406, Test Loss = 0.104774
# Epoch 070: Train Loss = 0.000385, Test Loss = 0.104856
# Epoch 071: Train Loss = 0.000382, Test Loss = 0.104735
# Epoch 072: Train Loss = 0.000384, Test Loss = 0.105173
# Epoch 073: Train Loss = 0.000337, Test Loss = 0.104910
# Epoch 074: Train Loss = 0.000309, Test Loss = 0.105039
# Epoch 075: Train Loss = 0.000291, Test Loss = 0.104853
# Epoch 076: Train Loss = 0.000271, Test Loss = 0.105123
# Epoch 077: Train Loss = 0.000257, Test Loss = 0.104759
# Epoch 078: Train Loss = 0.000257, Test Loss = 0.105136
# Epoch 079: Train Loss = 0.000257, Test Loss = 0.105094
# Epoch 080: Train Loss = 0.000264, Test Loss = 0.104969
# Epoch 081: Train Loss = 0.000247, Test Loss = 0.104946
# Epoch 082: Train Loss = 0.000234, Test Loss = 0.105352
# Epoch 083: Train Loss = 0.000217, Test Loss = 0.104968
# Epoch 084: Train Loss = 0.000244, Test Loss = 0.105175
# Epoch 085: Train Loss = 0.000223, Test Loss = 0.105112
# Epoch 086: Train Loss = 0.000206, Test Loss = 0.105261
# Epoch 087: Train Loss = 0.000191, Test Loss = 0.105071
# Epoch 088: Train Loss = 0.000212, Test Loss = 0.105110
# Epoch 089: Train Loss = 0.000221, Test Loss = 0.105275
# Epoch 090: Train Loss = 0.000195, Test Loss = 0.105062
# Epoch 091: Train Loss = 0.000177, Test Loss = 0.105297
# Epoch 092: Train Loss = 0.000158, Test Loss = 0.105218
# Epoch 093: Train Loss = 0.000153, Test Loss = 0.105152
# Epoch 094: Train Loss = 0.000133, Test Loss = 0.105274
# Epoch 095: Train Loss = 0.000132, Test Loss = 0.105143
# Epoch 096: Train Loss = 0.000134, Test Loss = 0.105293
# Epoch 097: Train Loss = 0.000127, Test Loss = 0.105294
# Epoch 098: Train Loss = 0.000126, Test Loss = 0.105299
# Epoch 099: Train Loss = 0.000122, Test Loss = 0.105267
# Epoch 100: Train Loss = 0.000130, Test Loss = 0.105327
# Epoch 101: Train Loss = 0.000135, Test Loss = 0.105511
# Epoch 102: Train Loss = 0.000142, Test Loss = 0.105375
# Epoch 103: Train Loss = 0.000135, Test Loss = 0.105155
# Epoch 104: Train Loss = 0.000145, Test Loss = 0.105290
# Epoch 105: Train Loss = 0.000142, Test Loss = 0.105293
# Epoch 106: Train Loss = 0.000151, Test Loss = 0.105190
# Epoch 107: Train Loss = 0.000136, Test Loss = 0.105260
# Epoch 108: Train Loss = 0.000148, Test Loss = 0.105231
# Epoch 109: Train Loss = 0.000149, Test Loss = 0.105397
# Epoch 110: Train Loss = 0.000194, Test Loss = 0.105193
# Epoch 111: Train Loss = 0.000212, Test Loss = 0.105070
# Epoch 112: Train Loss = 0.000214, Test Loss = 0.105621
# Epoch 113: Train Loss = 0.000230, Test Loss = 0.105301
# Epoch 114: Train Loss = 0.000433, Test Loss = 0.105222
# Epoch 115: Train Loss = 0.000526, Test Loss = 0.105158
# Epoch 116: Train Loss = 0.000190, Test Loss = 0.105615
# Epoch 117: Train Loss = 0.000296, Test Loss = 0.105142
# Epoch 118: Train Loss = 0.000281, Test Loss = 0.105173
# Epoch 119: Train Loss = 0.000212, Test Loss = 0.105557
# Epoch 120: Train Loss = 0.000233, Test Loss = 0.105084
# Epoch 121: Train Loss = 0.000221, Test Loss = 0.104966
# Epoch 122: Train Loss = 0.000212, Test Loss = 0.105109
# Epoch 123: Train Loss = 0.000203, Test Loss = 0.104773
# Epoch 124: Train Loss = 0.000198, Test Loss = 0.104808
# Epoch 125: Train Loss = 0.000217, Test Loss = 0.104954
# Epoch 126: Train Loss = 0.000194, Test Loss = 0.104750
# Epoch 127: Train Loss = 0.000183, Test Loss = 0.104596
# Epoch 128: Train Loss = 0.000159, Test Loss = 0.104537
# Epoch 129: Train Loss = 0.000128, Test Loss = 0.104536
# Epoch 130: Train Loss = 0.000108, Test Loss = 0.104646
# Epoch 131: Train Loss = 0.000126, Test Loss = 0.104670
# Epoch 132: Train Loss = 0.000109, Test Loss = 0.104665
# Epoch 133: Train Loss = 0.000099, Test Loss = 0.104576
# Epoch 134: Train Loss = 0.000107, Test Loss = 0.104235
# Epoch 135: Train Loss = 0.000120, Test Loss = 0.104616
# Epoch 136: Train Loss = 0.000130, Test Loss = 0.104687
# Epoch 137: Train Loss = 0.000140, Test Loss = 0.104469
# Epoch 138: Train Loss = 0.000147, Test Loss = 0.104467
# Epoch 139: Train Loss = 0.000160, Test Loss = 0.104487
# Epoch 140: Train Loss = 0.000141, Test Loss = 0.104200
# Epoch 141: Train Loss = 0.000124, Test Loss = 0.104364
# Epoch 142: Train Loss = 0.000118, Test Loss = 0.104457
# Epoch 143: Train Loss = 0.000129, Test Loss = 0.104525
# Epoch 144: Train Loss = 0.000113, Test Loss = 0.104409
# Epoch 145: Train Loss = 0.000102, Test Loss = 0.104560
# Epoch 146: Train Loss = 0.000098, Test Loss = 0.104289
# Epoch 147: Train Loss = 0.000103, Test Loss = 0.104105
# Epoch 148: Train Loss = 0.000086, Test Loss = 0.104121
# Epoch 149: Train Loss = 0.000081, Test Loss = 0.104076
# Epoch 150: Train Loss = 0.000084, Test Loss = 0.104048
# Epoch 151: Train Loss = 0.000073, Test Loss = 0.103955
# Epoch 152: Train Loss = 0.000083, Test Loss = 0.103917
# Epoch 153: Train Loss = 0.000068, Test Loss = 0.103988
# Epoch 154: Train Loss = 0.000066, Test Loss = 0.103991
# Epoch 155: Train Loss = 0.000067, Test Loss = 0.104046
# Epoch 156: Train Loss = 0.000064, Test Loss = 0.103903
# Epoch 157: Train Loss = 0.000069, Test Loss = 0.103922
# Epoch 158: Train Loss = 0.000079, Test Loss = 0.103785
# Epoch 159: Train Loss = 0.000081, Test Loss = 0.103820
# Epoch 160: Train Loss = 0.000080, Test Loss = 0.103658
# Epoch 161: Train Loss = 0.000084, Test Loss = 0.103771
# Epoch 162: Train Loss = 0.000092, Test Loss = 0.103689
# Epoch 163: Train Loss = 0.000084, Test Loss = 0.103686
# Epoch 164: Train Loss = 0.000071, Test Loss = 0.103595
# Epoch 165: Train Loss = 0.000078, Test Loss = 0.103555
# Epoch 166: Train Loss = 0.000082, Test Loss = 0.103658
# Epoch 167: Train Loss = 0.000074, Test Loss = 0.103732
# Epoch 168: Train Loss = 0.000088, Test Loss = 0.103801
# Epoch 169: Train Loss = 0.000099, Test Loss = 0.103790
# Epoch 170: Train Loss = 0.000139, Test Loss = 0.103754
# Epoch 171: Train Loss = 0.000173, Test Loss = 0.103706
# Epoch 172: Train Loss = 0.000193, Test Loss = 0.103685
# Epoch 173: Train Loss = 0.000141, Test Loss = 0.103671
# Epoch 174: Train Loss = 0.000116, Test Loss = 0.103584
# Epoch 175: Train Loss = 0.000143, Test Loss = 0.104250
# Epoch 176: Train Loss = 0.000142, Test Loss = 0.103820
# Epoch 177: Train Loss = 0.000121, Test Loss = 0.103923
# Epoch 178: Train Loss = 0.000100, Test Loss = 0.103771
# Epoch 179: Train Loss = 0.000088, Test Loss = 0.103729
# Epoch 180: Train Loss = 0.000090, Test Loss = 0.103865
# Epoch 181: Train Loss = 0.000088, Test Loss = 0.103842
# Epoch 182: Train Loss = 0.000109, Test Loss = 0.103859
# Epoch 183: Train Loss = 0.000106, Test Loss = 0.103803
# Epoch 184: Train Loss = 0.000082, Test Loss = 0.103591
# Epoch 185: Train Loss = 0.000077, Test Loss = 0.103907
# Epoch 186: Train Loss = 0.000074, Test Loss = 0.103870
# Epoch 187: Train Loss = 0.000066, Test Loss = 0.103862
# Epoch 188: Train Loss = 0.000049, Test Loss = 0.103775
# Epoch 189: Train Loss = 0.000046, Test Loss = 0.103752
# Epoch 190: Train Loss = 0.000056, Test Loss = 0.103905
# Epoch 191: Train Loss = 0.000053, Test Loss = 0.103806
# Epoch 192: Train Loss = 0.000064, Test Loss = 0.103739
# Epoch 193: Train Loss = 0.000059, Test Loss = 0.103905
# Epoch 194: Train Loss = 0.000077, Test Loss = 0.103814
# Epoch 195: Train Loss = 0.000071, Test Loss = 0.103855
# Epoch 196: Train Loss = 0.000080, Test Loss = 0.103864
# Epoch 197: Train Loss = 0.000081, Test Loss = 0.103746
# Epoch 198: Train Loss = 0.000086, Test Loss = 0.103788
# Epoch 199: Train Loss = 0.000081, Test Loss = 0.103777
# Epoch 200: Train Loss = 0.000077, Test Loss = 0.103884
# Epoch 201: Train Loss = 0.000078, Test Loss = 0.103906
# Epoch 202: Train Loss = 0.000094, Test Loss = 0.103651
# Epoch 203: Train Loss = 0.000098, Test Loss = 0.103830
# Epoch 204: Train Loss = 0.000110, Test Loss = 0.103775
# Epoch 205: Train Loss = 0.000107, Test Loss = 0.103808
# Epoch 206: Train Loss = 0.000082, Test Loss = 0.103814
# Epoch 207: Train Loss = 0.000074, Test Loss = 0.103797
# Epoch 208: Train Loss = 0.000065, Test Loss = 0.103854
# Epoch 209: Train Loss = 0.000072, Test Loss = 0.103839
# Epoch 210: Train Loss = 0.000062, Test Loss = 0.103823
# Epoch 211: Train Loss = 0.000067, Test Loss = 0.103903
# Epoch 212: Train Loss = 0.000070, Test Loss = 0.103726
# Epoch 213: Train Loss = 0.000060, Test Loss = 0.103940
# Epoch 214: Train Loss = 0.000061, Test Loss = 0.103646
# Epoch 215: Train Loss = 0.000058, Test Loss = 0.103980
# Epoch 216: Train Loss = 0.000060, Test Loss = 0.103645
# Epoch 217: Train Loss = 0.000057, Test Loss = 0.103780
# Epoch 218: Train Loss = 0.000058, Test Loss = 0.103814
# Epoch 219: Train Loss = 0.000068, Test Loss = 0.103925
# Epoch 220: Train Loss = 0.000083, Test Loss = 0.103667
# Epoch 221: Train Loss = 0.000071, Test Loss = 0.103890
# Epoch 222: Train Loss = 0.000053, Test Loss = 0.103677
# Epoch 223: Train Loss = 0.000048, Test Loss = 0.103731
# Epoch 224: Train Loss = 0.000046, Test Loss = 0.103928
# Epoch 225: Train Loss = 0.000046, Test Loss = 0.103916
# Epoch 226: Train Loss = 0.000054, Test Loss = 0.103870
# Epoch 227: Train Loss = 0.000090, Test Loss = 0.103879
# Epoch 228: Train Loss = 0.000084, Test Loss = 0.103844
# Epoch 229: Train Loss = 0.000053, Test Loss = 0.103885
# Epoch 230: Train Loss = 0.000078, Test Loss = 0.103814
# Epoch 231: Train Loss = 0.000097, Test Loss = 0.103887
# Epoch 232: Train Loss = 0.000120, Test Loss = 0.103915
# Epoch 233: Train Loss = 0.000194, Test Loss = 0.103980
# Epoch 234: Train Loss = 0.000227, Test Loss = 0.103506
# Epoch 235: Train Loss = 0.000249, Test Loss = 0.103599
# Epoch 236: Train Loss = 0.000239, Test Loss = 0.103394
# Epoch 237: Train Loss = 0.000340, Test Loss = 0.103623
# Epoch 238: Train Loss = 0.000583, Test Loss = 0.103367
# Epoch 239: Train Loss = 0.000545, Test Loss = 0.103179
# Epoch 240: Train Loss = 0.000406, Test Loss = 0.103326
# Epoch 241: Train Loss = 0.000512, Test Loss = 0.103859
# Epoch 242: Train Loss = 0.000965, Test Loss = 0.103725
# Epoch 243: Train Loss = 0.001009, Test Loss = 0.104333
# Epoch 244: Train Loss = 0.000409, Test Loss = 0.102212
# Epoch 245: Train Loss = 0.000905, Test Loss = 0.103628
# Epoch 246: Train Loss = 0.000579, Test Loss = 0.104121
# Epoch 247: Train Loss = 0.000603, Test Loss = 0.102900
# Epoch 248: Train Loss = 0.000967, Test Loss = 0.103553
# Epoch 249: Train Loss = 0.000428, Test Loss = 0.102095
# Epoch 250: Train Loss = 0.001012, Test Loss = 0.102254
# Epoch 251: Train Loss = 0.000734, Test Loss = 0.101829
# Epoch 252: Train Loss = 0.000664, Test Loss = 0.102024
# Epoch 253: Train Loss = 0.000563, Test Loss = 0.104603
# Epoch 254: Train Loss = 0.000382, Test Loss = 0.103471
# Epoch 255: Train Loss = 0.000303, Test Loss = 0.103570
# Epoch 256: Train Loss = 0.000240, Test Loss = 0.102792
# Epoch 257: Train Loss = 0.000220, Test Loss = 0.102865
# Epoch 258: Train Loss = 0.000215, Test Loss = 0.102409
# Epoch 259: Train Loss = 0.000168, Test Loss = 0.102128
# Epoch 260: Train Loss = 0.000162, Test Loss = 0.102307
# Epoch 261: Train Loss = 0.000140, Test Loss = 0.102261
# Epoch 262: Train Loss = 0.000097, Test Loss = 0.102936
# Epoch 263: Train Loss = 0.000090, Test Loss = 0.102354
# Epoch 264: Train Loss = 0.000077, Test Loss = 0.102773
# Epoch 265: Train Loss = 0.000055, Test Loss = 0.102682
# Epoch 266: Train Loss = 0.000066, Test Loss = 0.102703
# Epoch 267: Train Loss = 0.000058, Test Loss = 0.102527
# Epoch 268: Train Loss = 0.000052, Test Loss = 0.102656
# Epoch 269: Train Loss = 0.000041, Test Loss = 0.102700
# Epoch 270: Train Loss = 0.000037, Test Loss = 0.102725
# Epoch 271: Train Loss = 0.000035, Test Loss = 0.102746
# Epoch 272: Train Loss = 0.000037, Test Loss = 0.102317
# Epoch 273: Train Loss = 0.000035, Test Loss = 0.102647
# Epoch 274: Train Loss = 0.000031, Test Loss = 0.102684
# Epoch 275: Train Loss = 0.000030, Test Loss = 0.102684
# Epoch 276: Train Loss = 0.000029, Test Loss = 0.102520
# Epoch 277: Train Loss = 0.000030, Test Loss = 0.102854
# Epoch 278: Train Loss = 0.000027, Test Loss = 0.102724
# Epoch 279: Train Loss = 0.000029, Test Loss = 0.102680
# Epoch 280: Train Loss = 0.000026, Test Loss = 0.102748
# Epoch 281: Train Loss = 0.000027, Test Loss = 0.102520
# Epoch 282: Train Loss = 0.000023, Test Loss = 0.102601
# Epoch 283: Train Loss = 0.000022, Test Loss = 0.102541
# Epoch 284: Train Loss = 0.000023, Test Loss = 0.102574
# Epoch 285: Train Loss = 0.000025, Test Loss = 0.102625
# Epoch 286: Train Loss = 0.000025, Test Loss = 0.102547
# Epoch 287: Train Loss = 0.000025, Test Loss = 0.102518
# Epoch 288: Train Loss = 0.000029, Test Loss = 0.102633
# Epoch 289: Train Loss = 0.000031, Test Loss = 0.102788
# Epoch 290: Train Loss = 0.000027, Test Loss = 0.102569
# Epoch 291: Train Loss = 0.000029, Test Loss = 0.102474
# Epoch 292: Train Loss = 0.000030, Test Loss = 0.102491
# Epoch 293: Train Loss = 0.000032, Test Loss = 0.102556
# Epoch 294: Train Loss = 0.000037, Test Loss = 0.102681
# Epoch 295: Train Loss = 0.000044, Test Loss = 0.102591
# Epoch 296: Train Loss = 0.000058, Test Loss = 0.102520
# Epoch 297: Train Loss = 0.000071, Test Loss = 0.102417
# Epoch 298: Train Loss = 0.000055, Test Loss = 0.102522
# Epoch 299: Train Loss = 0.000043, Test Loss = 0.102372
# Epoch 300: Train Loss = 0.000038, Test Loss = 0.102383
# Epoch 301: Train Loss = 0.000045, Test Loss = 0.102563
# Epoch 302: Train Loss = 0.000036, Test Loss = 0.102346
# Epoch 303: Train Loss = 0.000037, Test Loss = 0.102442
# Epoch 304: Train Loss = 0.000040, Test Loss = 0.102443
# Epoch 305: Train Loss = 0.000035, Test Loss = 0.102354
# Epoch 306: Train Loss = 0.000039, Test Loss = 0.102537
# Epoch 307: Train Loss = 0.000031, Test Loss = 0.102416
# Epoch 308: Train Loss = 0.000030, Test Loss = 0.102522
# Epoch 309: Train Loss = 0.000029, Test Loss = 0.102425
# Epoch 310: Train Loss = 0.000029, Test Loss = 0.102360
# Epoch 311: Train Loss = 0.000032, Test Loss = 0.102424
# Epoch 312: Train Loss = 0.000025, Test Loss = 0.102317
# Epoch 313: Train Loss = 0.000023, Test Loss = 0.102431
# Epoch 314: Train Loss = 0.000022, Test Loss = 0.102641
# Epoch 315: Train Loss = 0.000022, Test Loss = 0.102636
# Epoch 316: Train Loss = 0.000021, Test Loss = 0.102527
# Epoch 317: Train Loss = 0.000021, Test Loss = 0.102494
# Epoch 318: Train Loss = 0.000022, Test Loss = 0.102352
# Epoch 319: Train Loss = 0.000020, Test Loss = 0.102472
# Epoch 320: Train Loss = 0.000022, Test Loss = 0.102545
# Epoch 321: Train Loss = 0.000024, Test Loss = 0.102495
# Epoch 322: Train Loss = 0.000023, Test Loss = 0.102410
# Epoch 323: Train Loss = 0.000023, Test Loss = 0.102192
# Epoch 324: Train Loss = 0.000023, Test Loss = 0.102122
# Epoch 325: Train Loss = 0.000020, Test Loss = 0.102389
# Epoch 326: Train Loss = 0.000019, Test Loss = 0.102487
# Epoch 327: Train Loss = 0.000021, Test Loss = 0.102331
# Epoch 328: Train Loss = 0.000021, Test Loss = 0.102678
# Epoch 329: Train Loss = 0.000020, Test Loss = 0.102326
# Epoch 330: Train Loss = 0.000022, Test Loss = 0.102384
# Epoch 331: Train Loss = 0.000024, Test Loss = 0.102381
# Epoch 332: Train Loss = 0.000022, Test Loss = 0.102651
# Epoch 333: Train Loss = 0.000020, Test Loss = 0.102425
# Epoch 334: Train Loss = 0.000019, Test Loss = 0.102382
# Epoch 335: Train Loss = 0.000021, Test Loss = 0.102274
# Epoch 336: Train Loss = 0.000021, Test Loss = 0.102443
# Epoch 337: Train Loss = 0.000020, Test Loss = 0.102786
# Epoch 338: Train Loss = 0.000020, Test Loss = 0.102691
# Epoch 339: Train Loss = 0.000021, Test Loss = 0.102498
# Epoch 340: Train Loss = 0.000024, Test Loss = 0.102208
# Epoch 341: Train Loss = 0.000025, Test Loss = 0.102333
# Epoch 342: Train Loss = 0.000024, Test Loss = 0.102522
# Epoch 343: Train Loss = 0.000046, Test Loss = 0.103134
# Epoch 344: Train Loss = 0.000056, Test Loss = 0.102131
# Epoch 345: Train Loss = 0.000047, Test Loss = 0.102762
# Epoch 346: Train Loss = 0.000068, Test Loss = 0.101962
# Epoch 347: Train Loss = 0.000089, Test Loss = 0.102323
# Epoch 348: Train Loss = 0.000082, Test Loss = 0.102196
# Epoch 349: Train Loss = 0.000093, Test Loss = 0.102969
# Epoch 350: Train Loss = 0.000112, Test Loss = 0.102206
# Epoch 351: Train Loss = 0.000134, Test Loss = 0.103954
# Epoch 352: Train Loss = 0.000162, Test Loss = 0.102561
# Epoch 353: Train Loss = 0.000165, Test Loss = 0.101840
# Epoch 354: Train Loss = 0.000173, Test Loss = 0.103793
# Epoch 355: Train Loss = 0.000205, Test Loss = 0.103647
# Epoch 356: Train Loss = 0.000274, Test Loss = 0.103152
# Epoch 357: Train Loss = 0.000271, Test Loss = 0.102802
# Epoch 358: Train Loss = 0.000312, Test Loss = 0.102928
# Epoch 359: Train Loss = 0.000433, Test Loss = 0.101273
# Epoch 360: Train Loss = 0.000361, Test Loss = 0.102604
# Epoch 361: Train Loss = 0.000326, Test Loss = 0.101194
# Epoch 362: Train Loss = 0.000322, Test Loss = 0.104961
# Epoch 363: Train Loss = 0.000574, Test Loss = 0.102999
# Epoch 364: Train Loss = 0.000923, Test Loss = 0.102545
# Epoch 365: Train Loss = 0.000939, Test Loss = 0.105319
# Epoch 366: Train Loss = 0.001148, Test Loss = 0.100127
# Epoch 367: Train Loss = 0.001398, Test Loss = 0.103313
# Epoch 368: Train Loss = 0.002013, Test Loss = 0.102438
# Epoch 369: Train Loss = 0.001603, Test Loss = 0.108532
# Epoch 370: Train Loss = 0.001822, Test Loss = 0.103465
# Epoch 371: Train Loss = 0.001540, Test Loss = 0.101905
# Epoch 372: Train Loss = 0.001150, Test Loss = 0.102979
# Epoch 373: Train Loss = 0.000926, Test Loss = 0.102947
# Epoch 374: Train Loss = 0.000677, Test Loss = 0.105380
# Epoch 375: Train Loss = 0.000961, Test Loss = 0.105024
# Epoch 376: Train Loss = 0.000649, Test Loss = 0.104188
# Epoch 377: Train Loss = 0.000537, Test Loss = 0.101403
# Epoch 378: Train Loss = 0.000542, Test Loss = 0.102144
# Epoch 379: Train Loss = 0.000508, Test Loss = 0.101494
# Epoch 380: Train Loss = 0.000409, Test Loss = 0.103898
# Epoch 381: Train Loss = 0.000362, Test Loss = 0.102564
# Epoch 382: Train Loss = 0.000270, Test Loss = 0.103444
# Epoch 383: Train Loss = 0.000215, Test Loss = 0.103373
# Epoch 384: Train Loss = 0.000185, Test Loss = 0.102408
# Epoch 385: Train Loss = 0.000178, Test Loss = 0.103550
# Epoch 386: Train Loss = 0.000166, Test Loss = 0.103414
# Epoch 387: Train Loss = 0.000124, Test Loss = 0.102069
# Epoch 388: Train Loss = 0.000142, Test Loss = 0.102684
# Epoch 389: Train Loss = 0.000149, Test Loss = 0.103250
# Epoch 390: Train Loss = 0.000128, Test Loss = 0.101929
# Epoch 391: Train Loss = 0.000107, Test Loss = 0.101854
# Epoch 392: Train Loss = 0.000088, Test Loss = 0.102823
# Epoch 393: Train Loss = 0.000062, Test Loss = 0.103118
# Epoch 394: Train Loss = 0.000051, Test Loss = 0.102987
# Epoch 395: Train Loss = 0.000049, Test Loss = 0.103028
# Epoch 396: Train Loss = 0.000044, Test Loss = 0.102258
# Epoch 397: Train Loss = 0.000040, Test Loss = 0.101768
# Epoch 398: Train Loss = 0.000048, Test Loss = 0.103117
# Epoch 399: Train Loss = 0.000036, Test Loss = 0.103258
# Epoch 400: Train Loss = 0.000038, Test Loss = 0.102764
# Epoch 401: Train Loss = 0.000038, Test Loss = 0.103171
# Epoch 402: Train Loss = 0.000034, Test Loss = 0.102816
# Epoch 403: Train Loss = 0.000029, Test Loss = 0.102814
# Epoch 404: Train Loss = 0.000026, Test Loss = 0.103007
# Epoch 405: Train Loss = 0.000026, Test Loss = 0.102985
# Epoch 406: Train Loss = 0.000026, Test Loss = 0.102863
# Epoch 407: Train Loss = 0.000030, Test Loss = 0.102812
# Epoch 408: Train Loss = 0.000030, Test Loss = 0.102264
# Epoch 409: Train Loss = 0.000029, Test Loss = 0.102489
# Epoch 410: Train Loss = 0.000022, Test Loss = 0.102953
# Epoch 411: Train Loss = 0.000050, Test Loss = 0.103036
# Epoch 412: Train Loss = 0.000050, Test Loss = 0.103182
# Epoch 413: Train Loss = 0.000043, Test Loss = 0.103023
# Epoch 414: Train Loss = 0.000046, Test Loss = 0.103151
# Epoch 415: Train Loss = 0.000045, Test Loss = 0.102644
# Epoch 416: Train Loss = 0.000050, Test Loss = 0.102409
# Epoch 417: Train Loss = 0.000042, Test Loss = 0.103117
# Epoch 418: Train Loss = 0.000061, Test Loss = 0.102631
# Epoch 419: Train Loss = 0.000080, Test Loss = 0.101515
# Epoch 420: Train Loss = 0.000106, Test Loss = 0.102515
# Epoch 421: Train Loss = 0.000182, Test Loss = 0.106075
# Epoch 422: Train Loss = 0.000659, Test Loss = 0.103121
# Epoch 423: Train Loss = 0.000410, Test Loss = 0.101300
# Epoch 424: Train Loss = 0.000202, Test Loss = 0.101678
# Epoch 425: Train Loss = 0.000304, Test Loss = 0.103285
# Epoch 426: Train Loss = 0.000205, Test Loss = 0.103363
# Epoch 427: Train Loss = 0.000552, Test Loss = 0.101637
# Epoch 428: Train Loss = 0.000335, Test Loss = 0.102353
# Epoch 429: Train Loss = 0.000197, Test Loss = 0.102580
# Epoch 430: Train Loss = 0.000239, Test Loss = 0.103941
# Epoch 431: Train Loss = 0.000216, Test Loss = 0.102785
# Epoch 432: Train Loss = 0.000169, Test Loss = 0.103123
# Epoch 433: Train Loss = 0.000241, Test Loss = 0.105551
# Epoch 434: Train Loss = 0.000284, Test Loss = 0.101544
# Epoch 435: Train Loss = 0.000281, Test Loss = 0.102455
# Epoch 436: Train Loss = 0.000286, Test Loss = 0.103421
# Epoch 437: Train Loss = 0.000305, Test Loss = 0.103207
# Epoch 438: Train Loss = 0.000175, Test Loss = 0.102018
# Epoch 439: Train Loss = 0.000221, Test Loss = 0.102052
# Epoch 440: Train Loss = 0.000174, Test Loss = 0.102695
# Epoch 441: Train Loss = 0.000193, Test Loss = 0.101664
# Epoch 442: Train Loss = 0.000206, Test Loss = 0.101807
# Epoch 443: Train Loss = 0.000160, Test Loss = 0.103347
# Epoch 444: Train Loss = 0.000208, Test Loss = 0.102546
# Epoch 445: Train Loss = 0.000214, Test Loss = 0.101700
# Epoch 446: Train Loss = 0.000188, Test Loss = 0.102524
# Epoch 447: Train Loss = 0.000169, Test Loss = 0.103674
# Epoch 448: Train Loss = 0.000240, Test Loss = 0.103179
# Epoch 449: Train Loss = 0.000177, Test Loss = 0.102441
# Epoch 450: Train Loss = 0.000188, Test Loss = 0.102197
# Epoch 451: Train Loss = 0.000160, Test Loss = 0.102874
# Epoch 452: Train Loss = 0.000165, Test Loss = 0.103089
# Epoch 453: Train Loss = 0.000132, Test Loss = 0.103139
# Epoch 454: Train Loss = 0.000145, Test Loss = 0.101334
# Epoch 455: Train Loss = 0.000146, Test Loss = 0.102246
# Epoch 456: Train Loss = 0.000131, Test Loss = 0.102927
# Epoch 457: Train Loss = 0.000127, Test Loss = 0.101406
# Epoch 458: Train Loss = 0.000194, Test Loss = 0.102831
# Epoch 459: Train Loss = 0.000163, Test Loss = 0.102656
# Epoch 460: Train Loss = 0.000125, Test Loss = 0.102427
# Epoch 461: Train Loss = 0.000104, Test Loss = 0.102454
# Epoch 462: Train Loss = 0.000110, Test Loss = 0.102192
# Epoch 463: Train Loss = 0.000094, Test Loss = 0.102456
# Epoch 464: Train Loss = 0.000152, Test Loss = 0.103859
# Epoch 465: Train Loss = 0.000243, Test Loss = 0.102292
# Epoch 466: Train Loss = 0.000309, Test Loss = 0.102118
# Epoch 467: Train Loss = 0.000330, Test Loss = 0.104975
# Epoch 468: Train Loss = 0.000306, Test Loss = 0.101349
# Epoch 469: Train Loss = 0.000285, Test Loss = 0.102700
# Epoch 470: Train Loss = 0.000254, Test Loss = 0.103284
# Epoch 471: Train Loss = 0.000406, Test Loss = 0.100971
# Epoch 472: Train Loss = 0.000496, Test Loss = 0.104075
# Epoch 473: Train Loss = 0.000511, Test Loss = 0.102895
# Epoch 474: Train Loss = 0.000569, Test Loss = 0.102954
# Epoch 475: Train Loss = 0.000642, Test Loss = 0.102249
# Epoch 476: Train Loss = 0.000891, Test Loss = 0.102343
# Epoch 477: Train Loss = 0.000710, Test Loss = 0.103639
# Epoch 478: Train Loss = 0.000770, Test Loss = 0.102839
# Epoch 479: Train Loss = 0.000602, Test Loss = 0.103168
# Epoch 480: Train Loss = 0.000725, Test Loss = 0.103725
# Epoch 481: Train Loss = 0.000703, Test Loss = 0.103570
# Epoch 482: Train Loss = 0.000475, Test Loss = 0.102890
# Epoch 483: Train Loss = 0.000815, Test Loss = 0.102881
# Epoch 484: Train Loss = 0.000634, Test Loss = 0.101349
# Epoch 485: Train Loss = 0.000858, Test Loss = 0.102101
# Epoch 486: Train Loss = 0.000825, Test Loss = 0.103323
# Epoch 487: Train Loss = 0.000656, Test Loss = 0.103972
# Epoch 488: Train Loss = 0.000923, Test Loss = 0.105488
# Epoch 489: Train Loss = 0.000843, Test Loss = 0.103743
# Epoch 490: Train Loss = 0.001085, Test Loss = 0.102856
# Epoch 491: Train Loss = 0.001083, Test Loss = 0.103682
# Epoch 492: Train Loss = 0.000593, Test Loss = 0.104267
# Epoch 493: Train Loss = 0.000783, Test Loss = 0.100028
# Epoch 494: Train Loss = 0.000679, Test Loss = 0.105187
# Epoch 495: Train Loss = 0.000674, Test Loss = 0.107119
# Epoch 496: Train Loss = 0.000488, Test Loss = 0.101236
# Epoch 497: Train Loss = 0.000434, Test Loss = 0.105051
# Epoch 498: Train Loss = 0.000432, Test Loss = 0.104708
# Epoch 499: Train Loss = 0.000477, Test Loss = 0.102341
# Epoch 500: Train Loss = 0.000584, Test Loss = 0.103447

# %%
def visualize_sample_3d(model, test_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    with torch.no_grad():
        input_data, target = next(iter(test_loader))
        input_data = input_data.to(device)
        pred = model(input_data)
    sample_target = target[0].cpu().numpy()  # (T_out, H, W, 1)
    sample_pred = pred[0].cpu().numpy()      # (T_out, H, W, 1)
    times = [15, 20, 25, 30]  # target 시간 라벨
    T_out = sample_target.shape[0]
    plt.figure(figsize=(16, 4*T_out))
    for i in range(T_out):
        plt.subplot(T_out, 2, 2*i+1)
        plt.title(f"Ground Truth at t = {times[i]}")
        plt.imshow(sample_target[i, :, :, 0], cmap="seismic", origin="lower")
        plt.colorbar()
        plt.subplot(T_out, 2, 2*i+2)
        plt.title(f"Prediction at t = {times[i]}")
        plt.imshow(sample_pred[i, :, :, 0], cmap="seismic", origin="lower")
        plt.colorbar()
    plt.tight_layout()
    plt.show()


# 결과 시각화
visualize_sample_3d(model, test_loader)

# %%
plt.figure(figsize=(8,6))
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.yscale('log')
plt.legend()
plt.title("Training and Test Loss Curves (FNO3d) [Log Scale]")
plt.show()

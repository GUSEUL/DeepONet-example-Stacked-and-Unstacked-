# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt


# =============================================================================
# 1. Navier–Stokes PDE solver (pseudo-spectral method)
# =============================================================================
def solve_navier_stokes(w0, nu, dt, t_final, N):
    """
    2D Navier–Stokes vorticity PDE (주기적 경계조건) 를 푸는 간단한 pseudo-spectral solver.
    
    PDE:
        ∂ₜw + u · ∇w = ν ∆w + f(x)
        u = (ψ_y, -ψ_x),   and   ∆ψ = -w,  with periodic boundary conditions.
    입력:
        w0: 초기 vorticity, shape (N, N)
        nu: 점성 계수
        dt: 시간 스텝
        t_final: 최종 시간
        N: 격자 크기 (N×N)
    출력:
        snapshots: 정수 시간마다 (t, w) 튜플 리스트.
    """
    # 공간 좌표 생성 (0 ≤ x,y < 1)
    x = np.linspace(0, 1, N, endpoint=False)
    y = np.linspace(0, 1, N, endpoint=False)
    xv, yv = np.meshgrid(x, y, indexing='ij')
    
    # forcing function: f(x) = 0.1*( sin(2π(x+y)) + cos(2π(x+y)) )
    f = 0.1 * (np.sin(2*np.pi*(xv + yv)) + np.cos(2*np.pi*(xv + yv)))
    
    # FFT frequencies (주기적 도메인: [0,1])
    kx = np.fft.fftfreq(N, d=1.0/N) * 2*np.pi
    ky = np.fft.fftfreq(N, d=1.0/N) * 2*np.pi
    kx, ky = np.meshgrid(kx, ky, indexing='ij')
    ksq = kx**2 + ky**2
    ksq[0,0] = 1.0  # 0분할 방지
    
    w = w0.copy()
    snapshots = []
    snapshot_times = np.arange(0, t_final+dt, 1.0)  # 정수 시간마다 기록
    next_snapshot_index = 0
    
    nsteps = int(t_final/dt)
    for step in range(nsteps):
        t = step * dt
        # 스냅샷 기록
        if next_snapshot_index < len(snapshot_times) and t >= snapshot_times[next_snapshot_index]:
            snapshots.append((t, w.copy()))
            next_snapshot_index += 1
        
        # vorticity의 FFT
        w_hat = np.fft.fft2(w)
        # stream function: ∆ψ = -w  ->  ψ_hat = -w_hat / ksq, ψ_hat(0)=0
        psi_hat = -w_hat / ksq
        psi_hat[0,0] = 0.0
        psi = np.real(np.fft.ifft2(psi_hat))
        
        # 속도 계산: u = ψ_y, v = -ψ_x (spectral differentiation)
        u = np.real(np.fft.ifft2(1j * ky * psi_hat))
        v = -np.real(np.fft.ifft2(1j * kx * psi_hat))
        
        # vorticity gradient (spectral differentiation)
        w_x = np.real(np.fft.ifft2(1j * kx * w_hat))
        w_y = np.real(np.fft.ifft2(1j * ky * w_hat))
        
        # 비선형 항: u * w_x + v * w_y
        nonlinear = u * w_x + v * w_y
        
        # Laplacian: ∆w = ifft2(-ksq * w_hat)
        lap_w = np.real(np.fft.ifft2(-ksq * w_hat))
        
        # Euler explicit time stepping
        w = w + dt * (-nonlinear + nu * lap_w + f)
    
    return snapshots

    
# =============================================================================
# 2. Navier-Stokes 데이터셋 (PDE solver를 사용하여 데이터 생성)
# =============================================================================
class NavierStokesDatasetFromSolver(Dataset):
    def __init__(self, num_samples, N, dt, t_final, nu, T_in_range, T_out_times):
        """
        num_samples: 샘플 개수.
        N: 공간 격자 크기 (N×N).
        dt: 시간 스텝.
        t_final: 최종 시각 (예, 30).
        nu: 점성 계수.
        T_in_range: 입력 시간 구간 (예: (0, 10)).
        T_out_times: 타겟 시간 (예: [15, 20, 25, 30]).
        """
        self.samples = []
        for i in range(num_samples):
            # 랜덤 초기 조건 (예: 가우시안 랜덤 필드)
            w0 = np.random.randn(N, N)
            snapshots = solve_navier_stokes(w0, nu, dt, t_final, N)
            # snapshots: [(t, w), ...] t는 정수 시간 (0,1,2,...,t_final)
            input_series = []
            for t, w in snapshots:
                if t >= T_in_range[0] and t <= T_in_range[1]:
                    input_series.append(w)
            input_series = np.array(input_series)  # shape: (T_in, N, N)
            
            target_series = []
            for t, w in snapshots:
                if t in T_out_times:
                    target_series.append(w)
            target_series = np.array(target_series)  # shape: (T_out, N, N)
            self.samples.append((input_series, target_series))
        
        # 공간 좌표 (x, y) 생성, x,y ∈ [0,1)
        x = np.linspace(0, 1, N, endpoint=False)
        y = np.linspace(0, 1, N, endpoint=False)
        xv, yv = np.meshgrid(x, y, indexing='ij')
        self.spatial_coords = np.stack([xv, yv], axis=-1)  # (N, N, 2)
        # 입력 시간 좌표: 정수 시간 (예: 0,1,...,10)
        self.input_times = np.arange(T_in_range[0], T_in_range[1]+1)
        self.target_times = np.array(T_out_times)
        
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        input_series, target_series = self.samples[idx]
        T_in = input_series.shape[0]
        N = input_series.shape[1]
        # 각 입력 시간(t)에 대해 [vorticity, t, x, y]를 결합
        input_data = []
        for i, t in enumerate(self.input_times):
            t_field = np.full((N, N, 1), t)
            w_field = input_series[i][:, :, np.newaxis]
            combined = np.concatenate([w_field, t_field, self.spatial_coords], axis=-1)
            input_data.append(combined)
        input_data = np.stack(input_data, axis=0)  # shape: (T_in, N, N, 4)
        
        # target_series의 길이가 기대하는 T_out와 같지 않은 경우, 부족한 부분을 마지막 스냅샷으로 패딩
        if target_series.shape[0] < len(self.target_times):
            pad_len = len(self.target_times) - target_series.shape[0]
            last = target_series[-1:,...]
            pad = np.repeat(last, pad_len, axis=0)
            target_series = np.concatenate([target_series, pad], axis=0)
        
        target_data = []
        for i in range(target_series.shape[0]):
            target_data.append(target_series[i][:, :, np.newaxis])
        target_data = np.stack(target_data, axis=0)  # shape: (T_out, N, N, 1)
        
        # Torch tensor로 변환
        input_data = torch.tensor(input_data, dtype=torch.float32)
        target_data = torch.tensor(target_data, dtype=torch.float32)
        return input_data, target_data


# =============================================================================
# 3. 기존의 FNO 모델 (3D FNO: 시간-공간 연산자 학습)
# =============================================================================
class SpectralConv3d(nn.Module):
    def __init__(self, in_channels, out_channels, modes_t, modes_x, modes_y):
        super(SpectralConv3d, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes_t = modes_t
        self.modes_x = modes_x
        self.modes_y = modes_y
        self.scale = 1 / (in_channels * out_channels)
        self.weights = nn.Parameter(
            self.scale * torch.rand(in_channels, out_channels, modes_t, modes_x, modes_y, 2)
        )
    
    def compl_mul3d(self, input, weights):
        # weights: (in_channels, out_channels, t, x, y, 2) -> 복소수 텐서: (in_channels, out_channels, t, x, y)
        weight_complex = torch.view_as_complex(weights)
        # "bctxy, cotxy -> botxy": 입력의 각 주파수에 대해, C_in에 대해 합산하여 (batch, out_channels, t, x, y)를 얻음.
        return torch.einsum("bctxy, cotxy -> botxy", input, weight_complex)
    
    def forward(self, x):
        batchsize = x.shape[0]
        # 3D FFT 계산: x의 shape은 (batch, in_channels, t, x, y)
        x_ft = torch.fft.rfftn(x, dim=[2,3,4])
        out_ft = torch.zeros(
            batchsize, self.out_channels, x_ft.size(2), x_ft.size(3), x_ft.size(4),
            device=x.device, dtype=torch.cfloat
        )
        t_modes = min(self.modes_t, x_ft.size(2))
        x_modes = min(self.modes_x, x_ft.size(3))
        y_modes = min(self.modes_y, x_ft.size(4))
        out_ft[:, :, :t_modes, :x_modes, :y_modes] = self.compl_mul3d(
            x_ft[:, :, :t_modes, :x_modes, :y_modes],
            self.weights[:, :, :t_modes, :x_modes, :y_modes]
        )
        x = torch.fft.irfftn(out_ft, s=(x.size(2), x.size(3), x.size(4)))
        return x



class FNO3d(nn.Module):
    def __init__(self, modes_t, modes_x, modes_y, width, T_in, T_out):
        """
        modes_t, modes_x, modes_y: 시간 및 공간 방향의 Fourier 모드 수.
        width: latent channel 차원.
        T_in: 입력 시간 스텝 수 (예: 11, t=0~10)
        T_out: 출력 시간 스텝 수 (예: 4, t=15,20,25,30)
        """
        super(FNO3d, self).__init__()
        self.width = width
        self.T_in = T_in
        self.T_out = T_out
        self.fc0 = nn.Linear(4, width)  # 입력 채널: [vorticity, t, x, y]
        
        self.conv0 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv1 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv2 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv3 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        
        self.w0 = nn.Conv3d(self.width, self.width, 1)
        self.w1 = nn.Conv3d(self.width, self.width, 1)
        self.w2 = nn.Conv3d(self.width, self.width, 1)
        self.w3 = nn.Conv3d(self.width, self.width, 1)
        
        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)  # 출력: vorticity
        
        # Temporal predictor: 각 픽셀별로 입력 시간(T_in)을 출력 시간(T_out)으로 매핑
        self.temporal_fc = nn.Linear(T_in, T_out)
        
    def forward(self, x):
        # x: (batch, T_in, H, W, 4)
        batch, T_in, H, W, _ = x.shape
        x = self.fc0(x)  # (batch, T_in, H, W, width)
        x = x.permute(0, 4, 1, 2, 3)  # (batch, width, T_in, H, W)
        
        x0 = self.conv0(x)
        x1 = self.w0(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv1(x)
        x1 = self.w1(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv2(x)
        x1 = self.w2(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv3(x)
        x1 = self.w3(x)
        x = F.gelu(x0 + x1)
        
        x = x.permute(0, 2, 3, 4, 1)  # (batch, T_in, H, W, width)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)  # (batch, T_in, H, W, 1)
        
        # Temporal prediction: 각 픽셀별로 입력 시간 차원(T_in)을 T_out 차원으로 변환
        x = x.squeeze(-1)              # (batch, T_in, H, W)
        x = x.permute(0, 2, 3, 1)        # (batch, H, W, T_in)
        x = self.temporal_fc(x)          # (batch, H, W, T_out)
        x = x.permute(0, 3, 1, 2).unsqueeze(-1)  # (batch, T_out, H, W, 1)
        return x


# =============================================================================
# 4. 학습 루프 및 시각화
# =============================================================================
def train_model_3d(model, train_loader, test_loader, epochs=300):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)
    loss_fn = nn.MSELoss()
    train_losses = []
    test_losses = []
    
    for epoch in range(1, epochs+1):
        model.train()
        train_loss = 0.0
        for input_data, target in train_loader:
            # input_data: (batch, T_in, H, W, 4), target: (batch, T_out, H, W, 1)
            input_data = input_data.to(device)
            target = target.to(device)
            optimizer.zero_grad()
            output = model(input_data)
            loss = loss_fn(output, target)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * input_data.size(0)
        train_loss /= len(train_loader.dataset)
        train_losses.append(train_loss)
        
        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for input_data, target in test_loader:
                input_data = input_data.to(device)
                target = target.to(device)
                output = model(input_data)
                loss = loss_fn(output, target)
                test_loss += loss.item() * input_data.size(0)
        test_loss /= len(test_loader.dataset)
        test_losses.append(test_loss)
        scheduler.step()
        if epoch % 1 == 0:
            print(f"Epoch {epoch:03d}: Train Loss = {train_loss:.6f}, Test Loss = {test_loss:.6f}")
    
    plt.figure(figsize=(8,6))
    plt.plot(train_losses, label="Train Loss")
    plt.plot(test_losses, label="Test Loss")
    plt.xlabel("Epoch")
    plt.ylabel("MSE Loss")
    plt.legend()
    plt.title("Training and Test Loss Curves (FNO3d)")
    plt.show()
    
    return train_losses, test_losses

def visualize_sample_3d(model, test_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    with torch.no_grad():
        input_data, target = next(iter(test_loader))
        input_data = input_data.to(device)
        pred = model(input_data)
    sample_target = target[0].cpu().numpy()  # (T_out, H, W, 1)
    sample_pred = pred[0].cpu().numpy()      # (T_out, H, W, 1)
    times = [15, 20, 25, 30]  # target 시간 라벨
    T_out = sample_target.shape[0]
    plt.figure(figsize=(16, 4*T_out))
    for i in range(T_out):
        plt.subplot(T_out, 2, 2*i+1)
        plt.title(f"Ground Truth at t = {times[i]}")
        plt.imshow(sample_target[i, :, :, 0], cmap="RdBu", origin="lower")
        plt.colorbar()
        plt.subplot(T_out, 2, 2*i+2)
        plt.title(f"Prediction at t = {times[i]}")
        plt.imshow(sample_pred[i, :, :, 0], cmap="RdBu", origin="lower")
        plt.colorbar()
    plt.tight_layout()
    plt.show()


# =============================================================================
# 5. 전체 파이프라인 실행
# =============================================================================
if __name__ == '__main__':
    # PDE simulation parameters
    N = 64         # spatial resolution: 64x64
    dt = 0.005     # 시간 스텝 (안정성을 위해 충분히 작게)
    t_final = 50   # 최종 시각
    nu = 1e-3      # 점성 계수 (예시)
    
    # 데이터셋에서 사용할 시간 구간
    T_in_range = (0, 10)          # 입력: t=0 ~ 10 (정수 시간 스냅샷)
    T_out_times = [20, 30, 40, 49] # 타겟: t = 15,20,25,30
    
    num_train = 100   # 시연을 위한 샘플 수 (실제 연구에서는 더 많은 샘플 사용)
    num_test = 20
    
    # Navier–Stokes PDE solver를 통해 데이터 생성
    dataset_solver_train = NavierStokesDatasetFromSolver(num_samples=num_train, N=N, dt=dt, t_final=t_final, nu=nu, 
                                                          T_in_range=T_in_range, T_out_times=T_out_times)
    dataset_solver_test  = NavierStokesDatasetFromSolver(num_samples=num_test, N=N, dt=dt, t_final=t_final, nu=nu, 
                                                          T_in_range=T_in_range, T_out_times=T_out_times)
    
    train_loader = DataLoader(dataset_solver_train, batch_size=2, shuffle=True)
    test_loader = DataLoader(dataset_solver_test, batch_size=2, shuffle=False)
    
    # 모델 하이퍼파라미터: Fourier 모드 수 선택 (시간: 4, x: 16, y: 16), width: 32, T_out: 4
    modes_t, modes_x, modes_y = 4, 16, 16
    width = 32
    T_out = len(T_out_times)
    T_in = 11
    model = FNO3d(modes_t, modes_x, modes_y, width, T_in, T_out)
    
    # 학습
    train_losses, test_losses = train_model_3d(model, train_loader, test_loader, epochs=1000)
    
    # 결과 시각화
# Epoch 631: Train Loss = 0.000207, Test Loss = 0.020340
# Epoch 632: Train Loss = 0.000204, Test Loss = 0.020151
# Epoch 633: Train Loss = 0.000225, Test Loss = 0.020632
# Epoch 634: Train Loss = 0.000204, Test Loss = 0.020185
# Epoch 635: Train Loss = 0.000186, Test Loss = 0.020089
# Epoch 636: Train Loss = 0.000173, Test Loss = 0.020212
# Epoch 637: Train Loss = 0.000157, Test Loss = 0.020336
# Epoch 638: Train Loss = 0.000183, Test Loss = 0.020018
# Epoch 639: Train Loss = 0.000254, Test Loss = 0.020319
# Epoch 640: Train Loss = 0.000277, Test Loss = 0.020137
# Epoch 641: Train Loss = 0.000348, Test Loss = 0.019961
# Epoch 642: Train Loss = 0.000269, Test Loss = 0.020309
# Epoch 643: Train Loss = 0.000217, Test Loss = 0.020523
# Epoch 644: Train Loss = 0.000222, Test Loss = 0.020416
# Epoch 645: Train Loss = 0.000159, Test Loss = 0.020268
# Epoch 646: Train Loss = 0.000137, Test Loss = 0.020100
# Epoch 647: Train Loss = 0.000129, Test Loss = 0.020111
# Epoch 648: Train Loss = 0.000131, Test Loss = 0.019947
# Epoch 649: Train Loss = 0.000117, Test Loss = 0.020017
# Epoch 650: Train Loss = 0.000099, Test Loss = 0.020023
# Epoch 651: Train Loss = 0.000085, Test Loss = 0.020013
# Epoch 652: Train Loss = 0.000074, Test Loss = 0.019980
# Epoch 653: Train Loss = 0.000098, Test Loss = 0.020076
# Epoch 654: Train Loss = 0.000078, Test Loss = 0.020172
# Epoch 655: Train Loss = 0.000082, Test Loss = 0.020248
# Epoch 656: Train Loss = 0.000067, Test Loss = 0.020038
# Epoch 657: Train Loss = 0.000061, Test Loss = 0.020234
# Epoch 658: Train Loss = 0.000097, Test Loss = 0.020356
# Epoch 659: Train Loss = 0.000127, Test Loss = 0.019965
# Epoch 660: Train Loss = 0.000200, Test Loss = 0.020245
# Epoch 661: Train Loss = 0.000196, Test Loss = 0.020055
# Epoch 662: Train Loss = 0.000225, Test Loss = 0.020138
# Epoch 663: Train Loss = 0.000212, Test Loss = 0.019864
# Epoch 664: Train Loss = 0.000249, Test Loss = 0.020066
# Epoch 665: Train Loss = 0.000286, Test Loss = 0.020218
# Epoch 666: Train Loss = 0.000272, Test Loss = 0.020007
# Epoch 667: Train Loss = 0.000319, Test Loss = 0.020137
# Epoch 668: Train Loss = 0.000288, Test Loss = 0.020011
# Epoch 669: Train Loss = 0.000212, Test Loss = 0.020344
# Epoch 670: Train Loss = 0.000129, Test Loss = 0.020229
# Epoch 671: Train Loss = 0.000130, Test Loss = 0.020030
# Epoch 672: Train Loss = 0.000139, Test Loss = 0.020139
# Epoch 673: Train Loss = 0.000133, Test Loss = 0.020130
# Epoch 674: Train Loss = 0.000125, Test Loss = 0.020426
# Epoch 675: Train Loss = 0.000087, Test Loss = 0.020016
# Epoch 676: Train Loss = 0.000068, Test Loss = 0.020086
# Epoch 677: Train Loss = 0.000062, Test Loss = 0.019931
# Epoch 678: Train Loss = 0.000080, Test Loss = 0.020218
# Epoch 776: Train Loss = 0.000074, Test Loss = 0.019630
# Epoch 777: Train Loss = 0.000082, Test Loss = 0.019547
# Epoch 778: Train Loss = 0.000091, Test Loss = 0.020120
# Epoch 779: Train Loss = 0.000133, Test Loss = 0.019436
# Epoch 780: Train Loss = 0.000170, Test Loss = 0.019921
# Epoch 781: Train Loss = 0.000171, Test Loss = 0.019761
# Epoch 782: Train Loss = 0.000154, Test Loss = 0.019545
# Epoch 783: Train Loss = 0.000156, Test Loss = 0.019555
# Epoch 784: Train Loss = 0.000159, Test Loss = 0.019438
# Epoch 785: Train Loss = 0.000160, Test Loss = 0.019898
# Epoch 786: Train Loss = 0.000174, Test Loss = 0.019751
# Epoch 787: Train Loss = 0.000173, Test Loss = 0.019711
# Epoch 788: Train Loss = 0.000183, Test Loss = 0.019934
# Epoch 789: Train Loss = 0.000138, Test Loss = 0.019634
# Epoch 790: Train Loss = 0.000114, Test Loss = 0.019573
# Epoch 791: Train Loss = 0.000108, Test Loss = 0.019509
# Epoch 792: Train Loss = 0.000119, Test Loss = 0.019407
# Epoch 793: Train Loss = 0.000094, Test Loss = 0.019725
# Epoch 794: Train Loss = 0.000070, Test Loss = 0.019567
# Epoch 795: Train Loss = 0.000063, Test Loss = 0.019838
# Epoch 796: Train Loss = 0.000062, Test Loss = 0.019779
# Epoch 797: Train Loss = 0.000066, Test Loss = 0.019712
# Epoch 798: Train Loss = 0.000071, Test Loss = 0.019667
# Epoch 799: Train Loss = 0.000074, Test Loss = 0.019604
# Epoch 800: Train Loss = 0.000082, Test Loss = 0.019767
# Epoch 801: Train Loss = 0.000083, Test Loss = 0.019399
# Epoch 802: Train Loss = 0.000119, Test Loss = 0.019471
# Epoch 803: Train Loss = 0.000157, Test Loss = 0.019784
# Epoch 804: Train Loss = 0.000188, Test Loss = 0.019891
# Epoch 805: Train Loss = 0.000212, Test Loss = 0.019676
# Epoch 806: Train Loss = 0.000176, Test Loss = 0.019509
# Epoch 807: Train Loss = 0.000177, Test Loss = 0.019722
# Epoch 808: Train Loss = 0.000199, Test Loss = 0.019557
# Epoch 809: Train Loss = 0.000170, Test Loss = 0.019238
# Epoch 810: Train Loss = 0.000202, Test Loss = 0.019423
# Epoch 811: Train Loss = 0.000170, Test Loss = 0.019924
# Epoch 812: Train Loss = 0.000169, Test Loss = 0.019456
# Epoch 813: Train Loss = 0.000123, Test Loss = 0.019409
# Epoch 814: Train Loss = 0.000133, Test Loss = 0.019408
# Epoch 815: Train Loss = 0.000137, Test Loss = 0.019773
# Epoch 816: Train Loss = 0.000135, Test Loss = 0.019411
# Epoch 817: Train Loss = 0.000141, Test Loss = 0.019441
# Epoch 818: Train Loss = 0.000153, Test Loss = 0.019898
# Epoch 819: Train Loss = 0.000275, Test Loss = 0.019750
# Epoch 820: Train Loss = 0.000189, Test Loss = 0.019510
# Epoch 821: Train Loss = 0.000137, Test Loss = 0.019725
# Epoch 822: Train Loss = 0.000100, Test Loss = 0.019513
# Epoch 823: Train Loss = 0.000083, Test Loss = 0.019482
# Epoch 824: Train Loss = 0.000062, Test Loss = 0.019518
# Epoch 825: Train Loss = 0.000060, Test Loss = 0.019464
# Epoch 826: Train Loss = 0.000055, Test Loss = 0.019505
# Epoch 827: Train Loss = 0.000062, Test Loss = 0.019520
# Epoch 828: Train Loss = 0.000063, Test Loss = 0.019480
# Epoch 829: Train Loss = 0.000072, Test Loss = 0.019576
# Epoch 830: Train Loss = 0.000079, Test Loss = 0.019407
# Epoch 831: Train Loss = 0.000075, Test Loss = 0.019467
# Epoch 832: Train Loss = 0.000086, Test Loss = 0.019669
# Epoch 833: Train Loss = 0.000096, Test Loss = 0.019593
# Epoch 834: Train Loss = 0.000147, Test Loss = 0.019728
# Epoch 835: Train Loss = 0.000180, Test Loss = 0.019813
# Epoch 836: Train Loss = 0.000210, Test Loss = 0.019664
# Epoch 837: Train Loss = 0.000243, Test Loss = 0.019425
# Epoch 838: Train Loss = 0.000255, Test Loss = 0.019903
# Epoch 839: Train Loss = 0.000196, Test Loss = 0.019865
# Epoch 840: Train Loss = 0.000200, Test Loss = 0.019388
# Epoch 841: Train Loss = 0.000177, Test Loss = 0.019411
# Epoch 842: Train Loss = 0.000136, Test Loss = 0.019501
# Epoch 843: Train Loss = 0.000103, Test Loss = 0.019319
# Epoch 844: Train Loss = 0.000114, Test Loss = 0.019422
# Epoch 845: Train Loss = 0.000113, Test Loss = 0.019441
# Epoch 846: Train Loss = 0.000105, Test Loss = 0.019187
# Epoch 847: Train Loss = 0.000105, Test Loss = 0.019449
# Epoch 848: Train Loss = 0.000119, Test Loss = 0.019485
# Epoch 849: Train Loss = 0.000102, Test Loss = 0.019566
# Epoch 850: Train Loss = 0.000105, Test Loss = 0.019600
# Epoch 851: Train Loss = 0.000124, Test Loss = 0.019343
# Epoch 852: Train Loss = 0.000100, Test Loss = 0.019633
# Epoch 853: Train Loss = 0.000106, Test Loss = 0.019338
# Epoch 854: Train Loss = 0.000106, Test Loss = 0.019823
# Epoch 855: Train Loss = 0.000119, Test Loss = 0.019678
# Epoch 856: Train Loss = 0.000124, Test Loss = 0.019487
# Epoch 857: Train Loss = 0.000130, Test Loss = 0.019317
# Epoch 858: Train Loss = 0.000114, Test Loss = 0.019614
# Epoch 859: Train Loss = 0.000116, Test Loss = 0.019608
# Epoch 860: Train Loss = 0.000149, Test Loss = 0.019398
# Epoch 861: Train Loss = 0.000142, Test Loss = 0.019280
# Epoch 862: Train Loss = 0.000142, Test Loss = 0.019477
# Epoch 863: Train Loss = 0.000106, Test Loss = 0.019457
# Epoch 864: Train Loss = 0.000098, Test Loss = 0.019501
# Epoch 865: Train Loss = 0.000112, Test Loss = 0.019475
# Epoch 866: Train Loss = 0.000117, Test Loss = 0.019539
# Epoch 867: Train Loss = 0.000113, Test Loss = 0.019408
# Epoch 868: Train Loss = 0.000120, Test Loss = 0.019696
# Epoch 869: Train Loss = 0.000117, Test Loss = 0.019221
# Epoch 870: Train Loss = 0.000109, Test Loss = 0.019463
# Epoch 871: Train Loss = 0.000105, Test Loss = 0.019595
# Epoch 872: Train Loss = 0.000117, Test Loss = 0.019567
# Epoch 873: Train Loss = 0.000173, Test Loss = 0.019405
# Epoch 874: Train Loss = 0.000231, Test Loss = 0.019489
# Epoch 875: Train Loss = 0.000142, Test Loss = 0.019337
# Epoch 876: Train Loss = 0.000140, Test Loss = 0.019766
# Epoch 877: Train Loss = 0.000183, Test Loss = 0.019433
# Epoch 878: Train Loss = 0.000134, Test Loss = 0.019395
# Epoch 879: Train Loss = 0.000180, Test Loss = 0.019529
# Epoch 880: Train Loss = 0.000165, Test Loss = 0.019892
# Epoch 881: Train Loss = 0.000182, Test Loss = 0.019233
# Epoch 882: Train Loss = 0.000190, Test Loss = 0.019328
# Epoch 883: Train Loss = 0.000142, Test Loss = 0.019488
# Epoch 884: Train Loss = 0.000119, Test Loss = 0.019377
# Epoch 885: Train Loss = 0.000099, Test Loss = 0.019438
# Epoch 886: Train Loss = 0.000067, Test Loss = 0.019412
# Epoch 887: Train Loss = 0.000048, Test Loss = 0.019287
# Epoch 888: Train Loss = 0.000044, Test Loss = 0.019354
# Epoch 889: Train Loss = 0.000041, Test Loss = 0.019376
# Epoch 890: Train Loss = 0.000040, Test Loss = 0.019350
# Epoch 891: Train Loss = 0.000058, Test Loss = 0.019422
# Epoch 892: Train Loss = 0.000067, Test Loss = 0.019266
# Epoch 893: Train Loss = 0.000073, Test Loss = 0.019431
# Epoch 894: Train Loss = 0.000081, Test Loss = 0.019585
# Epoch 895: Train Loss = 0.000075, Test Loss = 0.019316
# Epoch 896: Train Loss = 0.000072, Test Loss = 0.019510
# Epoch 897: Train Loss = 0.000087, Test Loss = 0.019234
# Epoch 898: Train Loss = 0.000097, Test Loss = 0.019448
# Epoch 899: Train Loss = 0.000106, Test Loss = 0.019487
# Epoch 900: Train Loss = 0.000125, Test Loss = 0.019315
# Epoch 901: Train Loss = 0.000136, Test Loss = 0.019459
# Epoch 902: Train Loss = 0.000119, Test Loss = 0.019320
# Epoch 903: Train Loss = 0.000132, Test Loss = 0.019526
# Epoch 904: Train Loss = 0.000115, Test Loss = 0.019370
# Epoch 905: Train Loss = 0.000118, Test Loss = 0.019455
# Epoch 906: Train Loss = 0.000128, Test Loss = 0.019822
# Epoch 907: Train Loss = 0.000138, Test Loss = 0.019275
# Epoch 908: Train Loss = 0.000166, Test Loss = 0.019342
# Epoch 909: Train Loss = 0.000165, Test Loss = 0.019467
# Epoch 910: Train Loss = 0.000127, Test Loss = 0.019190
# Epoch 911: Train Loss = 0.000156, Test Loss = 0.019078
# Epoch 912: Train Loss = 0.000128, Test Loss = 0.019408
# Epoch 913: Train Loss = 0.000099, Test Loss = 0.019182
# Epoch 914: Train Loss = 0.000106, Test Loss = 0.019325
# Epoch 915: Train Loss = 0.000097, Test Loss = 0.019108
# Epoch 916: Train Loss = 0.000085, Test Loss = 0.019461
# Epoch 917: Train Loss = 0.000093, Test Loss = 0.019386
# Epoch 918: Train Loss = 0.000092, Test Loss = 0.019376
# Epoch 919: Train Loss = 0.000092, Test Loss = 0.019370
# Epoch 920: Train Loss = 0.000093, Test Loss = 0.019368
# Epoch 921: Train Loss = 0.000091, Test Loss = 0.019443
# Epoch 922: Train Loss = 0.000118, Test Loss = 0.019467
# Epoch 923: Train Loss = 0.000100, Test Loss = 0.019328
# Epoch 924: Train Loss = 0.000085, Test Loss = 0.019263
# Epoch 925: Train Loss = 0.000096, Test Loss = 0.019577
# Epoch 926: Train Loss = 0.000109, Test Loss = 0.019476
# Epoch 927: Train Loss = 0.000127, Test Loss = 0.019327
# Epoch 928: Train Loss = 0.000117, Test Loss = 0.019066
# Epoch 929: Train Loss = 0.000153, Test Loss = 0.019267
# Epoch 930: Train Loss = 0.000211, Test Loss = 0.019265
# Epoch 931: Train Loss = 0.000219, Test Loss = 0.020023
# Epoch 932: Train Loss = 0.000205, Test Loss = 0.019183
# Epoch 933: Train Loss = 0.000136, Test Loss = 0.019448
# Epoch 934: Train Loss = 0.000132, Test Loss = 0.019150
# Epoch 935: Train Loss = 0.000099, Test Loss = 0.019418
# Epoch 936: Train Loss = 0.000100, Test Loss = 0.019187
# Epoch 937: Train Loss = 0.000098, Test Loss = 0.019364
# Epoch 938: Train Loss = 0.000086, Test Loss = 0.019195
# Epoch 939: Train Loss = 0.000075, Test Loss = 0.019093
# Epoch 940: Train Loss = 0.000059, Test Loss = 0.019396
# Epoch 941: Train Loss = 0.000081, Test Loss = 0.019372
# Epoch 942: Train Loss = 0.000076, Test Loss = 0.019255
# Epoch 943: Train Loss = 0.000086, Test Loss = 0.019215
# Epoch 944: Train Loss = 0.000098, Test Loss = 0.019341
# Epoch 945: Train Loss = 0.000096, Test Loss = 0.019255
# Epoch 946: Train Loss = 0.000118, Test Loss = 0.019321
# Epoch 947: Train Loss = 0.000110, Test Loss = 0.019110
# Epoch 948: Train Loss = 0.000117, Test Loss = 0.019202
# Epoch 949: Train Loss = 0.000142, Test Loss = 0.019344
# Epoch 950: Train Loss = 0.000200, Test Loss = 0.019208
# Epoch 951: Train Loss = 0.000144, Test Loss = 0.019508
# Epoch 952: Train Loss = 0.000115, Test Loss = 0.019203
# Epoch 953: Train Loss = 0.000132, Test Loss = 0.019446
# Epoch 954: Train Loss = 0.000157, Test Loss = 0.019386
# Epoch 955: Train Loss = 0.000100, Test Loss = 0.019212
# Epoch 956: Train Loss = 0.000109, Test Loss = 0.019166
# Epoch 957: Train Loss = 0.000102, Test Loss = 0.019477
# Epoch 958: Train Loss = 0.000131, Test Loss = 0.019105
# Epoch 959: Train Loss = 0.000098, Test Loss = 0.019207
# Epoch 960: Train Loss = 0.000083, Test Loss = 0.019178
# Epoch 961: Train Loss = 0.000059, Test Loss = 0.019085
# Epoch 962: Train Loss = 0.000042, Test Loss = 0.019274
# Epoch 963: Train Loss = 0.000037, Test Loss = 0.019284
# Epoch 964: Train Loss = 0.000045, Test Loss = 0.019114
# Epoch 965: Train Loss = 0.000041, Test Loss = 0.019272
# Epoch 966: Train Loss = 0.000059, Test Loss = 0.019295
# Epoch 967: Train Loss = 0.000074, Test Loss = 0.019208
# Epoch 968: Train Loss = 0.000108, Test Loss = 0.019179
# Epoch 969: Train Loss = 0.000118, Test Loss = 0.019331
# Epoch 970: Train Loss = 0.000126, Test Loss = 0.019035
# Epoch 971: Train Loss = 0.000154, Test Loss = 0.019216
# Epoch 972: Train Loss = 0.000194, Test Loss = 0.019225
# Epoch 973: Train Loss = 0.000176, Test Loss = 0.019227
# Epoch 974: Train Loss = 0.000172, Test Loss = 0.019213
# Epoch 975: Train Loss = 0.000219, Test Loss = 0.018966
# Epoch 976: Train Loss = 0.000232, Test Loss = 0.019397
# Epoch 977: Train Loss = 0.000171, Test Loss = 0.018949
# Epoch 978: Train Loss = 0.000121, Test Loss = 0.019068
# Epoch 979: Train Loss = 0.000112, Test Loss = 0.019172
# Epoch 980: Train Loss = 0.000105, Test Loss = 0.019299
# Epoch 981: Train Loss = 0.000102, Test Loss = 0.019159
# Epoch 982: Train Loss = 0.000126, Test Loss = 0.019084
# Epoch 983: Train Loss = 0.000105, Test Loss = 0.019214
# Epoch 984: Train Loss = 0.000134, Test Loss = 0.019610
# Epoch 985: Train Loss = 0.000153, Test Loss = 0.019254
# Epoch 986: Train Loss = 0.000102, Test Loss = 0.019160
# Epoch 987: Train Loss = 0.000128, Test Loss = 0.019208
# Epoch 988: Train Loss = 0.000158, Test Loss = 0.019060
# Epoch 989: Train Loss = 0.000111, Test Loss = 0.019103
# Epoch 990: Train Loss = 0.000063, Test Loss = 0.019119
# Epoch 991: Train Loss = 0.000056, Test Loss = 0.019341
# Epoch 992: Train Loss = 0.000048, Test Loss = 0.019116
# Epoch 993: Train Loss = 0.000036, Test Loss = 0.019138
# Epoch 994: Train Loss = 0.000045, Test Loss = 0.019204
# Epoch 995: Train Loss = 0.000049, Test Loss = 0.019153
# Epoch 996: Train Loss = 0.000041, Test Loss = 0.019196
# Epoch 997: Train Loss = 0.000046, Test Loss = 0.019300
# Epoch 998: Train Loss = 0.000053, Test Loss = 0.019258
# Epoch 999: Train Loss = 0.000064, Test Loss = 0.019245
# Epoch 1000: Train Loss = 0.000099, Test Loss = 0.019112

# %%
def visualize_sample_3d(model, test_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    with torch.no_grad():
        input_data, target = next(iter(test_loader))
        input_data = input_data.to(device)
        pred = model(input_data)
    sample_target = target[0].cpu().numpy()  # (T_out, H, W, 1)
    sample_pred = pred[0].cpu().numpy()      # (T_out, H, W, 1)
    times = [15, 20, 25, 30]  # target 시간 라벨
    T_out = sample_target.shape[0]
    plt.figure(figsize=(16, 4*T_out))
    for i in range(T_out):
        plt.subplot(T_out, 2, 2*i+1)
        plt.title(f"Ground Truth at t = {times[i]}")
        plt.imshow(sample_target[i, :, :, 0], cmap="seismic", origin="lower")
        plt.colorbar()
        plt.subplot(T_out, 2, 2*i+2)
        plt.title(f"Prediction at t = {times[i]}")
        plt.imshow(sample_pred[i, :, :, 0], cmap="seismic", origin="lower")
        plt.colorbar()
    plt.tight_layout()
    plt.show()


# 결과 시각화
visualize_sample_3d(model, test_loader)

# %%
plt.figure(figsize=(8,6))
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.yscale('log')
plt.legend()
plt.title("Training and Test Loss Curves (FNO3d) [Log Scale]")
plt.show()

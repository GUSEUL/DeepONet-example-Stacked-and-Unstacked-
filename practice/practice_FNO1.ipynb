# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt

# =============================================================================
# 1. Navier–Stokes PDE solver (pseudo-spectral method)
# =============================================================================
def solve_navier_stokes(w0, nu, dt, t_final, N):
    """
    2D Navier–Stokes vorticity PDE (주기적 경계조건) 를 푸는 간단한 pseudo-spectral solver.
    
    PDE:
        ∂ₜw + u · ∇w = ν ∆w + f(x)
        u = (ψ_y, -ψ_x),   and   ∆ψ = -w,  with periodic boundary conditions.
    입력:
        w0: 초기 vorticity, shape (N, N)
        nu: 점성 계수
        dt: 시간 스텝
        t_final: 최종 시간
        N: 격자 크기 (N×N)
    출력:
        snapshots: 정수 시간마다 (t, w) 튜플 리스트.
    """
    # 공간 좌표 생성 (0 ≤ x,y < 1)
    x = np.linspace(0, 1, N, endpoint=False)
    y = np.linspace(0, 1, N, endpoint=False)
    xv, yv = np.meshgrid(x, y, indexing='ij')
    
    # forcing function: f(x) = 0.1*( sin(2π(x+y)) + cos(2π(x+y)) )
    f = 0.1 * (np.sin(2*np.pi*(xv + yv)) + np.cos(2*np.pi*(xv + yv)))
    
    # FFT frequencies (주기적 도메인: [0,1])
    kx = np.fft.fftfreq(N, d=1.0/N) * 2*np.pi
    ky = np.fft.fftfreq(N, d=1.0/N) * 2*np.pi
    kx, ky = np.meshgrid(kx, ky, indexing='ij')
    ksq = kx**2 + ky**2
    ksq[0,0] = 1.0  # 0분할 방지
    
    w = w0.copy()
    snapshots = []
    snapshot_times = np.arange(0, t_final+dt, 1.0)  # 정수 시간마다 기록
    next_snapshot_index = 0
    
    nsteps = int(t_final/dt)
    for step in range(nsteps):
        t = step * dt
        # 스냅샷 기록
        if next_snapshot_index < len(snapshot_times) and t >= snapshot_times[next_snapshot_index]:
            snapshots.append((t, w.copy()))
            next_snapshot_index += 1
        
        # vorticity의 FFT
        w_hat = np.fft.fft2(w)
        # stream function: ∆ψ = -w  ->  ψ_hat = -w_hat / ksq, ψ_hat(0)=0
        psi_hat = -w_hat / ksq
        psi_hat[0,0] = 0.0
        psi = np.real(np.fft.ifft2(psi_hat))
        
        # 속도 계산: u = ψ_y, v = -ψ_x (spectral differentiation)
        u = np.real(np.fft.ifft2(1j * ky * psi_hat))
        v = -np.real(np.fft.ifft2(1j * kx * psi_hat))
        
        # vorticity gradient (spectral differentiation)
        w_x = np.real(np.fft.ifft2(1j * kx * w_hat))
        w_y = np.real(np.fft.ifft2(1j * ky * w_hat))
        
        # 비선형 항: u * w_x + v * w_y
        nonlinear = u * w_x + v * w_y
        
        # Laplacian: ∆w = ifft2(-ksq * w_hat)
        lap_w = np.real(np.fft.ifft2(-ksq * w_hat))
        
        # Euler explicit time stepping
        w = w + dt * (-nonlinear + nu * lap_w + f)
    
    return snapshots

# %%
# =============================================================================
# 2. Navier-Stokes 데이터셋 (PDE solver를 사용하여 데이터 생성)
# =============================================================================
class NavierStokesDatasetFromSolver(Dataset):
    def __init__(self, num_samples, N, dt, t_final, nu, T_in_range, T_out_times):
        """
        num_samples: 샘플 개수.
        N: 공간 격자 크기 (N×N).
        dt: 시간 스텝.
        t_final: 최종 시각 (예, 30).
        nu: 점성 계수.
        T_in_range: 입력 시간 구간 (예: (0, 10)).
        T_out_times: 타겟 시간 (예: [15, 20, 25, 30]).
        """
        self.samples = []
        for i in range(num_samples):
            # 랜덤 초기 조건 (예: 가우시안 랜덤 필드)
            w0 = np.random.randn(N, N)
            snapshots = solve_navier_stokes(w0, nu, dt, t_final, N)
            # snapshots: [(t, w), ...] t는 정수 시간 (0,1,2,...,t_final)
            input_series = []
            for t, w in snapshots:
                if t >= T_in_range[0] and t <= T_in_range[1]:
                    input_series.append(w)
            input_series = np.array(input_series)  # shape: (T_in, N, N)
            
            target_series = []
            for t, w in snapshots:
                if t in T_out_times:
                    target_series.append(w)
            target_series = np.array(target_series)  # shape: (T_out, N, N)
            self.samples.append((input_series, target_series))
        
        # 공간 좌표 (x, y) 생성, x,y ∈ [0,1)
        x = np.linspace(0, 1, N, endpoint=False)
        y = np.linspace(0, 1, N, endpoint=False)
        xv, yv = np.meshgrid(x, y, indexing='ij')
        self.spatial_coords = np.stack([xv, yv], axis=-1)  # (N, N, 2)
        # 입력 시간 좌표: 정수 시간 (예: 0,1,...,10)
        self.input_times = np.arange(T_in_range[0], T_in_range[1]+1)
        self.target_times = np.array(T_out_times)
        
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        input_series, target_series = self.samples[idx]
        T_in = input_series.shape[0]
        N = input_series.shape[1]
        # 각 입력 시간(t)에 대해 [vorticity, t, x, y]를 결합
        input_data = []
        for i, t in enumerate(self.input_times):
            t_field = np.full((N, N, 1), t)
            w_field = input_series[i][:, :, np.newaxis]
            combined = np.concatenate([w_field, t_field, self.spatial_coords], axis=-1)
            input_data.append(combined)
        input_data = np.stack(input_data, axis=0)  # shape: (T_in, N, N, 4)
        
        # target_series의 길이가 기대하는 T_out와 같지 않은 경우, 부족한 부분을 마지막 스냅샷으로 패딩
        if target_series.shape[0] < len(self.target_times):
            pad_len = len(self.target_times) - target_series.shape[0]
            last = target_series[-1:,...]
            pad = np.repeat(last, pad_len, axis=0)
            target_series = np.concatenate([target_series, pad], axis=0)
        
        target_data = []
        for i in range(target_series.shape[0]):
            target_data.append(target_series[i][:, :, np.newaxis])
        target_data = np.stack(target_data, axis=0)  # shape: (T_out, N, N, 1)
        
        # Torch tensor로 변환
        input_data = torch.tensor(input_data, dtype=torch.float32)
        target_data = torch.tensor(target_data, dtype=torch.float32)
        return input_data, target_data

# %%
# =============================================================================
# 3. 기존의 FNO 모델 (3D FNO: 시간-공간 연산자 학습)
# =============================================================================
class SpectralConv3d(nn.Module):
    def __init__(self, in_channels, out_channels, modes_t, modes_x, modes_y):
        super(SpectralConv3d, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes_t = modes_t
        self.modes_x = modes_x
        self.modes_y = modes_y
        self.scale = 1 / (in_channels * out_channels)
        self.weights = nn.Parameter(
            self.scale * torch.rand(in_channels, out_channels, modes_t, modes_x, modes_y, 2)
        )
    
    def compl_mul3d(self, input, weights):
        # weights: (in_channels, out_channels, t, x, y, 2) -> 복소수 텐서: (in_channels, out_channels, t, x, y)
        weight_complex = torch.view_as_complex(weights)
        # "bctxy, cotxy -> botxy": 입력의 각 주파수에 대해, C_in에 대해 합산하여 (batch, out_channels, t, x, y)를 얻음.
        return torch.einsum("bctxy, cotxy -> botxy", input, weight_complex)
    
    def forward(self, x):
        batchsize = x.shape[0]
        # 3D FFT 계산: x의 shape은 (batch, in_channels, t, x, y)
        x_ft = torch.fft.rfftn(x, dim=[2,3,4])
        out_ft = torch.zeros(
            batchsize, self.out_channels, x_ft.size(2), x_ft.size(3), x_ft.size(4),
            device=x.device, dtype=torch.cfloat
        )
        t_modes = min(self.modes_t, x_ft.size(2))
        x_modes = min(self.modes_x, x_ft.size(3))
        y_modes = min(self.modes_y, x_ft.size(4))
        out_ft[:, :, :t_modes, :x_modes, :y_modes] = self.compl_mul3d(
            x_ft[:, :, :t_modes, :x_modes, :y_modes],
            self.weights[:, :, :t_modes, :x_modes, :y_modes]
        )
        x = torch.fft.irfftn(out_ft, s=(x.size(2), x.size(3), x.size(4)))
        return x



class FNO3d(nn.Module):
    def __init__(self, modes_t, modes_x, modes_y, width, T_out):
        super(FNO3d, self).__init__()
        self.width = width
        self.T_out = T_out
        self.fc0 = nn.Linear(4, width)  # 입력 채널: [vorticity, t, x, y]
        
        self.conv0 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv1 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv2 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv3 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        
        self.w0 = nn.Conv3d(self.width, self.width, 1)
        self.w1 = nn.Conv3d(self.width, self.width, 1)
        self.w2 = nn.Conv3d(self.width, self.width, 1)
        self.w3 = nn.Conv3d(self.width, self.width, 1)
        
        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)  # 출력: vorticity
        
    def forward(self, x):
        # x: (batch, T_in, H, W, 4)
        batch, T_in, H, W, _ = x.shape
        x = self.fc0(x)  # (batch, T_in, H, W, width)
        x = x.permute(0, 4, 1, 2, 3)  # (batch, width, T_in, H, W)
        
        x0 = self.conv0(x)
        x1 = self.w0(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv1(x)
        x1 = self.w1(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv2(x)
        x1 = self.w2(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv3(x)
        x1 = self.w3(x)
        x = F.gelu(x0 + x1)
        
        x = x.permute(0, 2, 3, 4, 1)  # (batch, T_in, H, W, width)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)  # (batch, T_in, H, W, 1)
        
        # 시간 차원을 평균 내어 collapse 후, T_out 시간 스텝을 반복.
        x = x.mean(dim=1, keepdim=True)  # (batch, 1, H, W, 1)
        x = x.repeat(1, self.T_out, 1, 1, 1)  # (batch, T_out, H, W, 1)
        return x

# %%
# =============================================================================
# 4. 학습 루프 및 시각화
# =============================================================================
def train_model_3d(model, train_loader, test_loader, epochs=300):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    #scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)
    loss_fn = nn.MSELoss()
    train_losses = []
    test_losses = []
    
    for epoch in range(1, epochs+1):
        model.train()
        train_loss = 0.0
        for input_data, target in train_loader:
            # input_data: (batch, T_in, H, W, 4), target: (batch, T_out, H, W, 1)
            input_data = input_data.to(device)
            target = target.to(device)
            optimizer.zero_grad()
            output = model(input_data)
            loss = loss_fn(output, target)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * input_data.size(0)
        train_loss /= len(train_loader.dataset)
        train_losses.append(train_loss)
        
        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for input_data, target in test_loader:
                input_data = input_data.to(device)
                target = target.to(device)
                output = model(input_data)
                loss = loss_fn(output, target)
                test_loss += loss.item() * input_data.size(0)
        test_loss /= len(test_loader.dataset)
        test_losses.append(test_loss)
        #scheduler.step()
        if epoch % 1 == 0:
            print(f"Epoch {epoch:03d}: Train Loss = {train_loss:.6f}, Test Loss = {test_loss:.6f}")
    
    plt.figure(figsize=(8,6))
    plt.plot(train_losses, label="Train Loss")
    plt.plot(test_losses, label="Test Loss")
    plt.xlabel("Epoch")
    plt.ylabel("MSE Loss")
    plt.legend()
    plt.title("Training and Test Loss Curves (FNO3d)")
    plt.show()
    
    return train_losses, test_losses

def visualize_sample_3d(model, test_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    with torch.no_grad():
        input_data, target = next(iter(test_loader))
        input_data = input_data.to(device)
        pred = model(input_data)
    sample_target = target[0].cpu().numpy()  # (T_out, H, W, 1)
    sample_pred = pred[0].cpu().numpy()      # (T_out, H, W, 1)
    times = [15, 20, 25, 30]  # target 시간 라벨
    T_out = sample_target.shape[0]
    plt.figure(figsize=(16, 4*T_out))
    for i in range(T_out):
        plt.subplot(T_out, 2, 2*i+1)
        plt.title(f"Ground Truth at t = {times[i]}")
        plt.imshow(sample_target[i, :, :, 0], cmap="RdBu", origin="lower")
        plt.colorbar()
        plt.subplot(T_out, 2, 2*i+2)
        plt.title(f"Prediction at t = {times[i]}")
        plt.imshow(sample_pred[i, :, :, 0], cmap="RdBu", origin="lower")
        plt.colorbar()
    plt.tight_layout()
    plt.show()

# %%
# =============================================================================
# 5. 전체 파이프라인 실행
# =============================================================================
if __name__ == '__main__':
    # PDE simulation parameters
    N = 64         # spatial resolution: 64x64
    dt = 0.005     # 시간 스텝 (안정성을 위해 충분히 작게)
    t_final = 50   # 최종 시각
    nu = 1e-3      # 점성 계수 (예시)
    
    # 데이터셋에서 사용할 시간 구간
    T_in_range = (0, 10)          # 입력: t=0 ~ 10 (정수 시간 스냅샷)
    T_out_times = [15, 20, 25, 30] # 타겟: t = 15,20,25,30
    
    num_train = 20   # 시연을 위한 샘플 수 (실제 연구에서는 더 많은 샘플 사용)
    num_test = 4
    
    # Navier–Stokes PDE solver를 통해 데이터 생성
    dataset_solver_train = NavierStokesDatasetFromSolver(num_samples=num_train, N=N, dt=dt, t_final=t_final, nu=nu, 
                                                          T_in_range=T_in_range, T_out_times=T_out_times)
    dataset_solver_test  = NavierStokesDatasetFromSolver(num_samples=num_test, N=N, dt=dt, t_final=t_final, nu=nu, 
                                                          T_in_range=T_in_range, T_out_times=T_out_times)
    
    train_loader = DataLoader(dataset_solver_train, batch_size=2, shuffle=True)
    test_loader = DataLoader(dataset_solver_test, batch_size=2, shuffle=False)
    
    # 모델 하이퍼파라미터: Fourier 모드 수 선택 (시간: 4, x: 16, y: 16), width: 32, T_out: 4
    modes_t, modes_x, modes_y = 4, 16, 16
    width = 32
    T_out = len(T_out_times)
    model = FNO3d(modes_t, modes_x, modes_y, width, T_out)
    
    # 학습
    train_losses, test_losses = train_model_3d(model, train_loader, test_loader, epochs=500)
    
    # 결과 시각화
    visualize_sample_3d(model, test_loader)
# Out:
# Epoch 001: Train Loss = 1.058080, Test Loss = 1.029156
# Epoch 002: Train Loss = 0.873941, Test Loss = 0.403046
# Epoch 003: Train Loss = 0.159772, Test Loss = 0.046997
# Epoch 004: Train Loss = 0.070025, Test Loss = 0.035723
# Epoch 005: Train Loss = 0.040661, Test Loss = 0.041558
# Epoch 006: Train Loss = 0.036134, Test Loss = 0.038897
# Epoch 007: Train Loss = 0.031446, Test Loss = 0.036242
# Epoch 008: Train Loss = 0.029936, Test Loss = 0.035887
# Epoch 009: Train Loss = 0.029985, Test Loss = 0.035519
# Epoch 010: Train Loss = 0.029184, Test Loss = 0.034590
# Epoch 011: Train Loss = 0.029143, Test Loss = 0.034091
# Epoch 012: Train Loss = 0.029172, Test Loss = 0.035060
# Epoch 013: Train Loss = 0.030588, Test Loss = 0.035686
# Epoch 014: Train Loss = 0.028944, Test Loss = 0.033853
# Epoch 015: Train Loss = 0.028631, Test Loss = 0.033854
# Epoch 016: Train Loss = 0.028444, Test Loss = 0.035538
# Epoch 017: Train Loss = 0.029862, Test Loss = 0.034006
# Epoch 018: Train Loss = 0.028484, Test Loss = 0.034378
# Epoch 019: Train Loss = 0.028241, Test Loss = 0.033467
# Epoch 020: Train Loss = 0.027948, Test Loss = 0.033240
# Epoch 021: Train Loss = 0.027788, Test Loss = 0.033598
# Epoch 022: Train Loss = 0.027935, Test Loss = 0.033577
# Epoch 023: Train Loss = 0.028417, Test Loss = 0.034502
# Epoch 024: Train Loss = 0.028194, Test Loss = 0.033397
# Epoch 025: Train Loss = 0.028273, Test Loss = 0.033618
# Epoch 026: Train Loss = 0.027682, Test Loss = 0.033083
# Epoch 027: Train Loss = 0.027811, Test Loss = 0.033274
# Epoch 028: Train Loss = 0.027916, Test Loss = 0.033862
# Epoch 029: Train Loss = 0.027929, Test Loss = 0.033639
# Epoch 030: Train Loss = 0.028325, Test Loss = 0.034105
# Epoch 031: Train Loss = 0.027730, Test Loss = 0.034246
# Epoch 032: Train Loss = 0.027952, Test Loss = 0.033677
# Epoch 033: Train Loss = 0.027548, Test Loss = 0.033393
# Epoch 034: Train Loss = 0.028094, Test Loss = 0.033124
# Epoch 035: Train Loss = 0.027774, Test Loss = 0.033356
# Epoch 036: Train Loss = 0.028130, Test Loss = 0.033789
# Epoch 037: Train Loss = 0.027607, Test Loss = 0.033684
# Epoch 038: Train Loss = 0.027672, Test Loss = 0.033414
# Epoch 039: Train Loss = 0.027533, Test Loss = 0.033447
# Epoch 040: Train Loss = 0.027170, Test Loss = 0.033387
# Epoch 041: Train Loss = 0.027423, Test Loss = 0.033426
# Epoch 042: Train Loss = 0.027482, Test Loss = 0.033981
# Epoch 043: Train Loss = 0.027358, Test Loss = 0.034136
# Epoch 044: Train Loss = 0.027526, Test Loss = 0.033895
# Epoch 045: Train Loss = 0.027466, Test Loss = 0.034202
# Epoch 046: Train Loss = 0.027336, Test Loss = 0.034063
# Epoch 047: Train Loss = 0.027071, Test Loss = 0.033700
# Epoch 048: Train Loss = 0.027149, Test Loss = 0.033652
# Epoch 049: Train Loss = 0.027180, Test Loss = 0.033671
# Epoch 050: Train Loss = 0.026905, Test Loss = 0.033809
# Epoch 051: Train Loss = 0.026853, Test Loss = 0.033882
# Epoch 052: Train Loss = 0.026999, Test Loss = 0.034057
# Epoch 053: Train Loss = 0.026924, Test Loss = 0.033660
# Epoch 054: Train Loss = 0.026839, Test Loss = 0.033783
# Epoch 055: Train Loss = 0.026881, Test Loss = 0.033954
# Epoch 056: Train Loss = 0.027039, Test Loss = 0.034468
# Epoch 057: Train Loss = 0.027032, Test Loss = 0.033959
# Epoch 058: Train Loss = 0.026862, Test Loss = 0.033674
# Epoch 059: Train Loss = 0.026787, Test Loss = 0.033756
# Epoch 060: Train Loss = 0.026742, Test Loss = 0.033746
# Epoch 061: Train Loss = 0.026719, Test Loss = 0.033865
# Epoch 062: Train Loss = 0.026698, Test Loss = 0.033900
# Epoch 063: Train Loss = 0.026650, Test Loss = 0.033973
# Epoch 064: Train Loss = 0.026650, Test Loss = 0.033994
# Epoch 065: Train Loss = 0.026641, Test Loss = 0.033923
# Epoch 066: Train Loss = 0.026641, Test Loss = 0.033920
# Epoch 067: Train Loss = 0.026625, Test Loss = 0.033964
# Epoch 068: Train Loss = 0.026633, Test Loss = 0.034004
# Epoch 069: Train Loss = 0.026644, Test Loss = 0.034124
# Epoch 070: Train Loss = 0.026623, Test Loss = 0.033998
# Epoch 071: Train Loss = 0.026607, Test Loss = 0.034027
# Epoch 072: Train Loss = 0.026605, Test Loss = 0.034050
# Epoch 073: Train Loss = 0.026596, Test Loss = 0.034062
# Epoch 074: Train Loss = 0.026586, Test Loss = 0.034090
# Epoch 075: Train Loss = 0.026591, Test Loss = 0.034182
# Epoch 076: Train Loss = 0.026576, Test Loss = 0.034160
# Epoch 077: Train Loss = 0.026574, Test Loss = 0.034123
# Epoch 078: Train Loss = 0.026570, Test Loss = 0.034118
# Epoch 079: Train Loss = 0.026567, Test Loss = 0.034082
# Epoch 080: Train Loss = 0.026566, Test Loss = 0.034105
# Epoch 081: Train Loss = 0.026564, Test Loss = 0.034136
# Epoch 082: Train Loss = 0.026563, Test Loss = 0.034116
# Epoch 083: Train Loss = 0.026556, Test Loss = 0.034098
# Epoch 084: Train Loss = 0.026559, Test Loss = 0.034130
# Epoch 085: Train Loss = 0.026559, Test Loss = 0.034198
# Epoch 086: Train Loss = 0.026568, Test Loss = 0.034140
# Epoch 087: Train Loss = 0.026573, Test Loss = 0.034129
# Epoch 088: Train Loss = 0.026567, Test Loss = 0.034180
# Epoch 089: Train Loss = 0.026560, Test Loss = 0.034184
# Epoch 090: Train Loss = 0.026553, Test Loss = 0.034153
# Epoch 091: Train Loss = 0.026552, Test Loss = 0.034128
# Epoch 092: Train Loss = 0.026552, Test Loss = 0.034215
# Epoch 093: Train Loss = 0.026557, Test Loss = 0.034215
# Epoch 094: Train Loss = 0.026556, Test Loss = 0.034164
# Epoch 095: Train Loss = 0.026554, Test Loss = 0.034239
# Epoch 096: Train Loss = 0.026551, Test Loss = 0.034171
# Epoch 097: Train Loss = 0.026548, Test Loss = 0.034118
# Epoch 098: Train Loss = 0.026546, Test Loss = 0.034159
# Epoch 099: Train Loss = 0.026547, Test Loss = 0.034209
# Epoch 100: Train Loss = 0.026547, Test Loss = 0.034162
# Epoch 101: Train Loss = 0.026546, Test Loss = 0.034174
# Epoch 102: Train Loss = 0.026545, Test Loss = 0.034120
# Epoch 103: Train Loss = 0.026544, Test Loss = 0.034113
# Epoch 104: Train Loss = 0.026545, Test Loss = 0.034119
# Epoch 105: Train Loss = 0.026545, Test Loss = 0.034144
# Epoch 106: Train Loss = 0.026543, Test Loss = 0.034152
# Epoch 107: Train Loss = 0.026543, Test Loss = 0.034175
# Epoch 108: Train Loss = 0.026542, Test Loss = 0.034161
# Epoch 109: Train Loss = 0.026542, Test Loss = 0.034159
# Epoch 110: Train Loss = 0.026542, Test Loss = 0.034183
# Epoch 111: Train Loss = 0.026541, Test Loss = 0.034148
# Epoch 112: Train Loss = 0.026541, Test Loss = 0.034154
# Epoch 113: Train Loss = 0.026541, Test Loss = 0.034156
# Epoch 114: Train Loss = 0.026541, Test Loss = 0.034141
# Epoch 115: Train Loss = 0.026541, Test Loss = 0.034144
# Epoch 116: Train Loss = 0.026541, Test Loss = 0.034166
# Epoch 117: Train Loss = 0.026541, Test Loss = 0.034172
# Epoch 118: Train Loss = 0.026541, Test Loss = 0.034173
# Epoch 119: Train Loss = 0.026541, Test Loss = 0.034145
# Epoch 120: Train Loss = 0.026541, Test Loss = 0.034155
# Epoch 121: Train Loss = 0.026540, Test Loss = 0.034163
# Epoch 122: Train Loss = 0.026541, Test Loss = 0.034171
# Epoch 123: Train Loss = 0.026541, Test Loss = 0.034158
# Epoch 124: Train Loss = 0.026540, Test Loss = 0.034147
# Epoch 125: Train Loss = 0.026540, Test Loss = 0.034152
# Epoch 126: Train Loss = 0.026540, Test Loss = 0.034172
# Epoch 127: Train Loss = 0.026540, Test Loss = 0.034152
# Epoch 128: Train Loss = 0.026540, Test Loss = 0.034151
# Epoch 129: Train Loss = 0.026540, Test Loss = 0.034164
# Epoch 130: Train Loss = 0.026540, Test Loss = 0.034179
# Epoch 131: Train Loss = 0.026541, Test Loss = 0.034182
# Epoch 132: Train Loss = 0.026542, Test Loss = 0.034164
# Epoch 133: Train Loss = 0.026542, Test Loss = 0.034156
# Epoch 134: Train Loss = 0.026542, Test Loss = 0.034211
# Epoch 135: Train Loss = 0.026543, Test Loss = 0.034222
# Epoch 136: Train Loss = 0.026542, Test Loss = 0.034158
# Epoch 137: Train Loss = 0.026547, Test Loss = 0.034139
# Epoch 138: Train Loss = 0.026548, Test Loss = 0.034183
# Epoch 139: Train Loss = 0.026553, Test Loss = 0.034222
# Epoch 140: Train Loss = 0.026550, Test Loss = 0.034190
# Epoch 141: Train Loss = 0.026554, Test Loss = 0.034129
# Epoch 142: Train Loss = 0.026557, Test Loss = 0.034059
# Epoch 143: Train Loss = 0.026552, Test Loss = 0.034114
# Epoch 144: Train Loss = 0.026550, Test Loss = 0.034153
# Epoch 145: Train Loss = 0.026550, Test Loss = 0.034158
# Epoch 146: Train Loss = 0.026552, Test Loss = 0.034146
# Epoch 147: Train Loss = 0.026550, Test Loss = 0.034197
# Epoch 148: Train Loss = 0.026547, Test Loss = 0.034117
# Epoch 149: Train Loss = 0.026547, Test Loss = 0.034117
# Epoch 150: Train Loss = 0.026545, Test Loss = 0.034131
# Epoch 151: Train Loss = 0.026547, Test Loss = 0.034134
# Epoch 152: Train Loss = 0.026551, Test Loss = 0.034060
# Epoch 153: Train Loss = 0.026555, Test Loss = 0.034035
# Epoch 154: Train Loss = 0.026579, Test Loss = 0.034161
# Epoch 155: Train Loss = 0.026566, Test Loss = 0.034150
# Epoch 156: Train Loss = 0.026551, Test Loss = 0.034286
# Epoch 157: Train Loss = 0.026574, Test Loss = 0.034184
# Epoch 158: Train Loss = 0.026570, Test Loss = 0.034083
# Epoch 159: Train Loss = 0.026577, Test Loss = 0.034207
# Epoch 160: Train Loss = 0.026595, Test Loss = 0.034129
# Epoch 161: Train Loss = 0.026646, Test Loss = 0.034409
# Epoch 162: Train Loss = 0.026654, Test Loss = 0.033890
# Epoch 163: Train Loss = 0.026618, Test Loss = 0.034184
# Epoch 164: Train Loss = 0.026671, Test Loss = 0.033997
# Epoch 165: Train Loss = 0.026723, Test Loss = 0.034272
# Epoch 166: Train Loss = 0.026690, Test Loss = 0.034234
# Epoch 167: Train Loss = 0.026695, Test Loss = 0.034140
# Epoch 168: Train Loss = 0.026655, Test Loss = 0.034076
# Epoch 169: Train Loss = 0.026605, Test Loss = 0.034135
# Epoch 170: Train Loss = 0.026594, Test Loss = 0.034192
# Epoch 171: Train Loss = 0.026625, Test Loss = 0.034146
# Epoch 172: Train Loss = 0.026595, Test Loss = 0.034126
# Epoch 173: Train Loss = 0.026624, Test Loss = 0.034307
# Epoch 174: Train Loss = 0.026619, Test Loss = 0.034205
# Epoch 175: Train Loss = 0.026595, Test Loss = 0.034114
# Epoch 176: Train Loss = 0.026596, Test Loss = 0.034147
# Epoch 177: Train Loss = 0.026573, Test Loss = 0.034057
# Epoch 178: Train Loss = 0.026615, Test Loss = 0.034199
# Epoch 179: Train Loss = 0.026650, Test Loss = 0.034249
# Epoch 180: Train Loss = 0.026639, Test Loss = 0.034410
# Epoch 181: Train Loss = 0.026613, Test Loss = 0.034095
# Epoch 182: Train Loss = 0.026589, Test Loss = 0.034196
# Epoch 183: Train Loss = 0.026576, Test Loss = 0.034153
# Epoch 184: Train Loss = 0.026584, Test Loss = 0.034013
# Epoch 185: Train Loss = 0.026567, Test Loss = 0.034142
# Epoch 186: Train Loss = 0.026566, Test Loss = 0.034198
# Epoch 187: Train Loss = 0.026566, Test Loss = 0.033976
# Epoch 188: Train Loss = 0.026558, Test Loss = 0.033940
# Epoch 189: Train Loss = 0.026555, Test Loss = 0.034080
# Epoch 190: Train Loss = 0.026557, Test Loss = 0.034075
# Epoch 191: Train Loss = 0.026549, Test Loss = 0.034095
# Epoch 192: Train Loss = 0.026550, Test Loss = 0.033953
# Epoch 193: Train Loss = 0.026544, Test Loss = 0.033982
# Epoch 194: Train Loss = 0.026546, Test Loss = 0.034018
# Epoch 195: Train Loss = 0.026543, Test Loss = 0.033979
# Epoch 196: Train Loss = 0.026545, Test Loss = 0.034001
# Epoch 197: Train Loss = 0.026544, Test Loss = 0.034003
# Epoch 198: Train Loss = 0.026544, Test Loss = 0.034015
# Epoch 199: Train Loss = 0.026544, Test Loss = 0.033985
# Epoch 200: Train Loss = 0.026545, Test Loss = 0.034008
# Epoch 201: Train Loss = 0.026545, Test Loss = 0.034102
# Epoch 202: Train Loss = 0.026553, Test Loss = 0.034008
# Epoch 203: Train Loss = 0.026547, Test Loss = 0.034002
# Epoch 204: Train Loss = 0.026547, Test Loss = 0.033988
# Epoch 205: Train Loss = 0.026543, Test Loss = 0.033973
# Epoch 206: Train Loss = 0.026542, Test Loss = 0.033993
# Epoch 207: Train Loss = 0.026542, Test Loss = 0.033984
# Epoch 208: Train Loss = 0.026542, Test Loss = 0.034005
# Epoch 209: Train Loss = 0.026543, Test Loss = 0.033986
# Epoch 210: Train Loss = 0.026544, Test Loss = 0.034021
# Epoch 211: Train Loss = 0.026544, Test Loss = 0.034048
# Epoch 212: Train Loss = 0.026551, Test Loss = 0.034048
# Epoch 213: Train Loss = 0.026547, Test Loss = 0.033999
# Epoch 214: Train Loss = 0.026547, Test Loss = 0.033968
# Epoch 215: Train Loss = 0.026555, Test Loss = 0.033959
# Epoch 216: Train Loss = 0.026546, Test Loss = 0.033963
# Epoch 217: Train Loss = 0.026543, Test Loss = 0.033991
# Epoch 218: Train Loss = 0.026546, Test Loss = 0.034012
# Epoch 219: Train Loss = 0.026548, Test Loss = 0.034051
# Epoch 220: Train Loss = 0.026550, Test Loss = 0.033974
# Epoch 221: Train Loss = 0.026552, Test Loss = 0.034008
# Epoch 222: Train Loss = 0.026551, Test Loss = 0.034038
# Epoch 223: Train Loss = 0.026547, Test Loss = 0.034054
# Epoch 224: Train Loss = 0.026546, Test Loss = 0.034030
# Epoch 225: Train Loss = 0.026545, Test Loss = 0.034015
# Epoch 226: Train Loss = 0.026547, Test Loss = 0.034052
# Epoch 227: Train Loss = 0.026547, Test Loss = 0.034060
# Epoch 228: Train Loss = 0.026546, Test Loss = 0.034029
# Epoch 229: Train Loss = 0.026550, Test Loss = 0.033980
# Epoch 230: Train Loss = 0.026548, Test Loss = 0.033940
# Epoch 231: Train Loss = 0.026550, Test Loss = 0.033980
# Epoch 232: Train Loss = 0.026574, Test Loss = 0.034113
# Epoch 233: Train Loss = 0.026608, Test Loss = 0.034104
# Epoch 234: Train Loss = 0.026709, Test Loss = 0.034193
# Epoch 235: Train Loss = 0.026684, Test Loss = 0.034281
# Epoch 236: Train Loss = 0.026724, Test Loss = 0.034084
# Epoch 237: Train Loss = 0.026698, Test Loss = 0.033746
# Epoch 238: Train Loss = 0.026627, Test Loss = 0.033718
# Epoch 239: Train Loss = 0.026691, Test Loss = 0.033872
# Epoch 240: Train Loss = 0.026635, Test Loss = 0.033849
# Epoch 241: Train Loss = 0.026635, Test Loss = 0.033961
# Epoch 242: Train Loss = 0.026643, Test Loss = 0.034170
# Epoch 243: Train Loss = 0.026658, Test Loss = 0.033864
# Epoch 244: Train Loss = 0.026630, Test Loss = 0.033935
# Epoch 245: Train Loss = 0.026613, Test Loss = 0.033889
# Epoch 246: Train Loss = 0.026664, Test Loss = 0.033948
# Epoch 247: Train Loss = 0.026726, Test Loss = 0.034053
# Epoch 248: Train Loss = 0.026825, Test Loss = 0.033792
# Epoch 249: Train Loss = 0.026952, Test Loss = 0.033753
# Epoch 250: Train Loss = 0.026869, Test Loss = 0.033884
# Epoch 251: Train Loss = 0.026836, Test Loss = 0.033751
# Epoch 252: Train Loss = 0.026859, Test Loss = 0.034633
# Epoch 253: Train Loss = 0.026704, Test Loss = 0.033795
# Epoch 254: Train Loss = 0.026768, Test Loss = 0.033746
# Epoch 255: Train Loss = 0.026663, Test Loss = 0.033778
# Epoch 256: Train Loss = 0.026725, Test Loss = 0.034063
# Epoch 257: Train Loss = 0.026892, Test Loss = 0.034210
# Epoch 258: Train Loss = 0.026828, Test Loss = 0.033900
# Epoch 259: Train Loss = 0.026713, Test Loss = 0.033800
# Epoch 260: Train Loss = 0.026685, Test Loss = 0.033645
# Epoch 261: Train Loss = 0.026613, Test Loss = 0.033650
# Epoch 262: Train Loss = 0.026623, Test Loss = 0.033668
# Epoch 263: Train Loss = 0.026601, Test Loss = 0.033818
# Epoch 264: Train Loss = 0.026649, Test Loss = 0.034023
# Epoch 265: Train Loss = 0.026696, Test Loss = 0.033813
# Epoch 266: Train Loss = 0.026644, Test Loss = 0.033794
# Epoch 267: Train Loss = 0.026579, Test Loss = 0.033870
# Epoch 268: Train Loss = 0.026618, Test Loss = 0.033846
# Epoch 269: Train Loss = 0.026584, Test Loss = 0.033749
# Epoch 270: Train Loss = 0.026555, Test Loss = 0.033806
# Epoch 271: Train Loss = 0.026559, Test Loss = 0.033731
# Epoch 272: Train Loss = 0.026562, Test Loss = 0.033721
# Epoch 273: Train Loss = 0.026589, Test Loss = 0.033696
# Epoch 274: Train Loss = 0.026586, Test Loss = 0.033766
# Epoch 275: Train Loss = 0.026580, Test Loss = 0.033743
# Epoch 276: Train Loss = 0.026561, Test Loss = 0.033738
# Epoch 277: Train Loss = 0.026554, Test Loss = 0.033739
# Epoch 278: Train Loss = 0.026563, Test Loss = 0.033770
# Epoch 279: Train Loss = 0.026553, Test Loss = 0.033711
# Epoch 280: Train Loss = 0.026550, Test Loss = 0.033729
# Epoch 281: Train Loss = 0.026562, Test Loss = 0.033820
# Epoch 282: Train Loss = 0.026571, Test Loss = 0.033785
# Epoch 283: Train Loss = 0.026554, Test Loss = 0.033813
# Epoch 284: Train Loss = 0.026552, Test Loss = 0.033823
# Epoch 285: Train Loss = 0.026556, Test Loss = 0.033773
# Epoch 286: Train Loss = 0.026556, Test Loss = 0.033775
# Epoch 287: Train Loss = 0.026566, Test Loss = 0.033861
# Epoch 288: Train Loss = 0.026564, Test Loss = 0.033713
# Epoch 289: Train Loss = 0.026551, Test Loss = 0.033756
# Epoch 290: Train Loss = 0.026548, Test Loss = 0.033722
# Epoch 291: Train Loss = 0.026549, Test Loss = 0.033730
# Epoch 292: Train Loss = 0.026545, Test Loss = 0.033750
# Epoch 293: Train Loss = 0.026543, Test Loss = 0.033703
# Epoch 294: Train Loss = 0.026541, Test Loss = 0.033714
# Epoch 295: Train Loss = 0.026542, Test Loss = 0.033720
# Epoch 296: Train Loss = 0.026543, Test Loss = 0.033729
# Epoch 297: Train Loss = 0.026541, Test Loss = 0.033738
# Epoch 298: Train Loss = 0.026541, Test Loss = 0.033743
# Epoch 299: Train Loss = 0.026541, Test Loss = 0.033740
# Epoch 300: Train Loss = 0.026541, Test Loss = 0.033746
# Epoch 301: Train Loss = 0.026541, Test Loss = 0.033729
# Epoch 302: Train Loss = 0.026540, Test Loss = 0.033742
# Epoch 303: Train Loss = 0.026542, Test Loss = 0.033740
# Epoch 304: Train Loss = 0.026546, Test Loss = 0.033749
# Epoch 305: Train Loss = 0.026546, Test Loss = 0.033703
# Epoch 306: Train Loss = 0.026547, Test Loss = 0.033737
# Epoch 307: Train Loss = 0.026546, Test Loss = 0.033751
# Epoch 308: Train Loss = 0.026544, Test Loss = 0.033746
# Epoch 309: Train Loss = 0.026545, Test Loss = 0.033765
# Epoch 310: Train Loss = 0.026547, Test Loss = 0.033794
# Epoch 311: Train Loss = 0.026550, Test Loss = 0.033763
# Epoch 312: Train Loss = 0.026549, Test Loss = 0.033700
# Epoch 313: Train Loss = 0.026553, Test Loss = 0.033755
# Epoch 314: Train Loss = 0.026549, Test Loss = 0.033736
# Epoch 315: Train Loss = 0.026546, Test Loss = 0.033733
# Epoch 316: Train Loss = 0.026547, Test Loss = 0.033749
# Epoch 317: Train Loss = 0.026545, Test Loss = 0.033736
# Epoch 318: Train Loss = 0.026542, Test Loss = 0.033743
# Epoch 319: Train Loss = 0.026542, Test Loss = 0.033764
# Epoch 320: Train Loss = 0.026548, Test Loss = 0.033751
# Epoch 321: Train Loss = 0.026549, Test Loss = 0.033761
# Epoch 322: Train Loss = 0.026555, Test Loss = 0.033729
# Epoch 323: Train Loss = 0.026548, Test Loss = 0.033753
# Epoch 324: Train Loss = 0.026546, Test Loss = 0.033723
# Epoch 325: Train Loss = 0.026546, Test Loss = 0.033723
# Epoch 326: Train Loss = 0.026550, Test Loss = 0.033722
# Epoch 327: Train Loss = 0.026547, Test Loss = 0.033736
# Epoch 328: Train Loss = 0.026557, Test Loss = 0.033719
# Epoch 329: Train Loss = 0.026550, Test Loss = 0.033700
# Epoch 330: Train Loss = 0.026570, Test Loss = 0.033739
# Epoch 331: Train Loss = 0.026556, Test Loss = 0.033726
# Epoch 332: Train Loss = 0.026554, Test Loss = 0.033749
# Epoch 333: Train Loss = 0.026552, Test Loss = 0.033743
# Epoch 334: Train Loss = 0.026550, Test Loss = 0.033764
# Epoch 335: Train Loss = 0.026568, Test Loss = 0.033672
# Epoch 336: Train Loss = 0.026564, Test Loss = 0.033751
# Epoch 337: Train Loss = 0.026561, Test Loss = 0.033744
# Epoch 338: Train Loss = 0.026559, Test Loss = 0.033825
# Epoch 339: Train Loss = 0.026564, Test Loss = 0.033729
# Epoch 340: Train Loss = 0.026565, Test Loss = 0.033697
# Epoch 341: Train Loss = 0.026577, Test Loss = 0.033783
# Epoch 342: Train Loss = 0.026568, Test Loss = 0.033772
# Epoch 343: Train Loss = 0.026563, Test Loss = 0.033718
# Epoch 344: Train Loss = 0.026594, Test Loss = 0.033678
# Epoch 345: Train Loss = 0.026596, Test Loss = 0.033578
# Epoch 346: Train Loss = 0.026601, Test Loss = 0.033750
# Epoch 347: Train Loss = 0.026600, Test Loss = 0.033686
# Epoch 348: Train Loss = 0.026587, Test Loss = 0.033729
# Epoch 349: Train Loss = 0.026642, Test Loss = 0.033892
# Epoch 350: Train Loss = 0.026644, Test Loss = 0.033566
# Epoch 351: Train Loss = 0.026776, Test Loss = 0.033650
# Epoch 352: Train Loss = 0.026866, Test Loss = 0.033974
# Epoch 353: Train Loss = 0.026688, Test Loss = 0.033772
# Epoch 354: Train Loss = 0.026727, Test Loss = 0.033714
# Epoch 355: Train Loss = 0.026891, Test Loss = 0.033778
# Epoch 356: Train Loss = 0.027002, Test Loss = 0.034008
# Epoch 357: Train Loss = 0.027085, Test Loss = 0.033807
# Epoch 358: Train Loss = 0.027352, Test Loss = 0.034092
# Epoch 359: Train Loss = 0.026836, Test Loss = 0.033785
# Epoch 360: Train Loss = 0.026823, Test Loss = 0.033976
# Epoch 361: Train Loss = 0.026826, Test Loss = 0.034061
# Epoch 362: Train Loss = 0.026780, Test Loss = 0.033777
# Epoch 363: Train Loss = 0.026656, Test Loss = 0.033597
# Epoch 364: Train Loss = 0.026672, Test Loss = 0.033536
# Epoch 365: Train Loss = 0.026712, Test Loss = 0.033559
# Epoch 366: Train Loss = 0.026729, Test Loss = 0.033766
# Epoch 367: Train Loss = 0.026680, Test Loss = 0.033631
# Epoch 368: Train Loss = 0.026616, Test Loss = 0.033616
# Epoch 369: Train Loss = 0.026600, Test Loss = 0.033589
# Epoch 370: Train Loss = 0.026636, Test Loss = 0.033571
# Epoch 371: Train Loss = 0.026677, Test Loss = 0.033777
# Epoch 372: Train Loss = 0.026709, Test Loss = 0.033754
# Epoch 373: Train Loss = 0.026648, Test Loss = 0.033730
# Epoch 374: Train Loss = 0.026611, Test Loss = 0.033677
# Epoch 375: Train Loss = 0.026589, Test Loss = 0.033740
# Epoch 376: Train Loss = 0.026572, Test Loss = 0.033687
# Epoch 377: Train Loss = 0.026570, Test Loss = 0.033602
# Epoch 378: Train Loss = 0.026587, Test Loss = 0.033619
# Epoch 379: Train Loss = 0.026562, Test Loss = 0.033677
# Epoch 380: Train Loss = 0.026566, Test Loss = 0.033590
# Epoch 381: Train Loss = 0.026568, Test Loss = 0.033634
# Epoch 382: Train Loss = 0.026569, Test Loss = 0.033536
# Epoch 383: Train Loss = 0.026554, Test Loss = 0.033560
# Epoch 384: Train Loss = 0.026550, Test Loss = 0.033546
# Epoch 385: Train Loss = 0.026548, Test Loss = 0.033588
# Epoch 386: Train Loss = 0.026552, Test Loss = 0.033557
# Epoch 387: Train Loss = 0.026548, Test Loss = 0.033539
# Epoch 388: Train Loss = 0.026545, Test Loss = 0.033565
# Epoch 389: Train Loss = 0.026544, Test Loss = 0.033591
# Epoch 390: Train Loss = 0.026544, Test Loss = 0.033539
# Epoch 391: Train Loss = 0.026543, Test Loss = 0.033591
# Epoch 392: Train Loss = 0.026543, Test Loss = 0.033565
# Epoch 393: Train Loss = 0.026546, Test Loss = 0.033555
# Epoch 394: Train Loss = 0.026545, Test Loss = 0.033553
# Epoch 395: Train Loss = 0.026541, Test Loss = 0.033541
# Epoch 396: Train Loss = 0.026541, Test Loss = 0.033549
# Epoch 397: Train Loss = 0.026541, Test Loss = 0.033569
# Epoch 398: Train Loss = 0.026545, Test Loss = 0.033592
# Epoch 399: Train Loss = 0.026546, Test Loss = 0.033547
# Epoch 400: Train Loss = 0.026545, Test Loss = 0.033523
# Epoch 401: Train Loss = 0.026544, Test Loss = 0.033573
# Epoch 402: Train Loss = 0.026545, Test Loss = 0.033632
# Epoch 403: Train Loss = 0.026546, Test Loss = 0.033544
# Epoch 404: Train Loss = 0.026547, Test Loss = 0.033541
# Epoch 405: Train Loss = 0.026542, Test Loss = 0.033557
# Epoch 406: Train Loss = 0.026544, Test Loss = 0.033625
# Epoch 407: Train Loss = 0.026544, Test Loss = 0.033589
# Epoch 408: Train Loss = 0.026544, Test Loss = 0.033628
# Epoch 409: Train Loss = 0.026543, Test Loss = 0.033594
# Epoch 410: Train Loss = 0.026542, Test Loss = 0.033571
# Epoch 411: Train Loss = 0.026544, Test Loss = 0.033564
# Epoch 412: Train Loss = 0.026544, Test Loss = 0.033584
# Epoch 413: Train Loss = 0.026544, Test Loss = 0.033549
# Epoch 414: Train Loss = 0.026544, Test Loss = 0.033558
# Epoch 415: Train Loss = 0.026542, Test Loss = 0.033596
# Epoch 416: Train Loss = 0.026544, Test Loss = 0.033592
# Epoch 417: Train Loss = 0.026547, Test Loss = 0.033560
# Epoch 418: Train Loss = 0.026545, Test Loss = 0.033610
# Epoch 419: Train Loss = 0.026548, Test Loss = 0.033591
# Epoch 420: Train Loss = 0.026547, Test Loss = 0.033562
# Epoch 421: Train Loss = 0.026549, Test Loss = 0.033583
# Epoch 422: Train Loss = 0.026547, Test Loss = 0.033533
# Epoch 423: Train Loss = 0.026556, Test Loss = 0.033539
# Epoch 424: Train Loss = 0.026546, Test Loss = 0.033558
# Epoch 425: Train Loss = 0.026549, Test Loss = 0.033597
# Epoch 426: Train Loss = 0.026549, Test Loss = 0.033575
# Epoch 427: Train Loss = 0.026548, Test Loss = 0.033605
# Epoch 428: Train Loss = 0.026546, Test Loss = 0.033558
# Epoch 429: Train Loss = 0.026544, Test Loss = 0.033554
# Epoch 430: Train Loss = 0.026547, Test Loss = 0.033568
# Epoch 431: Train Loss = 0.026547, Test Loss = 0.033551
# Epoch 432: Train Loss = 0.026549, Test Loss = 0.033561
# Epoch 433: Train Loss = 0.026567, Test Loss = 0.033667
# Epoch 434: Train Loss = 0.026608, Test Loss = 0.033682
# Epoch 435: Train Loss = 0.026627, Test Loss = 0.033797
# Epoch 436: Train Loss = 0.026692, Test Loss = 0.033606
# Epoch 437: Train Loss = 0.026642, Test Loss = 0.033906
# Epoch 438: Train Loss = 0.026671, Test Loss = 0.033684
# Epoch 439: Train Loss = 0.026568, Test Loss = 0.033582
# Epoch 440: Train Loss = 0.026605, Test Loss = 0.033601
# Epoch 441: Train Loss = 0.026650, Test Loss = 0.033617
# Epoch 442: Train Loss = 0.026671, Test Loss = 0.033582
# Epoch 443: Train Loss = 0.026635, Test Loss = 0.033597
# Epoch 444: Train Loss = 0.026656, Test Loss = 0.033802
# Epoch 445: Train Loss = 0.026642, Test Loss = 0.033490
# Epoch 446: Train Loss = 0.026631, Test Loss = 0.033593
# Epoch 447: Train Loss = 0.026612, Test Loss = 0.033555
# Epoch 448: Train Loss = 0.026606, Test Loss = 0.033534
# Epoch 449: Train Loss = 0.026602, Test Loss = 0.033524
# Epoch 450: Train Loss = 0.026581, Test Loss = 0.033535
# Epoch 451: Train Loss = 0.026570, Test Loss = 0.033543
# Epoch 452: Train Loss = 0.026617, Test Loss = 0.033529
# Epoch 453: Train Loss = 0.026628, Test Loss = 0.033589
# Epoch 454: Train Loss = 0.026612, Test Loss = 0.033599
# Epoch 455: Train Loss = 0.026669, Test Loss = 0.033566
# Epoch 456: Train Loss = 0.026636, Test Loss = 0.033597
# Epoch 457: Train Loss = 0.026617, Test Loss = 0.033632
# Epoch 458: Train Loss = 0.026620, Test Loss = 0.033603
# Epoch 459: Train Loss = 0.026598, Test Loss = 0.033507
# Epoch 460: Train Loss = 0.026661, Test Loss = 0.033452
# Epoch 461: Train Loss = 0.026612, Test Loss = 0.033426
# Epoch 462: Train Loss = 0.026637, Test Loss = 0.033553
# Epoch 463: Train Loss = 0.026608, Test Loss = 0.033492
# Epoch 464: Train Loss = 0.026640, Test Loss = 0.033581
# Epoch 465: Train Loss = 0.026604, Test Loss = 0.033537
# Epoch 466: Train Loss = 0.026575, Test Loss = 0.033519
# Epoch 467: Train Loss = 0.026583, Test Loss = 0.033411
# Epoch 468: Train Loss = 0.026577, Test Loss = 0.033422
# Epoch 469: Train Loss = 0.026555, Test Loss = 0.033467
# Epoch 470: Train Loss = 0.026554, Test Loss = 0.033458
# Epoch 471: Train Loss = 0.026566, Test Loss = 0.033488
# Epoch 472: Train Loss = 0.026562, Test Loss = 0.033562
# Epoch 473: Train Loss = 0.026566, Test Loss = 0.033571
# Epoch 474: Train Loss = 0.026614, Test Loss = 0.033744
# Epoch 475: Train Loss = 0.026643, Test Loss = 0.033586
# Epoch 476: Train Loss = 0.026595, Test Loss = 0.033437
# Epoch 477: Train Loss = 0.026601, Test Loss = 0.033606
# Epoch 478: Train Loss = 0.026580, Test Loss = 0.033663
# Epoch 479: Train Loss = 0.026595, Test Loss = 0.033610
# Epoch 480: Train Loss = 0.026585, Test Loss = 0.033576
# Epoch 481: Train Loss = 0.026606, Test Loss = 0.033605
# Epoch 482: Train Loss = 0.026613, Test Loss = 0.033717
# Epoch 483: Train Loss = 0.026627, Test Loss = 0.033615
# Epoch 484: Train Loss = 0.026574, Test Loss = 0.033530
# Epoch 485: Train Loss = 0.026573, Test Loss = 0.033514
# Epoch 486: Train Loss = 0.026571, Test Loss = 0.033436
# Epoch 487: Train Loss = 0.026577, Test Loss = 0.033528
# Epoch 488: Train Loss = 0.026557, Test Loss = 0.033493
# Epoch 489: Train Loss = 0.026567, Test Loss = 0.033498
# Epoch 490: Train Loss = 0.026564, Test Loss = 0.033472
# Epoch 491: Train Loss = 0.026579, Test Loss = 0.033446
# Epoch 492: Train Loss = 0.026559, Test Loss = 0.033436
# Epoch 493: Train Loss = 0.026555, Test Loss = 0.033447
# Epoch 494: Train Loss = 0.026562, Test Loss = 0.033415
# Epoch 495: Train Loss = 0.026550, Test Loss = 0.033522
# Epoch 496: Train Loss = 0.026554, Test Loss = 0.033501
# Epoch 497: Train Loss = 0.026567, Test Loss = 0.033458
# Epoch 498: Train Loss = 0.026571, Test Loss = 0.033650
# Epoch 499: Train Loss = 0.026589, Test Loss = 0.033540
# Epoch 500: Train Loss = 0.026583, Test Loss = 0.033481

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import torch

def animate_ground_truth_and_prediction(model, test_loader, save_path='combined_animation.gif'):
    """
    테스트 데이터셋의 첫 번째 샘플에 대해, ground truth와 FNO 모델의 예측 결과를
    시간에 따른 continuous animation으로 생성하여 .gif 파일로 저장합니다.
    모델 출력과 타겟의 shape은 (batch, T_out, H, W, 1)이어야 합니다.
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.eval()
    with torch.no_grad():
        input_data, target = next(iter(test_loader))
        input_data = input_data.to(device)
        pred = model(input_data)  # pred shape: (batch, T_out, H, W, 1)
    
    # 첫 번째 샘플 선택
    sample_target = target[0].cpu().numpy()  # (T_out, H, W, 1)
    sample_pred = pred[0].cpu().numpy()      # (T_out, H, W, 1)
    T_out = sample_target.shape[0]
    # 시간 라벨 (예: t = 15, 20, 25, 30 등, T_out에 맞게)
    times = [15, 20, 25, 30][:T_out]
    
    # 두 개의 서브플롯을 가진 Figure 생성 (좌측: Ground Truth, 우측: Prediction)
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))
    im1 = ax1.imshow(sample_target[0, :, :, 0], cmap="RdBu", origin="lower")
    ax1.set_title(f"Ground Truth at t = {times[0]}")
    plt.colorbar(im1, ax=ax1)
    
    im2 = ax2.imshow(sample_pred[0, :, :, 0], cmap="RdBu", origin="lower")
    ax2.set_title(f"FNO Prediction at t = {times[0]}")
    plt.colorbar(im2, ax=ax2)
    
    def update(frame):
        im1.set_data(sample_target[frame, :, :, 0])
        im2.set_data(sample_pred[frame, :, :, 0])
        ax1.set_title(f"Ground Truth at t = {times[frame]}")
        ax2.set_title(f"FNO Prediction at t = {times[frame]}")
        return [im1, im2]
    
    ani = animation.FuncAnimation(fig, update, frames=T_out, interval=800, blit=True)
    writer = animation.PillowWriter(fps=2)
    ani.save(save_path, writer=writer)
    print("Animation saved as", save_path)
    plt.close(fig)
    return ani

# 사용 예시:
# model과 test_loader는 이미 학습된 FNO 모델과 테스트 데이터로더라고 가정합니다.
ani = animate_ground_truth_and_prediction(model, test_loader, save_path='combined_animation.gif')
# Out:
# Animation saved as combined_animation.gif

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import torch

def create_FNO_motion_animation(model, test_loader, save_path='FNO_motion.gif'):
    """
    FNO 모델이 예측한 motion을 애니메이션으로 생성하여 .gif 파일로 저장합니다.
    모델은 (batch, T_out, H, W, 1) 형태의 예측 결과를 출력한다고 가정합니다.
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.eval()
    with torch.no_grad():
        # 테스트 데이터의 첫 배치에서 첫 번째 샘플 사용
        input_data, target = next(iter(test_loader))
        input_data = input_data.to(device)
        pred = model(input_data)  # pred shape: (batch, T_out, H, W, 1)
    sample_pred = pred[0].cpu().numpy()  # (T_out, H, W, 1)
    T_out, H, W, _ = sample_pred.shape
    
    # 예를 들어, FNO가 예측한 시간 스텝이 t = 15, 20, 25, 30이라면:
    times = [15, 20, 25, 30][:T_out]
    
    fig, ax = plt.subplots()
    im = ax.imshow(sample_pred[0, :, :, 0], cmap="RdBu", origin="lower")
    ax.set_title("FNO Predicted Motion at t = {}".format(times[0]))
    plt.colorbar(im, ax=ax)
    
    def update(frame):
        im.set_data(sample_pred[frame, :, :, 0])
        ax.set_title("FNO Predicted Motion at t = {}".format(times[frame]))
        return [im]
    
    ani = animation.FuncAnimation(fig, update, frames=T_out, interval=800, blit=True)
    writer = animation.PillowWriter(fps=2)
    ani.save(save_path, writer=writer)
    print("FNO motion animation saved as", save_path)
    plt.close(fig)
    return ani

# 사용 예:
# model과 test_loader는 이미 학습된 FNO 모델과 테스트 데이터로더라고 가정합니다.
ani = create_FNO_motion_animation(model, test_loader, save_path='FNO_motion.gif')
# Out:
# FNO motion animation saved as FNO_motion.gif

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation

def animate_prediction(model, test_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    with torch.no_grad():
        input_data, target = next(iter(test_loader))
        input_data = input_data.to(device)
        pred = model(input_data)  # pred shape: (batch, T_out, H, W, 1)
    # 배치의 첫 번째 샘플 선택
    sample_pred = pred[0].cpu().numpy()    # shape: (T_out, H, W, 1)
    sample_target = target[0].cpu().numpy()  # shape: (T_out, H, W, 1)
    
    T_out, H, W, _ = sample_pred.shape
    
    fig, ax = plt.subplots()
    # 초기 프레임 (예: t = 첫 번째 시간 스텝)
    im = ax.imshow(sample_pred[0, :, :, 0], cmap="RdBu", animated=True)
    ax.set_title("Prediction at t = {}".format(15))
    plt.colorbar(im, ax=ax)
    
    def update(frame):
        im.set_data(sample_pred[frame, :, :, 0])
        # 시간 라벨은 t = 15,20,25,30 등의 값이라고 가정
        times = [15, 20, 25, 30]
        ax.set_title("Prediction at t = {}".format(times[frame]))
        return [im]
    
    ani = animation.FuncAnimation(fig, update, frames=T_out, interval=800, blit=True)
    plt.show()
    return ani

ani = animate_prediction(model, test_loader)

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import torch

def create_animation_and_save(model, test_loader, save_path='navier_stokes_prediction.gif'):
    """
    모델의 예측 결과를 애니메이션으로 만들고 .gif 파일로 저장합니다.
    모델은 FNO3d 형태의 모델이며, test_loader에서 하나의 배치에서 첫 번째 샘플을 사용합니다.
    예상 출력 shape: (batch, T_out, H, W, 1)
    """
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model.eval()
    with torch.no_grad():
        input_data, target = next(iter(test_loader))
        # 모델 입력: 이미 (batch, T_in, H, W, 4) 형태로 구성되어 있다고 가정
        input_data = input_data.to(device)
        pred = model(input_data)  # 예측: (batch, T_out, H, W, 1)
    
    # 첫 번째 샘플 선택
    sample_pred = pred[0].cpu().numpy()  # shape: (T_out, H, W, 1)
    T_out, H, W, _ = sample_pred.shape
    
    # 시간 라벨 (예: t = 15, 20, 25, 30)
    times = [15, 20, 25, 30]
    
    fig, ax = plt.subplots()
    im = ax.imshow(sample_pred[0, :, :, 0], cmap="RdBu", animated=True)
    ax.set_title("Prediction at t = {}".format(times[0]))
    plt.colorbar(im, ax=ax)
    
    def update(frame):
        im.set_data(sample_pred[frame, :, :, 0])
        ax.set_title("Prediction at t = {}".format(times[frame]))
        return [im]
    
    ani = animation.FuncAnimation(fig, update, frames=T_out, interval=800, blit=True)
    # .gif 파일로 저장 (PillowWriter 사용, fps는 초당 프레임 수)
    writer = animation.PillowWriter(fps=2)
    ani.save(save_path, writer=writer)
    print("Animation saved as", save_path)
    plt.close(fig)
    return ani

# 사용 예시:
# model과 test_loader는 앞서 정의된 FNO3d 모델과 데이터로더라고 가정합니다.
ani = create_animation_and_save(model, test_loader, save_path='navier_stokes_prediction.gif')
# Out:
# Animation saved as navier_stokes_prediction.gif
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt

# =============================================================================
# 1. Navier–Stokes PDE solver (pseudo-spectral method)
# =============================================================================
def solve_navier_stokes(w0, nu, dt, t_final, N):
    """
    2D Navier–Stokes vorticity PDE (주기적 경계조건) 를 푸는 간단한 pseudo-spectral solver.
    
    PDE:
        ∂ₜw + u · ∇w = ν ∆w + f(x)
        u = (ψ_y, -ψ_x),   and   ∆ψ = -w,  with periodic boundary conditions.
    입력:
        w0: 초기 vorticity, shape (N, N)
        nu: 점성 계수
        dt: 시간 스텝
        t_final: 최종 시간
        N: 격자 크기 (N×N)
    출력:
        snapshots: 정수 시간마다 (t, w) 튜플 리스트.
    """
    # 공간 좌표 생성 (0 ≤ x,y < 1)
    x = np.linspace(0, 1, N, endpoint=False)
    y = np.linspace(0, 1, N, endpoint=False)
    xv, yv = np.meshgrid(x, y, indexing='ij')
    
    # forcing function: f(x) = 0.1*( sin(2π(x+y)) + cos(2π(x+y)) )
    f = 0.1 * (np.sin(2*np.pi*(xv + yv)) + np.cos(2*np.pi*(xv + yv)))
    
    # FFT frequencies (주기적 도메인: [0,1])
    kx = np.fft.fftfreq(N, d=1.0/N) * 2*np.pi
    ky = np.fft.fftfreq(N, d=1.0/N) * 2*np.pi
    kx, ky = np.meshgrid(kx, ky, indexing='ij')
    ksq = kx**2 + ky**2
    ksq[0,0] = 1.0  # 0분할 방지
    
    w = w0.copy()
    snapshots = []
    snapshot_times = np.arange(0, t_final+dt, 1.0)  # 정수 시간마다 기록
    next_snapshot_index = 0
    
    nsteps = int(t_final/dt)
    for step in range(nsteps):
        t = step * dt
        # 스냅샷 기록
        if next_snapshot_index < len(snapshot_times) and t >= snapshot_times[next_snapshot_index]:
            snapshots.append((t, w.copy()))
            next_snapshot_index += 1
        
        # vorticity의 FFT
        w_hat = np.fft.fft2(w)
        # stream function: ∆ψ = -w  ->  ψ_hat = -w_hat / ksq, ψ_hat(0)=0
        psi_hat = -w_hat / ksq
        psi_hat[0,0] = 0.0
        psi = np.real(np.fft.ifft2(psi_hat))
        
        # 속도 계산: u = ψ_y, v = -ψ_x (spectral differentiation)
        u = np.real(np.fft.ifft2(1j * ky * psi_hat))
        v = -np.real(np.fft.ifft2(1j * kx * psi_hat))
        
        # vorticity gradient (spectral differentiation)
        w_x = np.real(np.fft.ifft2(1j * kx * w_hat))
        w_y = np.real(np.fft.ifft2(1j * ky * w_hat))
        
        # 비선형 항: u * w_x + v * w_y
        nonlinear = u * w_x + v * w_y
        
        # Laplacian: ∆w = ifft2(-ksq * w_hat)
        lap_w = np.real(np.fft.ifft2(-ksq * w_hat))
        
        # Euler explicit time stepping
        w = w + dt * (-nonlinear + nu * lap_w + f)
    
    return snapshots

    
# =============================================================================
# 2. Navier-Stokes 데이터셋 (PDE solver를 사용하여 데이터 생성)
# =============================================================================
class NavierStokesDatasetFromSolver(Dataset):
    def __init__(self, num_samples, N, dt, t_final, nu, T_in_range, T_out_times):
        """
        num_samples: 샘플 개수.
        N: 공간 격자 크기 (N×N).
        dt: 시간 스텝.
        t_final: 최종 시각 (예, 30).
        nu: 점성 계수.
        T_in_range: 입력 시간 구간 (예: (0, 10)).
        T_out_times: 타겟 시간 (예: [15, 20, 25, 30]).
        """
        self.samples = []
        for i in range(num_samples):
            # 랜덤 초기 조건 (예: 가우시안 랜덤 필드)
            w0 = np.random.randn(N, N)
            snapshots = solve_navier_stokes(w0, nu, dt, t_final, N)
            # snapshots: [(t, w), ...] t는 정수 시간 (0,1,2,...,t_final)
            input_series = []
            for t, w in snapshots:
                if t >= T_in_range[0] and t <= T_in_range[1]:
                    input_series.append(w)
            input_series = np.array(input_series)  # shape: (T_in, N, N)
            
            target_series = []
            for t, w in snapshots:
                if t in T_out_times:
                    target_series.append(w)
            target_series = np.array(target_series)  # shape: (T_out, N, N)
            self.samples.append((input_series, target_series))
        
        # 공간 좌표 (x, y) 생성, x,y ∈ [0,1)
        x = np.linspace(0, 1, N, endpoint=False)
        y = np.linspace(0, 1, N, endpoint=False)
        xv, yv = np.meshgrid(x, y, indexing='ij')
        self.spatial_coords = np.stack([xv, yv], axis=-1)  # (N, N, 2)
        # 입력 시간 좌표: 정수 시간 (예: 0,1,...,10)
        self.input_times = np.arange(T_in_range[0], T_in_range[1]+1)
        self.target_times = np.array(T_out_times)
        
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        input_series, target_series = self.samples[idx]
        T_in = input_series.shape[0]
        N = input_series.shape[1]
        # 각 입력 시간(t)에 대해 [vorticity, t, x, y]를 결합
        input_data = []
        for i, t in enumerate(self.input_times):
            t_field = np.full((N, N, 1), t)
            w_field = input_series[i][:, :, np.newaxis]
            combined = np.concatenate([w_field, t_field, self.spatial_coords], axis=-1)
            input_data.append(combined)
        input_data = np.stack(input_data, axis=0)  # shape: (T_in, N, N, 4)
        
        # target_series의 길이가 기대하는 T_out와 같지 않은 경우, 부족한 부분을 마지막 스냅샷으로 패딩
        if target_series.shape[0] < len(self.target_times):
            pad_len = len(self.target_times) - target_series.shape[0]
            last = target_series[-1:,...]
            pad = np.repeat(last, pad_len, axis=0)
            target_series = np.concatenate([target_series, pad], axis=0)
        
        target_data = []
        for i in range(target_series.shape[0]):
            target_data.append(target_series[i][:, :, np.newaxis])
        target_data = np.stack(target_data, axis=0)  # shape: (T_out, N, N, 1)
        
        # Torch tensor로 변환
        input_data = torch.tensor(input_data, dtype=torch.float32)
        target_data = torch.tensor(target_data, dtype=torch.float32)
        return input_data, target_data


# =============================================================================
# 3. 기존의 FNO 모델 (3D FNO: 시간-공간 연산자 학습)
# =============================================================================
class SpectralConv3d(nn.Module):
    def __init__(self, in_channels, out_channels, modes_t, modes_x, modes_y):
        super(SpectralConv3d, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes_t = modes_t
        self.modes_x = modes_x
        self.modes_y = modes_y
        self.scale = 1 / (in_channels * out_channels)
        self.weights = nn.Parameter(
            self.scale * torch.rand(in_channels, out_channels, modes_t, modes_x, modes_y, 2)
        )
    
    def compl_mul3d(self, input, weights):
        # weights: (in_channels, out_channels, t, x, y, 2) -> 복소수 텐서: (in_channels, out_channels, t, x, y)
        weight_complex = torch.view_as_complex(weights)
        # "bctxy, cotxy -> botxy": 입력의 각 주파수에 대해, C_in에 대해 합산하여 (batch, out_channels, t, x, y)를 얻음.
        return torch.einsum("bctxy, cotxy -> botxy", input, weight_complex)
    
    def forward(self, x):
        batchsize = x.shape[0]
        # 3D FFT 계산: x의 shape은 (batch, in_channels, t, x, y)
        x_ft = torch.fft.rfftn(x, dim=[2,3,4])
        out_ft = torch.zeros(
            batchsize, self.out_channels, x_ft.size(2), x_ft.size(3), x_ft.size(4),
            device=x.device, dtype=torch.cfloat
        )
        t_modes = min(self.modes_t, x_ft.size(2))
        x_modes = min(self.modes_x, x_ft.size(3))
        y_modes = min(self.modes_y, x_ft.size(4))
        out_ft[:, :, :t_modes, :x_modes, :y_modes] = self.compl_mul3d(
            x_ft[:, :, :t_modes, :x_modes, :y_modes],
            self.weights[:, :, :t_modes, :x_modes, :y_modes]
        )
        x = torch.fft.irfftn(out_ft, s=(x.size(2), x.size(3), x.size(4)))
        return x



class FNO3d(nn.Module):
    def __init__(self, modes_t, modes_x, modes_y, width, T_in, T_out):
        """
        modes_t, modes_x, modes_y: 시간 및 공간 방향의 Fourier 모드 수.
        width: latent channel 차원.
        T_in: 입력 시간 스텝 수 (예: 11, t=0~10)
        T_out: 출력 시간 스텝 수 (예: 4, t=15,20,25,30)
        """
        super(FNO3d, self).__init__()
        self.width = width
        self.T_in = T_in
        self.T_out = T_out
        self.fc0 = nn.Linear(4, width)  # 입력 채널: [vorticity, t, x, y]
        
        self.conv0 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv1 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv2 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv3 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        
        self.w0 = nn.Conv3d(self.width, self.width, 1)
        self.w1 = nn.Conv3d(self.width, self.width, 1)
        self.w2 = nn.Conv3d(self.width, self.width, 1)
        self.w3 = nn.Conv3d(self.width, self.width, 1)
        
        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)  # 출력: vorticity
        
        # Temporal predictor: 각 픽셀별로 입력 시간(T_in)을 출력 시간(T_out)으로 매핑
        self.temporal_fc = nn.Linear(T_in, T_out)
        
    def forward(self, x):
        # x: (batch, T_in, H, W, 4)
        batch, T_in, H, W, _ = x.shape
        x = self.fc0(x)  # (batch, T_in, H, W, width)
        x = x.permute(0, 4, 1, 2, 3)  # (batch, width, T_in, H, W)
        
        x0 = self.conv0(x)
        x1 = self.w0(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv1(x)
        x1 = self.w1(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv2(x)
        x1 = self.w2(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv3(x)
        x1 = self.w3(x)
        x = F.gelu(x0 + x1)
        
        x = x.permute(0, 2, 3, 4, 1)  # (batch, T_in, H, W, width)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)  # (batch, T_in, H, W, 1)
        
        # Temporal prediction: 각 픽셀별로 입력 시간 차원(T_in)을 T_out 차원으로 변환
        x = x.squeeze(-1)              # (batch, T_in, H, W)
        x = x.permute(0, 2, 3, 1)        # (batch, H, W, T_in)
        x = self.temporal_fc(x)          # (batch, H, W, T_out)
        x = x.permute(0, 3, 1, 2).unsqueeze(-1)  # (batch, T_out, H, W, 1)
        return x


# =============================================================================
# 4. 학습 루프 및 시각화
# =============================================================================
def train_model_3d(model, train_loader, test_loader, epochs=300):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)
    loss_fn = nn.MSELoss()
    train_losses = []
    test_losses = []
    
    for epoch in range(1, epochs+1):
        model.train()
        train_loss = 0.0
        for input_data, target in train_loader:
            # input_data: (batch, T_in, H, W, 4), target: (batch, T_out, H, W, 1)
            input_data = input_data.to(device)
            target = target.to(device)
            optimizer.zero_grad()
            output = model(input_data)
            loss = loss_fn(output, target)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * input_data.size(0)
        train_loss /= len(train_loader.dataset)
        train_losses.append(train_loss)
        
        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for input_data, target in test_loader:
                input_data = input_data.to(device)
                target = target.to(device)
                output = model(input_data)
                loss = loss_fn(output, target)
                test_loss += loss.item() * input_data.size(0)
        test_loss /= len(test_loader.dataset)
        test_losses.append(test_loss)
        scheduler.step()
        if epoch % 1 == 0:
            print(f"Epoch {epoch:03d}: Train Loss = {train_loss:.6f}, Test Loss = {test_loss:.6f}")
    
    plt.figure(figsize=(8,6))
    plt.plot(train_losses, label="Train Loss")
    plt.plot(test_losses, label="Test Loss")
    plt.xlabel("Epoch")
    plt.ylabel("MSE Loss")
    plt.legend()
    plt.title("Training and Test Loss Curves (FNO3d)")
    plt.show()
    
    return train_losses, test_losses

def visualize_sample_3d(model, test_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    with torch.no_grad():
        input_data, target = next(iter(test_loader))
        input_data = input_data.to(device)
        pred = model(input_data)
    sample_target = target[0].cpu().numpy()  # (T_out, H, W, 1)
    sample_pred = pred[0].cpu().numpy()      # (T_out, H, W, 1)
    times = [15, 20, 25, 30]  # target 시간 라벨
    T_out = sample_target.shape[0]
    plt.figure(figsize=(16, 4*T_out))
    for i in range(T_out):
        plt.subplot(T_out, 2, 2*i+1)
        plt.title(f"Ground Truth at t = {times[i]}")
        plt.imshow(sample_target[i, :, :, 0], cmap="RdBu", origin="lower")
        plt.colorbar()
        plt.subplot(T_out, 2, 2*i+2)
        plt.title(f"Prediction at t = {times[i]}")
        plt.imshow(sample_pred[i, :, :, 0], cmap="RdBu", origin="lower")
        plt.colorbar()
    plt.tight_layout()
    plt.show()

# =============================================================================
# 5. 전체 파이프라인 실행
# =============================================================================
if __name__ == '__main__':
    # PDE simulation parameters
    N = 64         # spatial resolution: 64x64
    dt = 0.005     # 시간 스텝 (안정성을 위해 충분히 작게)
    t_final = 50   # 최종 시각
    nu = 1e-3      # 점성 계수 (예시)
    
    # 데이터셋에서 사용할 시간 구간
    T_in_range = (0, 10)          # 입력: t=0 ~ 10 (정수 시간 스냅샷)
    T_out_times = [20, 30, 40, 49] # 타겟: t = 15,20,25,30
    
    num_train = 20   # 시연을 위한 샘플 수 (실제 연구에서는 더 많은 샘플 사용)
    num_test = 4
    
    # Navier–Stokes PDE solver를 통해 데이터 생성
    dataset_solver_train = NavierStokesDatasetFromSolver(num_samples=num_train, N=N, dt=dt, t_final=t_final, nu=nu, 
                                                          T_in_range=T_in_range, T_out_times=T_out_times)
    dataset_solver_test  = NavierStokesDatasetFromSolver(num_samples=num_test, N=N, dt=dt, t_final=t_final, nu=nu, 
                                                          T_in_range=T_in_range, T_out_times=T_out_times)
    
    train_loader = DataLoader(dataset_solver_train, batch_size=2, shuffle=True)
    test_loader = DataLoader(dataset_solver_test, batch_size=2, shuffle=False)
    
    # 모델 하이퍼파라미터: Fourier 모드 수 선택 (시간: 4, x: 16, y: 16), width: 32, T_out: 4
    modes_t, modes_x, modes_y = 4, 16, 16
    width = 32
    T_out = len(T_out_times)
    T_in = 11
    model = FNO3d(modes_t, modes_x, modes_y, width, T_in, T_out)
    
    # 학습
    train_losses, test_losses = train_model_3d(model, train_loader, test_loader, epochs=500)
    
    # 결과 시각화
    visualize_sample_3d(model, test_loader)

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt


# =============================================================================
# 1. Navier–Stokes PDE solver (pseudo-spectral method)
# =============================================================================
def solve_navier_stokes(w0, nu, dt, t_final, N):
    """
    2D Navier–Stokes vorticity PDE (주기적 경계조건) 를 푸는 간단한 pseudo-spectral solver.
    
    PDE:
        ∂ₜw + u · ∇w = ν ∆w + f(x)
        u = (ψ_y, -ψ_x),   and   ∆ψ = -w,  with periodic boundary conditions.
    입력:
        w0: 초기 vorticity, shape (N, N)
        nu: 점성 계수
        dt: 시간 스텝
        t_final: 최종 시간
        N: 격자 크기 (N×N)
    출력:
        snapshots: 정수 시간마다 (t, w) 튜플 리스트.
    """
    # 공간 좌표 생성 (0 ≤ x,y < 1)
    x = np.linspace(0, 1, N, endpoint=False)
    y = np.linspace(0, 1, N, endpoint=False)
    xv, yv = np.meshgrid(x, y, indexing='ij')
    
    # forcing function: f(x) = 0.1*( sin(2π(x+y)) + cos(2π(x+y)) )
    f = 0.1 * (np.sin(2*np.pi*(xv + yv)) + np.cos(2*np.pi*(xv + yv)))
    
    # FFT frequencies (주기적 도메인: [0,1])
    kx = np.fft.fftfreq(N, d=1.0/N) * 2*np.pi
    ky = np.fft.fftfreq(N, d=1.0/N) * 2*np.pi
    kx, ky = np.meshgrid(kx, ky, indexing='ij')
    ksq = kx**2 + ky**2
    ksq[0,0] = 1.0  # 0분할 방지
    
    w = w0.copy()
    snapshots = []
    snapshot_times = np.arange(0, t_final+dt, 1.0)  # 정수 시간마다 기록
    next_snapshot_index = 0
    
    nsteps = int(t_final/dt)
    for step in range(nsteps):
        t = step * dt
        # 스냅샷 기록
        if next_snapshot_index < len(snapshot_times) and t >= snapshot_times[next_snapshot_index]:
            snapshots.append((t, w.copy()))
            next_snapshot_index += 1
        
        # vorticity의 FFT
        w_hat = np.fft.fft2(w)
        # stream function: ∆ψ = -w  ->  ψ_hat = -w_hat / ksq, ψ_hat(0)=0
        psi_hat = -w_hat / ksq
        psi_hat[0,0] = 0.0
        psi = np.real(np.fft.ifft2(psi_hat))
        
        # 속도 계산: u = ψ_y, v = -ψ_x (spectral differentiation)
        u = np.real(np.fft.ifft2(1j * ky * psi_hat))
        v = -np.real(np.fft.ifft2(1j * kx * psi_hat))
        
        # vorticity gradient (spectral differentiation)
        w_x = np.real(np.fft.ifft2(1j * kx * w_hat))
        w_y = np.real(np.fft.ifft2(1j * ky * w_hat))
        
        # 비선형 항: u * w_x + v * w_y
        nonlinear = u * w_x + v * w_y
        
        # Laplacian: ∆w = ifft2(-ksq * w_hat)
        lap_w = np.real(np.fft.ifft2(-ksq * w_hat))
        
        # Euler explicit time stepping
        w = w + dt * (-nonlinear + nu * lap_w + f)
    
    return snapshots

    
# =============================================================================
# 2. Navier-Stokes 데이터셋 (PDE solver를 사용하여 데이터 생성)
# =============================================================================
class NavierStokesDatasetFromSolver(Dataset):
    def __init__(self, num_samples, N, dt, t_final, nu, T_in_range, T_out_times):
        """
        num_samples: 샘플 개수.
        N: 공간 격자 크기 (N×N).
        dt: 시간 스텝.
        t_final: 최종 시각 (예, 30).
        nu: 점성 계수.
        T_in_range: 입력 시간 구간 (예: (0, 10)).
        T_out_times: 타겟 시간 (예: [15, 20, 25, 30]).
        """
        self.samples = []
        for i in range(num_samples):
            # 랜덤 초기 조건 (예: 가우시안 랜덤 필드)
            w0 = np.random.randn(N, N)
            snapshots = solve_navier_stokes(w0, nu, dt, t_final, N)
            # snapshots: [(t, w), ...] t는 정수 시간 (0,1,2,...,t_final)
            input_series = []
            for t, w in snapshots:
                if t >= T_in_range[0] and t <= T_in_range[1]:
                    input_series.append(w)
            input_series = np.array(input_series)  # shape: (T_in, N, N)
            
            target_series = []
            for t, w in snapshots:
                if t in T_out_times:
                    target_series.append(w)
            target_series = np.array(target_series)  # shape: (T_out, N, N)
            self.samples.append((input_series, target_series))
        
        # 공간 좌표 (x, y) 생성, x,y ∈ [0,1)
        x = np.linspace(0, 1, N, endpoint=False)
        y = np.linspace(0, 1, N, endpoint=False)
        xv, yv = np.meshgrid(x, y, indexing='ij')
        self.spatial_coords = np.stack([xv, yv], axis=-1)  # (N, N, 2)
        # 입력 시간 좌표: 정수 시간 (예: 0,1,...,10)
        self.input_times = np.arange(T_in_range[0], T_in_range[1]+1)
        self.target_times = np.array(T_out_times)
        
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        input_series, target_series = self.samples[idx]
        T_in = input_series.shape[0]
        N = input_series.shape[1]
        # 각 입력 시간(t)에 대해 [vorticity, t, x, y]를 결합
        input_data = []
        for i, t in enumerate(self.input_times):
            t_field = np.full((N, N, 1), t)
            w_field = input_series[i][:, :, np.newaxis]
            combined = np.concatenate([w_field, t_field, self.spatial_coords], axis=-1)
            input_data.append(combined)
        input_data = np.stack(input_data, axis=0)  # shape: (T_in, N, N, 4)
        
        # target_series의 길이가 기대하는 T_out와 같지 않은 경우, 부족한 부분을 마지막 스냅샷으로 패딩
        if target_series.shape[0] < len(self.target_times):
            pad_len = len(self.target_times) - target_series.shape[0]
            last = target_series[-1:,...]
            pad = np.repeat(last, pad_len, axis=0)
            target_series = np.concatenate([target_series, pad], axis=0)
        
        target_data = []
        for i in range(target_series.shape[0]):
            target_data.append(target_series[i][:, :, np.newaxis])
        target_data = np.stack(target_data, axis=0)  # shape: (T_out, N, N, 1)
        
        # Torch tensor로 변환
        input_data = torch.tensor(input_data, dtype=torch.float32)
        target_data = torch.tensor(target_data, dtype=torch.float32)
        return input_data, target_data


# =============================================================================
# 3. 기존의 FNO 모델 (3D FNO: 시간-공간 연산자 학습)
# =============================================================================
class SpectralConv3d(nn.Module):
    def __init__(self, in_channels, out_channels, modes_t, modes_x, modes_y):
        super(SpectralConv3d, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.modes_t = modes_t
        self.modes_x = modes_x
        self.modes_y = modes_y
        self.scale = 1 / (in_channels * out_channels)
        self.weights = nn.Parameter(
            self.scale * torch.rand(in_channels, out_channels, modes_t, modes_x, modes_y, 2)
        )
    
    def compl_mul3d(self, input, weights):
        # weights: (in_channels, out_channels, t, x, y, 2) -> 복소수 텐서: (in_channels, out_channels, t, x, y)
        weight_complex = torch.view_as_complex(weights)
        # "bctxy, cotxy -> botxy": 입력의 각 주파수에 대해, C_in에 대해 합산하여 (batch, out_channels, t, x, y)를 얻음.
        return torch.einsum("bctxy, cotxy -> botxy", input, weight_complex)
    
    def forward(self, x):
        batchsize = x.shape[0]
        # 3D FFT 계산: x의 shape은 (batch, in_channels, t, x, y)
        x_ft = torch.fft.rfftn(x, dim=[2,3,4])
        out_ft = torch.zeros(
            batchsize, self.out_channels, x_ft.size(2), x_ft.size(3), x_ft.size(4),
            device=x.device, dtype=torch.cfloat
        )
        t_modes = min(self.modes_t, x_ft.size(2))
        x_modes = min(self.modes_x, x_ft.size(3))
        y_modes = min(self.modes_y, x_ft.size(4))
        out_ft[:, :, :t_modes, :x_modes, :y_modes] = self.compl_mul3d(
            x_ft[:, :, :t_modes, :x_modes, :y_modes],
            self.weights[:, :, :t_modes, :x_modes, :y_modes]
        )
        x = torch.fft.irfftn(out_ft, s=(x.size(2), x.size(3), x.size(4)))
        return x



class FNO3d(nn.Module):
    def __init__(self, modes_t, modes_x, modes_y, width, T_in, T_out):
        """
        modes_t, modes_x, modes_y: 시간 및 공간 방향의 Fourier 모드 수.
        width: latent channel 차원.
        T_in: 입력 시간 스텝 수 (예: 11, t=0~10)
        T_out: 출력 시간 스텝 수 (예: 4, t=15,20,25,30)
        """
        super(FNO3d, self).__init__()
        self.width = width
        self.T_in = T_in
        self.T_out = T_out
        self.fc0 = nn.Linear(4, width)  # 입력 채널: [vorticity, t, x, y]
        
        self.conv0 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv1 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv2 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        self.conv3 = SpectralConv3d(self.width, self.width, modes_t, modes_x, modes_y)
        
        self.w0 = nn.Conv3d(self.width, self.width, 1)
        self.w1 = nn.Conv3d(self.width, self.width, 1)
        self.w2 = nn.Conv3d(self.width, self.width, 1)
        self.w3 = nn.Conv3d(self.width, self.width, 1)
        
        self.fc1 = nn.Linear(self.width, 128)
        self.fc2 = nn.Linear(128, 1)  # 출력: vorticity
        
        # Temporal predictor: 각 픽셀별로 입력 시간(T_in)을 출력 시간(T_out)으로 매핑
        self.temporal_fc = nn.Linear(T_in, T_out)
        
    def forward(self, x):
        # x: (batch, T_in, H, W, 4)
        batch, T_in, H, W, _ = x.shape
        x = self.fc0(x)  # (batch, T_in, H, W, width)
        x = x.permute(0, 4, 1, 2, 3)  # (batch, width, T_in, H, W)
        
        x0 = self.conv0(x)
        x1 = self.w0(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv1(x)
        x1 = self.w1(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv2(x)
        x1 = self.w2(x)
        x = F.gelu(x0 + x1)
        
        x0 = self.conv3(x)
        x1 = self.w3(x)
        x = F.gelu(x0 + x1)
        
        x = x.permute(0, 2, 3, 4, 1)  # (batch, T_in, H, W, width)
        x = self.fc1(x)
        x = F.gelu(x)
        x = self.fc2(x)  # (batch, T_in, H, W, 1)
        
        # Temporal prediction: 각 픽셀별로 입력 시간 차원(T_in)을 T_out 차원으로 변환
        x = x.squeeze(-1)              # (batch, T_in, H, W)
        x = x.permute(0, 2, 3, 1)        # (batch, H, W, T_in)
        x = self.temporal_fc(x)          # (batch, H, W, T_out)
        x = x.permute(0, 3, 1, 2).unsqueeze(-1)  # (batch, T_out, H, W, 1)
        return x


# =============================================================================
# 4. 학습 루프 및 시각화
# =============================================================================
def train_model_3d(model, train_loader, test_loader, epochs=300):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.5)
    loss_fn = nn.MSELoss()
    train_losses = []
    test_losses = []
    
    for epoch in range(1, epochs+1):
        model.train()
        train_loss = 0.0
        for input_data, target in train_loader:
            # input_data: (batch, T_in, H, W, 4), target: (batch, T_out, H, W, 1)
            input_data = input_data.to(device)
            target = target.to(device)
            optimizer.zero_grad()
            output = model(input_data)
            loss = loss_fn(output, target)
            loss.backward()
            optimizer.step()
            train_loss += loss.item() * input_data.size(0)
        train_loss /= len(train_loader.dataset)
        train_losses.append(train_loss)
        
        model.eval()
        test_loss = 0.0
        with torch.no_grad():
            for input_data, target in test_loader:
                input_data = input_data.to(device)
                target = target.to(device)
                output = model(input_data)
                loss = loss_fn(output, target)
                test_loss += loss.item() * input_data.size(0)
        test_loss /= len(test_loader.dataset)
        test_losses.append(test_loss)
        #scheduler.step()
        if epoch % 1 == 0:
            print(f"Epoch {epoch:03d}: Train Loss = {train_loss:.6f}, Test Loss = {test_loss:.6f}")
    
    plt.figure(figsize=(8,6))
    plt.plot(train_losses, label="Train Loss")
    plt.plot(test_losses, label="Test Loss")
    plt.xlabel("Epoch")
    plt.ylabel("MSE Loss")
    plt.legend()
    plt.title("Training and Test Loss Curves (FNO3d)")
    plt.show()
    
    return train_losses, test_losses

def visualize_sample_3d(model, test_loader):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.eval()
    with torch.no_grad():
        input_data, target = next(iter(test_loader))
        input_data = input_data.to(device)
        pred = model(input_data)
    sample_target = target[0].cpu().numpy()  # (T_out, H, W, 1)
    sample_pred = pred[0].cpu().numpy()      # (T_out, H, W, 1)
    times = [15, 20, 25, 30]  # target 시간 라벨
    T_out = sample_target.shape[0]
    plt.figure(figsize=(16, 4*T_out))
    for i in range(T_out):
        plt.subplot(T_out, 2, 2*i+1)
        plt.title(f"Ground Truth at t = {times[i]}")
        plt.imshow(sample_target[i, :, :, 0], cmap="seismic", origin="lower")
        plt.colorbar()
        plt.subplot(T_out, 2, 2*i+2)
        plt.title(f"Prediction at t = {times[i]}")
        plt.imshow(sample_pred[i, :, :, 0], cmap="seismic", origin="lower")
        plt.colorbar()
    plt.tight_layout()
    plt.show()


# =============================================================================
# 5. 전체 파이프라인 실행
# =============================================================================
if __name__ == '__main__':
    # PDE simulation parameters
    N = 64         # spatial resolution: 64x64
    dt = 0.005     # 시간 스텝 (안정성을 위해 충분히 작게)
    t_final = 50   # 최종 시각
    nu = 1e-3      # 점성 계수 (예시)
    
    # 데이터셋에서 사용할 시간 구간
    T_in_range = (0, 10)          # 입력: t=0 ~ 10 (정수 시간 스냅샷)
    T_out_times = [20, 30, 40, 49] # 타겟: t = 15,20,25,30
    
    num_train = 1000   # 시연을 위한 샘플 수 (실제 연구에서는 더 많은 샘플 사용)
    num_test = 200
    
    # Navier–Stokes PDE solver를 통해 데이터 생성
    dataset_solver_train = NavierStokesDatasetFromSolver(num_samples=num_train, N=N, dt=dt, t_final=t_final, nu=nu, 
                                                          T_in_range=T_in_range, T_out_times=T_out_times)
    dataset_solver_test  = NavierStokesDatasetFromSolver(num_samples=num_test, N=N, dt=dt, t_final=t_final, nu=nu, 
                                                          T_in_range=T_in_range, T_out_times=T_out_times)
    
    train_loader = DataLoader(dataset_solver_train, batch_size=2, shuffle=True)
    test_loader = DataLoader(dataset_solver_test, batch_size=2, shuffle=False)
    
    # 모델 하이퍼파라미터: Fourier 모드 수 선택 (시간: 4, x: 16, y: 16), width: 32, T_out: 4
    modes_t, modes_x, modes_y = 4, 16, 16
    width = 32
    T_out = len(T_out_times)
    T_in = 11
    model = FNO3d(modes_t, modes_x, modes_y, width, T_in, T_out)
    
    # 학습
    train_losses, test_losses = train_model_3d(model, train_loader, test_loader, epochs=500)
    
    # 결과 시각화
    visualize_sample_3d(model, test_loader)
# Out:
# Epoch 001: Train Loss = 0.134455, Test Loss = 0.038933
# Epoch 002: Train Loss = 0.025287, Test Loss = 0.019079
# Epoch 003: Train Loss = 0.014448, Test Loss = 0.012158
# Epoch 004: Train Loss = 0.010063, Test Loss = 0.009008
# Epoch 005: Train Loss = 0.007388, Test Loss = 0.006815
# Epoch 006: Train Loss = 0.005953, Test Loss = 0.005705
# Epoch 007: Train Loss = 0.004830, Test Loss = 0.005932
# Epoch 008: Train Loss = 0.004157, Test Loss = 0.004580
# Epoch 009: Train Loss = 0.003576, Test Loss = 0.003893
# Epoch 010: Train Loss = 0.003072, Test Loss = 0.003540
# Epoch 011: Train Loss = 0.002759, Test Loss = 0.004066
# Epoch 012: Train Loss = 0.002522, Test Loss = 0.003449
# Epoch 013: Train Loss = 0.002378, Test Loss = 0.003381
# Epoch 014: Train Loss = 0.002054, Test Loss = 0.002896
# Epoch 015: Train Loss = 0.001837, Test Loss = 0.003507
# Epoch 016: Train Loss = 0.001732, Test Loss = 0.002969
# Epoch 017: Train Loss = 0.001581, Test Loss = 0.002489
# Epoch 018: Train Loss = 0.001588, Test Loss = 0.002884
# Epoch 019: Train Loss = 0.001378, Test Loss = 0.002975
# Epoch 020: Train Loss = 0.001226, Test Loss = 0.002002
# Epoch 021: Train Loss = 0.001298, Test Loss = 0.002029
# Epoch 022: Train Loss = 0.001205, Test Loss = 0.002215
# Epoch 023: Train Loss = 0.001039, Test Loss = 0.002310
# Epoch 024: Train Loss = 0.001129, Test Loss = 0.001982
# Epoch 025: Train Loss = 0.001042, Test Loss = 0.001759
# Epoch 026: Train Loss = 0.000965, Test Loss = 0.001990
# Epoch 027: Train Loss = 0.000999, Test Loss = 0.001798
# Epoch 028: Train Loss = 0.000814, Test Loss = 0.002103
# Epoch 029: Train Loss = 0.000870, Test Loss = 0.002082
# Epoch 030: Train Loss = 0.000817, Test Loss = 0.001651
# Epoch 031: Train Loss = 0.000698, Test Loss = 0.002027
# Epoch 032: Train Loss = 0.000760, Test Loss = 0.001445
# Epoch 033: Train Loss = 0.000748, Test Loss = 0.001795
# Epoch 034: Train Loss = 0.000706, Test Loss = 0.001573
# Epoch 035: Train Loss = 0.000707, Test Loss = 0.001579
# Epoch 036: Train Loss = 0.000682, Test Loss = 0.001779
# Epoch 037: Train Loss = 0.000758, Test Loss = 0.001776
# Epoch 038: Train Loss = 0.000633, Test Loss = 0.001410
# Epoch 039: Train Loss = 0.000583, Test Loss = 0.001918
# Epoch 040: Train Loss = 0.000660, Test Loss = 0.001661
# Epoch 041: Train Loss = 0.000565, Test Loss = 0.001378
# Epoch 042: Train Loss = 0.000672, Test Loss = 0.001298
# Epoch 043: Train Loss = 0.000574, Test Loss = 0.001702
# Epoch 044: Train Loss = 0.000537, Test Loss = 0.001431
# Epoch 045: Train Loss = 0.000497, Test Loss = 0.001758
# Epoch 046: Train Loss = 0.000482, Test Loss = 0.001333
# Epoch 047: Train Loss = 0.000563, Test Loss = 0.001330
# Epoch 048: Train Loss = 0.000591, Test Loss = 0.001701
# Epoch 049: Train Loss = 0.000459, Test Loss = 0.001503
# Epoch 050: Train Loss = 0.000457, Test Loss = 0.001181
# Epoch 051: Train Loss = 0.000493, Test Loss = 0.001228
# Epoch 052: Train Loss = 0.000542, Test Loss = 0.001241
# Epoch 053: Train Loss = 0.000401, Test Loss = 0.001362
# Epoch 054: Train Loss = 0.000471, Test Loss = 0.001265
# Epoch 055: Train Loss = 0.000452, Test Loss = 0.001426
# Epoch 056: Train Loss = 0.000439, Test Loss = 0.001327
# Epoch 057: Train Loss = 0.000475, Test Loss = 0.001384
# Epoch 058: Train Loss = 0.000448, Test Loss = 0.001244
# Epoch 059: Train Loss = 0.000391, Test Loss = 0.001270
# Epoch 060: Train Loss = 0.000419, Test Loss = 0.001218
# Epoch 061: Train Loss = 0.000443, Test Loss = 0.001103
# Epoch 062: Train Loss = 0.000367, Test Loss = 0.001118
# Epoch 063: Train Loss = 0.000354, Test Loss = 0.001185
# Epoch 064: Train Loss = 0.000459, Test Loss = 0.001199
# Epoch 065: Train Loss = 0.000333, Test Loss = 0.001200
# Epoch 066: Train Loss = 0.000389, Test Loss = 0.001167
# Epoch 067: Train Loss = 0.000386, Test Loss = 0.001170
# Epoch 068: Train Loss = 0.000370, Test Loss = 0.001132
# Epoch 069: Train Loss = 0.000379, Test Loss = 0.001220
# Epoch 070: Train Loss = 0.000306, Test Loss = 0.001164
# Epoch 071: Train Loss = 0.000419, Test Loss = 0.001175
# Epoch 072: Train Loss = 0.000342, Test Loss = 0.001295
# Epoch 073: Train Loss = 0.000341, Test Loss = 0.001135
# Epoch 074: Train Loss = 0.000313, Test Loss = 0.001083
# Epoch 075: Train Loss = 0.000345, Test Loss = 0.001128
# Epoch 076: Train Loss = 0.000373, Test Loss = 0.001106
# Epoch 077: Train Loss = 0.000356, Test Loss = 0.001171
# Epoch 078: Train Loss = 0.000338, Test Loss = 0.001061
# Epoch 079: Train Loss = 0.000329, Test Loss = 0.001106
# Epoch 080: Train Loss = 0.000342, Test Loss = 0.001112
# Epoch 081: Train Loss = 0.000285, Test Loss = 0.001077
# Epoch 082: Train Loss = 0.000330, Test Loss = 0.001298
# Epoch 083: Train Loss = 0.000269, Test Loss = 0.001039
# Epoch 084: Train Loss = 0.000267, Test Loss = 0.001077
# Epoch 085: Train Loss = 0.000330, Test Loss = 0.001003
# Epoch 086: Train Loss = 0.000338, Test Loss = 0.001159
# Epoch 087: Train Loss = 0.000308, Test Loss = 0.001024
# Epoch 088: Train Loss = 0.000264, Test Loss = 0.001091
# Epoch 089: Train Loss = 0.000334, Test Loss = 0.001374
# Epoch 090: Train Loss = 0.000262, Test Loss = 0.001039
# Epoch 091: Train Loss = 0.000263, Test Loss = 0.001128
# Epoch 092: Train Loss = 0.000348, Test Loss = 0.001378
# Epoch 093: Train Loss = 0.000277, Test Loss = 0.001002
# Epoch 094: Train Loss = 0.000291, Test Loss = 0.001001
# Epoch 095: Train Loss = 0.000248, Test Loss = 0.001025
# Epoch 096: Train Loss = 0.000244, Test Loss = 0.001063
# Epoch 097: Train Loss = 0.000264, Test Loss = 0.001467
# Epoch 098: Train Loss = 0.000369, Test Loss = 0.001129
# Epoch 099: Train Loss = 0.000266, Test Loss = 0.001083
# Epoch 100: Train Loss = 0.000225, Test Loss = 0.000968
# Epoch 101: Train Loss = 0.000244, Test Loss = 0.001094
# Epoch 102: Train Loss = 0.000262, Test Loss = 0.001050
# Epoch 103: Train Loss = 0.000238, Test Loss = 0.001130
# Epoch 104: Train Loss = 0.000272, Test Loss = 0.000973
# Epoch 105: Train Loss = 0.000319, Test Loss = 0.000960
# Epoch 106: Train Loss = 0.000312, Test Loss = 0.000919
# Epoch 107: Train Loss = 0.000213, Test Loss = 0.000946
# Epoch 108: Train Loss = 0.000255, Test Loss = 0.001031
# Epoch 109: Train Loss = 0.000210, Test Loss = 0.001108
# Epoch 110: Train Loss = 0.000255, Test Loss = 0.001011
# Epoch 111: Train Loss = 0.000259, Test Loss = 0.001011
# Epoch 112: Train Loss = 0.000278, Test Loss = 0.001212
# Epoch 113: Train Loss = 0.000254, Test Loss = 0.000997
# Epoch 114: Train Loss = 0.000213, Test Loss = 0.000966
# Epoch 115: Train Loss = 0.000223, Test Loss = 0.000983
# Epoch 116: Train Loss = 0.000238, Test Loss = 0.001008
# Epoch 117: Train Loss = 0.000267, Test Loss = 0.000994
# Epoch 118: Train Loss = 0.000210, Test Loss = 0.000895
# Epoch 119: Train Loss = 0.000191, Test Loss = 0.000952
# Epoch 120: Train Loss = 0.000249, Test Loss = 0.000911
# Epoch 121: Train Loss = 0.000252, Test Loss = 0.001125
# Epoch 122: Train Loss = 0.000286, Test Loss = 0.001088
# Epoch 123: Train Loss = 0.000216, Test Loss = 0.000974
# Epoch 124: Train Loss = 0.000196, Test Loss = 0.000934
# Epoch 125: Train Loss = 0.000177, Test Loss = 0.000913
# Epoch 126: Train Loss = 0.000208, Test Loss = 0.001117
# Epoch 127: Train Loss = 0.000257, Test Loss = 0.000910
# Epoch 128: Train Loss = 0.000220, Test Loss = 0.000922
# Epoch 129: Train Loss = 0.000235, Test Loss = 0.000989
# Epoch 130: Train Loss = 0.000238, Test Loss = 0.000960
# Epoch 131: Train Loss = 0.000213, Test Loss = 0.000963
# Epoch 132: Train Loss = 0.000179, Test Loss = 0.000845
# Epoch 133: Train Loss = 0.000169, Test Loss = 0.000909
# Epoch 134: Train Loss = 0.000190, Test Loss = 0.000928
# Epoch 135: Train Loss = 0.000212, Test Loss = 0.000938
# Epoch 136: Train Loss = 0.000193, Test Loss = 0.000981
# Epoch 137: Train Loss = 0.000204, Test Loss = 0.000979
# Epoch 138: Train Loss = 0.000203, Test Loss = 0.000963
# Epoch 139: Train Loss = 0.000163, Test Loss = 0.000915
# Epoch 140: Train Loss = 0.000210, Test Loss = 0.000941
# Epoch 141: Train Loss = 0.000209, Test Loss = 0.000884
# Epoch 142: Train Loss = 0.000247, Test Loss = 0.001039
# Epoch 143: Train Loss = 0.000174, Test Loss = 0.000939
# Epoch 144: Train Loss = 0.000175, Test Loss = 0.000911
# Epoch 145: Train Loss = 0.000170, Test Loss = 0.000937
# Epoch 146: Train Loss = 0.000164, Test Loss = 0.000947
# Epoch 147: Train Loss = 0.000213, Test Loss = 0.000925
# Epoch 148: Train Loss = 0.000236, Test Loss = 0.000935
# Epoch 149: Train Loss = 0.000202, Test Loss = 0.000857
# Epoch 150: Train Loss = 0.000181, Test Loss = 0.001197
# Epoch 151: Train Loss = 0.000171, Test Loss = 0.001053
# Epoch 152: Train Loss = 0.000142, Test Loss = 0.000911
# Epoch 153: Train Loss = 0.000151, Test Loss = 0.000963
# Epoch 154: Train Loss = 0.000298, Test Loss = 0.000903
# Epoch 155: Train Loss = 0.000164, Test Loss = 0.001019
# Epoch 156: Train Loss = 0.000185, Test Loss = 0.000929
# Epoch 157: Train Loss = 0.000148, Test Loss = 0.000935
# Epoch 158: Train Loss = 0.000178, Test Loss = 0.000922
# Epoch 159: Train Loss = 0.000225, Test Loss = 0.000874
# Epoch 160: Train Loss = 0.000183, Test Loss = 0.000876
# Epoch 161: Train Loss = 0.000168, Test Loss = 0.000896
# Epoch 162: Train Loss = 0.000157, Test Loss = 0.000833
# Epoch 163: Train Loss = 0.000138, Test Loss = 0.000918
# Epoch 164: Train Loss = 0.000157, Test Loss = 0.000964
# Epoch 165: Train Loss = 0.000192, Test Loss = 0.000929
# Epoch 166: Train Loss = 0.000201, Test Loss = 0.001006
# Epoch 167: Train Loss = 0.000185, Test Loss = 0.000849
# Epoch 168: Train Loss = 0.000165, Test Loss = 0.000899
# Epoch 169: Train Loss = 0.000166, Test Loss = 0.000857
# Epoch 170: Train Loss = 0.000178, Test Loss = 0.000871
# Epoch 171: Train Loss = 0.000156, Test Loss = 0.000918
# Epoch 172: Train Loss = 0.000162, Test Loss = 0.000880
# Epoch 173: Train Loss = 0.000173, Test Loss = 0.001029
# Epoch 174: Train Loss = 0.000186, Test Loss = 0.001075
# Epoch 175: Train Loss = 0.000170, Test Loss = 0.000883
# Epoch 176: Train Loss = 0.000157, Test Loss = 0.000896
# Epoch 177: Train Loss = 0.000167, Test Loss = 0.001012
# Epoch 178: Train Loss = 0.000158, Test Loss = 0.000881
# Epoch 179: Train Loss = 0.000141, Test Loss = 0.000862
# Epoch 180: Train Loss = 0.000151, Test Loss = 0.000875
# Epoch 181: Train Loss = 0.000162, Test Loss = 0.000837
# Epoch 182: Train Loss = 0.000139, Test Loss = 0.000921
# Epoch 183: Train Loss = 0.000171, Test Loss = 0.000873
# Epoch 184: Train Loss = 0.000165, Test Loss = 0.000878
# Epoch 185: Train Loss = 0.000143, Test Loss = 0.000889
# Epoch 186: Train Loss = 0.000147, Test Loss = 0.000822
# Epoch 187: Train Loss = 0.000165, Test Loss = 0.000836
# Epoch 188: Train Loss = 0.000135, Test Loss = 0.000903
# Epoch 189: Train Loss = 0.000193, Test Loss = 0.001105
# Epoch 190: Train Loss = 0.000163, Test Loss = 0.000900
# Epoch 191: Train Loss = 0.000135, Test Loss = 0.000831
# Epoch 192: Train Loss = 0.000137, Test Loss = 0.000898
# Epoch 193: Train Loss = 0.000139, Test Loss = 0.000887
# Epoch 194: Train Loss = 0.000157, Test Loss = 0.000905
# Epoch 195: Train Loss = 0.000144, Test Loss = 0.000840
# Epoch 196: Train Loss = 0.000137, Test Loss = 0.000828
# Epoch 197: Train Loss = 0.000161, Test Loss = 0.000944
# Epoch 198: Train Loss = 0.000147, Test Loss = 0.000817
# Epoch 199: Train Loss = 0.000134, Test Loss = 0.000878
# Epoch 200: Train Loss = 0.000162, Test Loss = 0.000878
# Epoch 201: Train Loss = 0.000154, Test Loss = 0.000877
# Epoch 202: Train Loss = 0.000139, Test Loss = 0.000832
# Epoch 203: Train Loss = 0.000130, Test Loss = 0.000908
# Epoch 204: Train Loss = 0.000127, Test Loss = 0.000855
# Epoch 205: Train Loss = 0.000146, Test Loss = 0.000931
# Epoch 206: Train Loss = 0.000129, Test Loss = 0.000855
# Epoch 207: Train Loss = 0.000134, Test Loss = 0.000833
# Epoch 208: Train Loss = 0.000147, Test Loss = 0.000863
# Epoch 209: Train Loss = 0.000151, Test Loss = 0.001088
# Epoch 210: Train Loss = 0.000193, Test Loss = 0.000849
# Epoch 211: Train Loss = 0.000107, Test Loss = 0.000816
# Epoch 212: Train Loss = 0.000145, Test Loss = 0.000981
# Epoch 213: Train Loss = 0.000147, Test Loss = 0.000894
# Epoch 214: Train Loss = 0.000125, Test Loss = 0.000865
# Epoch 215: Train Loss = 0.000134, Test Loss = 0.000855
# Epoch 216: Train Loss = 0.000109, Test Loss = 0.000804
# Epoch 217: Train Loss = 0.000121, Test Loss = 0.000907
# Epoch 218: Train Loss = 0.000169, Test Loss = 0.000868
# Epoch 219: Train Loss = 0.000144, Test Loss = 0.001060
# Epoch 220: Train Loss = 0.000137, Test Loss = 0.000845
# Epoch 221: Train Loss = 0.000138, Test Loss = 0.000857
# Epoch 222: Train Loss = 0.000111, Test Loss = 0.000894
# Epoch 223: Train Loss = 0.000125, Test Loss = 0.000820
# Epoch 224: Train Loss = 0.000117, Test Loss = 0.000868
# Epoch 225: Train Loss = 0.000144, Test Loss = 0.001034
# Epoch 226: Train Loss = 0.000159, Test Loss = 0.000891
# Epoch 227: Train Loss = 0.000106, Test Loss = 0.000816
# Epoch 228: Train Loss = 0.000094, Test Loss = 0.000829
# Epoch 229: Train Loss = 0.000129, Test Loss = 0.000842
# Epoch 230: Train Loss = 0.000122, Test Loss = 0.000850
# Epoch 231: Train Loss = 0.000140, Test Loss = 0.000832
# Epoch 232: Train Loss = 0.000131, Test Loss = 0.000885
# Epoch 233: Train Loss = 0.000132, Test Loss = 0.000868
# Epoch 234: Train Loss = 0.000144, Test Loss = 0.000813
# Epoch 235: Train Loss = 0.000110, Test Loss = 0.000808
# Epoch 236: Train Loss = 0.000130, Test Loss = 0.000831
# Epoch 237: Train Loss = 0.000104, Test Loss = 0.000858
# Epoch 238: Train Loss = 0.000129, Test Loss = 0.000836
# Epoch 239: Train Loss = 0.000129, Test Loss = 0.000870
# Epoch 240: Train Loss = 0.000113, Test Loss = 0.000803
# Epoch 241: Train Loss = 0.000122, Test Loss = 0.000859
# Epoch 242: Train Loss = 0.000128, Test Loss = 0.000828
# Epoch 243: Train Loss = 0.000108, Test Loss = 0.000860
# Epoch 244: Train Loss = 0.000133, Test Loss = 0.000880
# Epoch 245: Train Loss = 0.000117, Test Loss = 0.000797
# Epoch 246: Train Loss = 0.000129, Test Loss = 0.000785
# Epoch 247: Train Loss = 0.000107, Test Loss = 0.000809
# Epoch 248: Train Loss = 0.000104, Test Loss = 0.000813
# Epoch 249: Train Loss = 0.000114, Test Loss = 0.000869
# Epoch 250: Train Loss = 0.000138, Test Loss = 0.000925
# Epoch 251: Train Loss = 0.000109, Test Loss = 0.000838
# Epoch 252: Train Loss = 0.000122, Test Loss = 0.000858
# Epoch 253: Train Loss = 0.000111, Test Loss = 0.000911
# Epoch 254: Train Loss = 0.000136, Test Loss = 0.000837
# Epoch 255: Train Loss = 0.000115, Test Loss = 0.000815
# Epoch 256: Train Loss = 0.000150, Test Loss = 0.000817
# Epoch 257: Train Loss = 0.000101, Test Loss = 0.000806
# Epoch 258: Train Loss = 0.000116, Test Loss = 0.000810
# Epoch 259: Train Loss = 0.000095, Test Loss = 0.000842
# Epoch 260: Train Loss = 0.000138, Test Loss = 0.000818
# Epoch 261: Train Loss = 0.000146, Test Loss = 0.000851
# Epoch 262: Train Loss = 0.000117, Test Loss = 0.000893
# Epoch 263: Train Loss = 0.000136, Test Loss = 0.000797
# Epoch 264: Train Loss = 0.000084, Test Loss = 0.000843
# Epoch 265: Train Loss = 0.000113, Test Loss = 0.000875
# Epoch 266: Train Loss = 0.000098, Test Loss = 0.000868
# Epoch 267: Train Loss = 0.000137, Test Loss = 0.000847
# Epoch 268: Train Loss = 0.000114, Test Loss = 0.000799
# Epoch 269: Train Loss = 0.000107, Test Loss = 0.000840
# Epoch 270: Train Loss = 0.000138, Test Loss = 0.000994
# Epoch 271: Train Loss = 0.000118, Test Loss = 0.000832
# Epoch 272: Train Loss = 0.000086, Test Loss = 0.000788
# Epoch 273: Train Loss = 0.000104, Test Loss = 0.000843
# Epoch 274: Train Loss = 0.000100, Test Loss = 0.000860
# Epoch 275: Train Loss = 0.000113, Test Loss = 0.000843
# Epoch 276: Train Loss = 0.000103, Test Loss = 0.000828
# Epoch 277: Train Loss = 0.000103, Test Loss = 0.000832
# Epoch 278: Train Loss = 0.000097, Test Loss = 0.000824
# Epoch 279: Train Loss = 0.000166, Test Loss = 0.001026
# Epoch 280: Train Loss = 0.000098, Test Loss = 0.000789
# Epoch 281: Train Loss = 0.000076, Test Loss = 0.000818
# Epoch 282: Train Loss = 0.000105, Test Loss = 0.000813
# Epoch 283: Train Loss = 0.000099, Test Loss = 0.000853
# Epoch 284: Train Loss = 0.000119, Test Loss = 0.000918
# Epoch 285: Train Loss = 0.000129, Test Loss = 0.000882
# Epoch 286: Train Loss = 0.000096, Test Loss = 0.000809
# Epoch 287: Train Loss = 0.000092, Test Loss = 0.000833
# Epoch 288: Train Loss = 0.000101, Test Loss = 0.000798
# Epoch 289: Train Loss = 0.000124, Test Loss = 0.000895
# Epoch 290: Train Loss = 0.000107, Test Loss = 0.000838
# Epoch 291: Train Loss = 0.000110, Test Loss = 0.000815
# Epoch 292: Train Loss = 0.000085, Test Loss = 0.000832
# Epoch 293: Train Loss = 0.000098, Test Loss = 0.000794
# Epoch 294: Train Loss = 0.000109, Test Loss = 0.000844
# Epoch 295: Train Loss = 0.000113, Test Loss = 0.000821
# Epoch 296: Train Loss = 0.000106, Test Loss = 0.000829
# Epoch 297: Train Loss = 0.000090, Test Loss = 0.000837
# Epoch 298: Train Loss = 0.000112, Test Loss = 0.000814
# Epoch 299: Train Loss = 0.000117, Test Loss = 0.000950
# Epoch 300: Train Loss = 0.000090, Test Loss = 0.000805
# Epoch 301: Train Loss = 0.000083, Test Loss = 0.000799
# Epoch 302: Train Loss = 0.000103, Test Loss = 0.000808
# Epoch 303: Train Loss = 0.000101, Test Loss = 0.000791
# Epoch 304: Train Loss = 0.000083, Test Loss = 0.000814
# Epoch 305: Train Loss = 0.000110, Test Loss = 0.000887
# Epoch 306: Train Loss = 0.000097, Test Loss = 0.000794
# Epoch 307: Train Loss = 0.000105, Test Loss = 0.000839
# Epoch 308: Train Loss = 0.000078, Test Loss = 0.000822
# Epoch 309: Train Loss = 0.000092, Test Loss = 0.000856
# Epoch 310: Train Loss = 0.000108, Test Loss = 0.000855
# Epoch 311: Train Loss = 0.000107, Test Loss = 0.000828
# Epoch 312: Train Loss = 0.000075, Test Loss = 0.000824
# Epoch 313: Train Loss = 0.000103, Test Loss = 0.000808
# Epoch 314: Train Loss = 0.000136, Test Loss = 0.000848
# Epoch 315: Train Loss = 0.000103, Test Loss = 0.000843
# Epoch 316: Train Loss = 0.000079, Test Loss = 0.000799
# Epoch 317: Train Loss = 0.000094, Test Loss = 0.000946
# Epoch 318: Train Loss = 0.000100, Test Loss = 0.000824
# Epoch 319: Train Loss = 0.000115, Test Loss = 0.000886
# Epoch 320: Train Loss = 0.000095, Test Loss = 0.000812
# Epoch 321: Train Loss = 0.000101, Test Loss = 0.000830
# Epoch 322: Train Loss = 0.000096, Test Loss = 0.000801
# Epoch 323: Train Loss = 0.000091, Test Loss = 0.000771
# Epoch 324: Train Loss = 0.000094, Test Loss = 0.000823
# Epoch 325: Train Loss = 0.000080, Test Loss = 0.000794
# Epoch 326: Train Loss = 0.000090, Test Loss = 0.000804
# Epoch 327: Train Loss = 0.000099, Test Loss = 0.000778
# Epoch 328: Train Loss = 0.000077, Test Loss = 0.000783
# Epoch 329: Train Loss = 0.000106, Test Loss = 0.000860
# Epoch 330: Train Loss = 0.000093, Test Loss = 0.000797
# Epoch 331: Train Loss = 0.000093, Test Loss = 0.000822
# Epoch 332: Train Loss = 0.000087, Test Loss = 0.000808
# Epoch 333: Train Loss = 0.000104, Test Loss = 0.000794
# Epoch 334: Train Loss = 0.000108, Test Loss = 0.000800
# Epoch 335: Train Loss = 0.000115, Test Loss = 0.000782
# Epoch 336: Train Loss = 0.000075, Test Loss = 0.000797
# Epoch 337: Train Loss = 0.000088, Test Loss = 0.000812
# Epoch 338: Train Loss = 0.000087, Test Loss = 0.000879
# Epoch 339: Train Loss = 0.000085, Test Loss = 0.000832
# Epoch 340: Train Loss = 0.000086, Test Loss = 0.000862
# Epoch 341: Train Loss = 0.000123, Test Loss = 0.000806
# Epoch 342: Train Loss = 0.000088, Test Loss = 0.000801
# Epoch 343: Train Loss = 0.000086, Test Loss = 0.000779
# Epoch 344: Train Loss = 0.000094, Test Loss = 0.000810
# Epoch 345: Train Loss = 0.000079, Test Loss = 0.000816
# Epoch 346: Train Loss = 0.000076, Test Loss = 0.000861
# Epoch 347: Train Loss = 0.000099, Test Loss = 0.000924
# Epoch 348: Train Loss = 0.000110, Test Loss = 0.000794
# Epoch 349: Train Loss = 0.000061, Test Loss = 0.000820
# Epoch 350: Train Loss = 0.000097, Test Loss = 0.000825
# Epoch 351: Train Loss = 0.000086, Test Loss = 0.000843
# Epoch 352: Train Loss = 0.000119, Test Loss = 0.000991
# Epoch 353: Train Loss = 0.000107, Test Loss = 0.000792
# Epoch 354: Train Loss = 0.000072, Test Loss = 0.000894
# Epoch 355: Train Loss = 0.000084, Test Loss = 0.000773
# Epoch 356: Train Loss = 0.000085, Test Loss = 0.000810
# Epoch 357: Train Loss = 0.000118, Test Loss = 0.000806
# Epoch 358: Train Loss = 0.000087, Test Loss = 0.000802
# Epoch 359: Train Loss = 0.000078, Test Loss = 0.000843
# Epoch 360: Train Loss = 0.000086, Test Loss = 0.000811
# Epoch 361: Train Loss = 0.000093, Test Loss = 0.000830
# Epoch 362: Train Loss = 0.000076, Test Loss = 0.000813
# Epoch 363: Train Loss = 0.000085, Test Loss = 0.000835
# Epoch 364: Train Loss = 0.000094, Test Loss = 0.000801
# Epoch 365: Train Loss = 0.000079, Test Loss = 0.000856
# Epoch 366: Train Loss = 0.000094, Test Loss = 0.000796
# Epoch 367: Train Loss = 0.000084, Test Loss = 0.000800
# Epoch 368: Train Loss = 0.000080, Test Loss = 0.000796
# Epoch 369: Train Loss = 0.000095, Test Loss = 0.000805
# Epoch 370: Train Loss = 0.000075, Test Loss = 0.000823
# Epoch 371: Train Loss = 0.000090, Test Loss = 0.000922
# Epoch 372: Train Loss = 0.000089, Test Loss = 0.000811
# Epoch 373: Train Loss = 0.000074, Test Loss = 0.000832
# Epoch 374: Train Loss = 0.000079, Test Loss = 0.000799
# Epoch 375: Train Loss = 0.000101, Test Loss = 0.000838
# Epoch 376: Train Loss = 0.000074, Test Loss = 0.000807
# Epoch 377: Train Loss = 0.000063, Test Loss = 0.000791
# Epoch 378: Train Loss = 0.000079, Test Loss = 0.000769
# Epoch 379: Train Loss = 0.000092, Test Loss = 0.000840
# Epoch 380: Train Loss = 0.000089, Test Loss = 0.000779
# Epoch 381: Train Loss = 0.000079, Test Loss = 0.000846
# Epoch 382: Train Loss = 0.000094, Test Loss = 0.000831
# Epoch 383: Train Loss = 0.000090, Test Loss = 0.000770
# Epoch 384: Train Loss = 0.000072, Test Loss = 0.000800
# Epoch 385: Train Loss = 0.000064, Test Loss = 0.000813
# Epoch 386: Train Loss = 0.000080, Test Loss = 0.000816
# Epoch 387: Train Loss = 0.000080, Test Loss = 0.000783
# Epoch 388: Train Loss = 0.000071, Test Loss = 0.000855
# Epoch 389: Train Loss = 0.000082, Test Loss = 0.000807
# Epoch 390: Train Loss = 0.000100, Test Loss = 0.000814
# Epoch 391: Train Loss = 0.000080, Test Loss = 0.000789
# Epoch 392: Train Loss = 0.000098, Test Loss = 0.000783
# Epoch 393: Train Loss = 0.000081, Test Loss = 0.000783
# Epoch 394: Train Loss = 0.000073, Test Loss = 0.000825
# Epoch 395: Train Loss = 0.000086, Test Loss = 0.000804
# Epoch 396: Train Loss = 0.000073, Test Loss = 0.000870
# Epoch 397: Train Loss = 0.000095, Test Loss = 0.000815
# Epoch 398: Train Loss = 0.000077, Test Loss = 0.000780
# Epoch 399: Train Loss = 0.000072, Test Loss = 0.000863
# Epoch 400: Train Loss = 0.000077, Test Loss = 0.000810
# Epoch 401: Train Loss = 0.000074, Test Loss = 0.000794
# Epoch 402: Train Loss = 0.000078, Test Loss = 0.000799
# Epoch 403: Train Loss = 0.000084, Test Loss = 0.000780
# Epoch 404: Train Loss = 0.000069, Test Loss = 0.000812
# Epoch 405: Train Loss = 0.000073, Test Loss = 0.000824
# Epoch 406: Train Loss = 0.000088, Test Loss = 0.000839
# Epoch 407: Train Loss = 0.000085, Test Loss = 0.000835
# Epoch 408: Train Loss = 0.000072, Test Loss = 0.000825
# Epoch 409: Train Loss = 0.000075, Test Loss = 0.000803
# Epoch 410: Train Loss = 0.000085, Test Loss = 0.000812
# Epoch 411: Train Loss = 0.000076, Test Loss = 0.000817
# Epoch 412: Train Loss = 0.000072, Test Loss = 0.000800
# Epoch 413: Train Loss = 0.000077, Test Loss = 0.000796
# Epoch 414: Train Loss = 0.000074, Test Loss = 0.000774
# Epoch 415: Train Loss = 0.000084, Test Loss = 0.000806
# Epoch 416: Train Loss = 0.000065, Test Loss = 0.000778
# Epoch 417: Train Loss = 0.000073, Test Loss = 0.000779
# Epoch 418: Train Loss = 0.000097, Test Loss = 0.000802
# Epoch 419: Train Loss = 0.000067, Test Loss = 0.000786
# Epoch 420: Train Loss = 0.000080, Test Loss = 0.000796
# Epoch 421: Train Loss = 0.000073, Test Loss = 0.000814
# Epoch 422: Train Loss = 0.000075, Test Loss = 0.000798
# Epoch 423: Train Loss = 0.000085, Test Loss = 0.000895
# Epoch 424: Train Loss = 0.000067, Test Loss = 0.000815
# Epoch 425: Train Loss = 0.000082, Test Loss = 0.000824
# Epoch 426: Train Loss = 0.000072, Test Loss = 0.000833
# Epoch 427: Train Loss = 0.000080, Test Loss = 0.000771
# Epoch 428: Train Loss = 0.000070, Test Loss = 0.000813
# Epoch 429: Train Loss = 0.000079, Test Loss = 0.000804
# Epoch 430: Train Loss = 0.000085, Test Loss = 0.000830
# Epoch 431: Train Loss = 0.000088, Test Loss = 0.000763
# Epoch 432: Train Loss = 0.000069, Test Loss = 0.000781
# Epoch 433: Train Loss = 0.000074, Test Loss = 0.000806
# Epoch 434: Train Loss = 0.000064, Test Loss = 0.000841
# Epoch 435: Train Loss = 0.000065, Test Loss = 0.000794
# Epoch 436: Train Loss = 0.000071, Test Loss = 0.000811
# Epoch 437: Train Loss = 0.000080, Test Loss = 0.000832
# Epoch 438: Train Loss = 0.000075, Test Loss = 0.000786
# Epoch 439: Train Loss = 0.000067, Test Loss = 0.000792
# Epoch 440: Train Loss = 0.000064, Test Loss = 0.000795
# Epoch 441: Train Loss = 0.000073, Test Loss = 0.000834
# Epoch 442: Train Loss = 0.000064, Test Loss = 0.000784
# Epoch 443: Train Loss = 0.000069, Test Loss = 0.000790
# Epoch 444: Train Loss = 0.000093, Test Loss = 0.000771
# Epoch 445: Train Loss = 0.000066, Test Loss = 0.000792
# Epoch 446: Train Loss = 0.000067, Test Loss = 0.000780
# Epoch 447: Train Loss = 0.000052, Test Loss = 0.000808
# Epoch 448: Train Loss = 0.000128, Test Loss = 0.000811
# Epoch 449: Train Loss = 0.000066, Test Loss = 0.000860
# Epoch 450: Train Loss = 0.000078, Test Loss = 0.000779
# Epoch 451: Train Loss = 0.000062, Test Loss = 0.000841
# Epoch 452: Train Loss = 0.000072, Test Loss = 0.000798
# Epoch 453: Train Loss = 0.000085, Test Loss = 0.000785
# Epoch 454: Train Loss = 0.000078, Test Loss = 0.000772
# Epoch 455: Train Loss = 0.000055, Test Loss = 0.000801
# Epoch 456: Train Loss = 0.000074, Test Loss = 0.000785
# Epoch 457: Train Loss = 0.000068, Test Loss = 0.000768
# Epoch 458: Train Loss = 0.000071, Test Loss = 0.000780
# Epoch 459: Train Loss = 0.000059, Test Loss = 0.000788
# Epoch 460: Train Loss = 0.000063, Test Loss = 0.000780
# Epoch 461: Train Loss = 0.000088, Test Loss = 0.000810
# Epoch 462: Train Loss = 0.000072, Test Loss = 0.000823
# Epoch 463: Train Loss = 0.000071, Test Loss = 0.000774
# Epoch 464: Train Loss = 0.000058, Test Loss = 0.000764
# Epoch 465: Train Loss = 0.000068, Test Loss = 0.000765
# Epoch 466: Train Loss = 0.000069, Test Loss = 0.000839
# Epoch 467: Train Loss = 0.000058, Test Loss = 0.000799
# Epoch 468: Train Loss = 0.000075, Test Loss = 0.000787
# Epoch 469: Train Loss = 0.000071, Test Loss = 0.000824
# Epoch 470: Train Loss = 0.000072, Test Loss = 0.000800
# Epoch 471: Train Loss = 0.000073, Test Loss = 0.000771
# Epoch 472: Train Loss = 0.000077, Test Loss = 0.000802
# Epoch 473: Train Loss = 0.000075, Test Loss = 0.000800
# Epoch 474: Train Loss = 0.000056, Test Loss = 0.000777
# Epoch 475: Train Loss = 0.000075, Test Loss = 0.000775
# Epoch 476: Train Loss = 0.000070, Test Loss = 0.000793
# Epoch 477: Train Loss = 0.000068, Test Loss = 0.000780
# Epoch 478: Train Loss = 0.000071, Test Loss = 0.000820
# Epoch 479: Train Loss = 0.000066, Test Loss = 0.000857
# Epoch 480: Train Loss = 0.000063, Test Loss = 0.000796
# Epoch 481: Train Loss = 0.000055, Test Loss = 0.000795
# Epoch 482: Train Loss = 0.000080, Test Loss = 0.000831
# Epoch 483: Train Loss = 0.000082, Test Loss = 0.000856
# Epoch 484: Train Loss = 0.000071, Test Loss = 0.000809
# Epoch 485: Train Loss = 0.000057, Test Loss = 0.000841
# Epoch 486: Train Loss = 0.000054, Test Loss = 0.000811
# Epoch 487: Train Loss = 0.000073, Test Loss = 0.000825
# Epoch 488: Train Loss = 0.000066, Test Loss = 0.000785
# Epoch 489: Train Loss = 0.000062, Test Loss = 0.000795
# Epoch 490: Train Loss = 0.000071, Test Loss = 0.000775
# Epoch 491: Train Loss = 0.000071, Test Loss = 0.000799
# Epoch 492: Train Loss = 0.000067, Test Loss = 0.000801
# Epoch 493: Train Loss = 0.000066, Test Loss = 0.000775
# Epoch 494: Train Loss = 0.000065, Test Loss = 0.000787
# Epoch 495: Train Loss = 0.000059, Test Loss = 0.000781
# Epoch 496: Train Loss = 0.000056, Test Loss = 0.000786
# Epoch 497: Train Loss = 0.000075, Test Loss = 0.000810
# Epoch 498: Train Loss = 0.000077, Test Loss = 0.000799
# Epoch 499: Train Loss = 0.000060, Test Loss = 0.000815
# Epoch 500: Train Loss = 0.000073, Test Loss = 0.000812

# %%
plt.figure(figsize=(8,6))
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.yscale("log")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()
plt.title("Training and Test Loss Curves (FNO3d)")
plt.show()
